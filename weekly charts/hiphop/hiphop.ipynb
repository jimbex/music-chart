# %%
import pandas as pd
from datetime import datetime
m = datetime.today().strftime('%B')
d = datetime.today().strftime('%d')
w = datetime.today().strftime('%V')
w = int(w)
d = int(d)

# %%
df1 = pd.read_csv(f'apple_afrohiphop-week{w}.csv', encoding='utf-8')
df2 = pd.read_csv(f'audio_hiphop-week{w}.csv', encoding='utf-8')
df3 = pd.read_csv(f'youtube_afrohiphop-week{w}.csv', encoding='utf-8')
df4 = pd.read_csv(f'boom_hiphop-week{w}.csv', encoding='utf-8')
df5 = pd.read_csv(f'spotify_afrohiphop-week{w}.csv', encoding='utf-8')
df6 = pd.read_csv(f'deezer_afrohiphop-week{w}.csv', encoding='utf-8')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]
df4 = df4[['song', 'artist']]
df5 = df5[['song', 'artist']]
df6 = df6[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    i = i.lower()
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        a[x] = a[x].replace('feat', '(feat')
    if 'remix' in i:
        a[x] = a[x].replace('remix', '(remix')
    if '  ' in i:
        a[x] = a[x].replace('  ', ' ')
    if '(' in a[x]:
        a[x] = a[x][: a[x].index('(')]
    if '\\' in i:
        a[x] = a[x].replace('\\', '') 
    a[x] = a[x].strip().lower()
    x += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a120a6babc2f> in <module>
# ----> 1 a = list(df1['song'])
#       2 a1 = a.copy()
#       3 a2 = list(df1['artist'])
#       4 x = 0
#       5 for i in a:
#
# NameError: name 'df1' is not defined

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    i = i.lower()
    if 'remix' in i:
        b[x] = i.replace('remix', '(remix')
    if 'ft' in i:
        b[x] = b[x].replace('ft', '(ft')
    if 'feat' in i:
        b[x] = b[x].replace('feat', '(feat')
    if '  ' in i:
        b[x] = b[x].replace('  ', ' ')
    if '(' in b[x]:
        b[x] = b[x][: b[x].index('(')]
    if '\\' in i:
        b[x] = b[x].replace('\\', '') 
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    i = i.lower()
    if 'ft' in i:
        c[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        c[x] = c[x].replace('feat', '(feat')
    if 'remix' in i:
        c[x] = c[x].replace('remix', '(remix')
    if '  ' in i:
        c[x] = c[x].replace('  ', ' ')
    if '(' in c[x]:
        c[x] = c[x][: c[x].index('(')]
    if '\\' in i:
        c[x] = c[x].replace('\\', '')  
    c[x] = c[x].strip().lower()
    x += 1

# %%
d = list(df4['song'])
d1 = d.copy()
d2 = list(df4['artist'])
x = 0
for i in d:
    i = i.lower()
    if 'ft' in i:
        d[x] = i.replace('ft', '(ft') + ')'
    if 'feat' in i:
        d[x] = d[x].replace('feat', '(feat')
    if 'remix' in i:
        d[x] = d[x].replace('remix', '(remix')
    if '  ' in d[x]:
        d[x] = d[x].replace('  ', ' ')
    x += 1
x = 0
for i in d:
    if '(' in i:
        d[x] = i[: i.index('(')]
    if '\\' in i:
        d[x] = d[x].replace('\\', '') 
    d[x] = d[x].strip().lower()
    x += 1

# %%
e = list(df5['song'])
e1 = e.copy()
e2 = list(df5['artist'])
x = 0
for i in e:
    i = i.lower()
    if 'ft' in i:
        e[x] = e[x].replace('ft', '(ft')
    if 'feat' in i:
        e[x] = e[x].replace('feat', '(feat')
    if 'remix' in i:
        e[x] = e[x].replace('remix', '(remix')
    if '  ' in i:
        e[x] = e[x].replace('  ', ' ')
    if '(' in e[x]:
        e[x] = e[x][: e[x].index('(')]
    if '\\' in i:
        e[x] = e[x].replace('\\', '') 
    e[x] = e[x].strip().lower()
    x += 1

# %%
f = list(df6['song'])
f1 = f.copy()
f2 = list(df6['artist'])
x = 0
for i in f:
    i = i.lower()
    if 'ft' in i:
        f[x] = f[x].replace('ft', '(ft')
    if 'feat' in i:
        f[x] = f[x].replace('feat', '(feat')
    if 'remix' in i:
        f[x] = f[x].replace('remix', '(remix')
    if '  ' in i:
        f[x] = f[x].replace('  ', ' ')
    if '(' in f[x]:
        f[x] = f[x][: f[x].index('(')]
    if '\\' in i:
        f[x] = f[x].replace('\\', '') 
    f[x] = f[x].strip().lower()
    x += 1

# %%
songs = a + b + c + d + e + f
songs = set(songs)

# %%
len(songs)
# Out:
# 334

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [400]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(410)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(350)

# %%
x = 0
for i in songs:
    if i in d:
        final[i].append(d.index(i) + 1)
    else:
        final[i].append(450)

# %%
x = 0
for i in songs:
    if i in e:
        final[i].append(e.index(i) + 1)
    else:
        final[i].append(420)

# %%
x = 0
for i in songs:
    if i in f:
        final[i].append(f.index(i) + 1)
    else:
        final[i].append(330)

# %%
x = 0
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    if i in b and len(final[i]) < 7:
        final[i].append(b2[b.index(i)])
    if i in c and len(final[i]) < 7:
        final[i].append(c2[c.index(i)])
    if i in d and len(final[i]) < 7:
        final[i].append(d2[d.index(i)])
    if i in e and len(final[i]) < 7:
        final[i].append(e2[e.index(i)])
    if i in f and len(final[i]) < 7:
        final[i].append(f2[f.index(i)])
    x += 1

# %%
final
# Out:
# {'the box': [400, 410, 350, 65, 420, 330, 'Roddy Ricch'],
#  'verdansk': [400, 410, 350, 49, 420, 330, 'Dave'],
#  'aquafina froze': [38, 410, 350, 450, 420, 330, 'Sosa-E'],
#  'round 2': [400, 410, 350, 450, 67, 330, 'Sarkodie, Giggs'],
#  'tomorrow never comes': [400, 410, 350, 20, 420, 330, 'PlaTBoss'],
#  'kilode': [44, 410, 350, 450, 420, 330, 'Tobii WTW'],
#  'molade': [400, 42, 350, 450, 420, 330, 'Beatsbykarma'],
#  'monalisa': [400, 410, 350, 17, 420, 330, 'Lojay'],
#  't.y.b': [26, 410, 350, 450, 420, 330, 'Del B,  Phyno and  Mufasa'],
#  'tiktok girl': [400, 46, 350, 450, 420, 330, 'Kwasi Yesu'],
#  'hold on': [72, 410, 350, 450, 420, 330, 'Oluwapizzle and  Emaxee'],
#  'ops': [400, 69, 350, 450, 420, 330, 'KashCPT'],
#  'dragon roll': [400, 410, 350, 450, 8, 330, 'Frenna'],
#  'problem no dey finish': [400, 410, 350, 450, 40, 330, 'BRYAN THE MENSAH'],
#  'the end': [400, 410, 350, 66, 420, 330, 'Erigga'],
#  'ammo': [400, 410, 350, 450, 26, 330, 'Shane Eagle'],
#  "god's work": [400, 410, 350, 450, 18, 330, 'IAMDDB'],
#  'all my life': [400, 410, 350, 21, 420, 7, 'M.I Abaga'],
#  'use to this': [400, 45, 350, 450, 420, 330, 'Marvy feat. Psycho YP'],
#  'jailer': [91, 410, 350, 450, 420, 330, 'Olamide'],
#  'don’t truss': [400, 81, 350, 450, 420, 330, 'PatricKxxLee'],
#  'black': [400, 410, 25, 450, 420, 330, 'Shane Eagle'],
#  'dreams': [21, 410, 350, 450, 420, 330, 'Kilo Kami'],
#  'monster': [400, 15, 350, 450, 420, 330, 'Vnero feat. Tonez'],
#  "it's not a gun": [400, 410, 350, 450, 51, 330, 'DAP The Contract'],
#  'balance': [400,
#   8,
#   350,
#   450,
#   420,
#   330,
#   'Pappy Kojo featuring Joey B and Nshonamuzik'],
#  'loose guard': [400, 19, 350, 450, 420, 41, 'Legendary Styles & Falz'],
#  'change': [400,
#   59,
#   350,
#   450,
#   420,
#   330,
#   'Lord Edward and Boy Nino feat. Murphy Cubic, Tyrone Jones'],
#  'kolo': [400, 7, 350, 450, 420, 3, 'Ice Prince '],
#  'african knockout': [400,
#   23,
#   350,
#   450,
#   420,
#   330,
#   'AFRICAN KNOCKOUT x M.I Abaga'],
#  'wahala dey': [400, 410, 350, 28, 420, 330, 'Erigga'],
#  'ghost': [400, 58, 350, 450, 420, 330, 'Stringz Beatz'],
#  'i no wear pant': [400, 410, 350, 36, 420, 330, 'Erigga'],
#  'whipped': [1, 410, 350, 450, 420, 330, 'Sarkodie'],
#  'high': [59, 410, 350, 450, 420, 330, 'Korshi T'],
#  'no fugazy': [400, 3, 350, 450, 420, 330, 'Sarkodie'],
#  'what if i stumble': [87, 410, 350, 450, 420, 330, 'Snatcha'],
#  'makola dreams': [66, 410, 350, 450, 420, 330, 'Omar Sterling'],
#  'the 5 year plan': [400, 410, 350, 450, 43, 330, 'A-Reece'],
#  'gidi flex': [93, 410, 350, 450, 420, 330, 'KingJayy'],
#  'the target': [400, 410, 36, 450, 420, 330, 'Medikal'],
#  'yaya tourxc3xa9': [80, 410, 350, 450, 420, 330, 'Yung Mavu'],
#  'ksm': [400, 77, 350, 450, 420, 330, 'Naza'],
#  'dorime': [400, 79, 350, 450, 420, 330, 'Samklef'],
#  'pagans': [27,
#   410,
#   350,
#   450,
#   420,
#   330,
#   'Kelly Anthony,  Sarkodie and  Larruso'],
#  'untimely': [35, 410, 350, 450, 420, 330, 'Kelly Anthony and  Vory'],
#  'make up your mind': [400, 410, 350, 450, 7, 330, 'Ice Prince'],
#  'somebody': [6, 410, 350, 450, 420, 330, 'Olamide'],
#  'politics and lies': [400, 410, 350, 13, 420, 330, 'PlaTBoss'],
#  'glory': [400, 410, 38, 450, 420, 330, 'Nyashinski'],
#  'y3 y3 dom': [97, 76, 350, 450, 420, 27, 'Jay Bahd'],
#  'mona lisa': [400, 410, 350, 450, 56, 330, 'Booba'],
#  'snakes in the crib': [400,
#   54,
#   350,
#   450,
#   420,
#   330,
#   'Kwesta featuring Tshego AMG'],
#  'akata gang gang': [68, 410, 350, 450, 420, 330, 'Reggie'],
#  'deep in da streets': [400, 410, 350, 450, 48, 330, 'TNT Kenya'],
#  'rich off pain': [400, 410, 350, 68, 420, 330, 'LiL Baby'],
#  'mofoti 2.0': [78, 410, 350, 450, 420, 330, 'Rexxie'],
#  'loyal': [56, 410, 350, 450, 420, 330, 'Acebergtm'],
#  'lemme know': [400, 410, 350, 450, 420, 42, 'LADIPOE'],
#  'decisions': [67, 410, 350, 450, 420, 17, 'Jay Bahd'],
#  'class clown': [400, 410, 13, 450, 420, 330, 'TNT Kenya'],
#  'no fear': [400, 4, 21, 450, 420, 330, 'M.anifest'],
#  'who be this guy': [400, 64, 42, 450, 420, 330, 'Kheengz'],
#  'sika beba': [15, 410, 350, 450, 420, 330, 'Akesisem'],
#  'dimension': [400, 410, 350, 4, 420, 330, 'Jae5'],
#  'toxic': [400, 21, 350, 450, 420, 330, 'Reminisce'],
#  'indifferent': [400, 410, 350, 52, 420, 330, 'PlaTBoss'],
#  'hapo tu': [400, 410, 350, 450, 30, 330, 'Nyashinski'],
#  'vector, khaligraph jones, dip doundou guiss': [400,
#   410,
#   48,
#   450,
#   420,
#   330,
#   'Vector'],
#  'keja': [400, 82, 350, 450, 420, 330, 'Juicee Mann'],
#  'grandad': [400, 410, 350, 450, 29, 330, 'NSG'],
#  '3:05am': [28, 410, 350, 450, 420, 330, 'Kenah'],
#  'jaara': [400, 410, 350, 59, 420, 330, 'Sarkodie'],
#  'odeshi': [400, 18, 350, 450, 420, 330, 'Kwvdwo Pvnch'],
#  'lazarus': [400, 410, 350, 14, 420, 330, 'Dave'],
#  'ye x 4': [58, 410, 350, 450, 420, 330, 'Blxckie and  Nasty C'],
#  'stress away': [42, 410, 350, 450, 420, 330, 'W1zzy and  PVPI STRZ'],
#  'lv n attn': [400, 410, 350, 29, 420, 330, 'Lojay'],
#  'every weekend': [400, 10, 350, 450, 420, 330, 'DJ Tunez & J. Anthoni'],
#  'village to city': [400, 410, 350, 450, 420, 43, 'Alpha Bankz'],
#  "hustler's tale": [400, 410, 350, 9, 420, 330, 'PlaTBoss'],
#  'σ. morose': [400, 410, 350, 450, 61, 330, 'Damso'],
#  'wishing well': [400, 410, 350, 40, 420, 330, 'Juice WRLD'],
#  'voice of the heroes': [400, 410, 350, 37, 420, 330, 'LiL Baby'],
#  'koleyewon': [400, 410, 350, 5, 420, 330, 'Naira Marley'],
#  'acebergtm': [400, 410, 45, 450, 420, 330, 'Acebergtm'],
#  'zamo': [32, 410, 350, 450, 420, 330, 'Ajebo Hustlers'],
#  'roll call': [400, 29, 350, 450, 420, 330, '$pacely'],
#  'go down': [400, 41, 350, 450, 420, 330, 'Bucky Raw'],
#  'senior man': [23, 410, 350, 450, 420, 330, 'Abobi Eddieroll'],
#  'truth': [400, 410, 22, 450, 420, 330, 'Emtee'],
#  'steve biko': [400, 410, 10, 450, 420, 330, 'Nasty C'],
#  'stoves': [63, 410, 350, 450, 420, 330, 'Wale the Sage'],
#  'no juju': [89, 410, 350, 450, 420, 330, 'Khofi Images'],
#  '1980': [400, 410, 350, 58, 420, 330, 'Original Gravity'],
#  'emtee': [400, 410, 35, 450, 420, 330, 'Nasty C'],
#  'whine it pon me': [29, 410, 350, 450, 420, 330, 'Young D'],
#  'justice': [400, 47, 350, 450, 420, 330, 'KayMad'],
#  'feeling': [57, 410, 350, 450, 45, 1, 'LADIPOE and  Buju'],
#  'euphoria': [75, 2, 350, 450, 33, 19, 'PsychoYP'],
#  'feel': [400, 410, 350, 2, 420, 330, 'Mrolaide '],
#  'mehia sika': [400, 63, 350, 450, 420, 330, 'ZACK GH'],
#  'mercy': [400, 84, 350, 450, 420, 330, 'Falz'],
#  'khaligraph jones x sarkodie': [400,
#   410,
#   24,
#   450,
#   420,
#   330,
#   'khaligraph jones ria'],
#  'ghetto': [400, 410, 350, 450, 420, 10, 'Kizz Daniel'],
#  're': [400, 410, 350, 450, 59, 330, 'Dua Saleh'],
#  'on the move': [400, 70, 350, 450, 420, 330, 'RichMiller'],
#  'gym': [400, 410, 350, 450, 57, 330, 'Kiki Marley'],
#  'for the money': [400, 410, 350, 12, 420, 330, 'Phyno'],
#  'in the fire': [400, 410, 350, 60, 420, 330, 'Dave'],
#  'stfu': [400, 410, 39, 450, 420, 330, 'Dremo'],
#  'fiesta': [51, 410, 350, 450, 420, 330, 'MHD'],
#  'hustle': [17, 410, 350, 450, 420, 330, 'Nami'],
#  'zombie': [400, 51, 350, 450, 420, 330, 'Blaqbonez'],
#  'confirm me': [83, 410, 350, 450, 420, 330, 'Durello'],
#  'cakes': [47, 410, 350, 450, 420, 330, 'Straffitti'],
#  'long way': [400, 410, 350, 450, 420, 34, 'Emtee'],
#  'a. iverson': [25, 410, 350, 450, 420, 330, 'Zamir'],
#  'location': [400, 410, 350, 450, 17, 330, 'Dave'],
#  'wreckless tactics': [400, 78, 350, 450, 420, 330, 'TRiPPY TRiPPY'],
#  'trust issues': [400, 410, 350, 16, 420, 330, 'PlaTBoss'],
#  'fantastic!': [400, 410, 350, 450, 37, 330, 'Suté Iwar'],
#  'money calling': [400, 410, 350, 450, 420, 20, 'P Montana'],
#  'astronaute': [400, 410, 350, 450, 52, 330, 'Youssoupha'],
#  'see you next week': [13, 410, 350, 450, 420, 330, 'Dremo'],
#  'done': [400, 410, 350, 450, 46, 330, 'Frida Amani'],
#  'rockets': [60, 410, 350, 450, 420, 330, 'Kashcpt'],
#  'forever': [52, 410, 350, 450, 420, 330, 'Frank Casino'],
#  'big boy': [400, 410, 350, 54, 420, 330, 'eLDee'],
#  'makaveli': [19, 410, 350, 450, 420, 330, 'Kida Kudz'],
#  'get a grip': [8, 410, 350, 450, 420, 330, 'DEELA'],
#  'brown': [400, 57, 350, 450, 420, 330, 'King Lutendo featuring Una Rams'],
#  'bourdillon love': [400, 38, 350, 450, 420, 330, 'Studio Magic x Fresh L'],
#  'why me remix': [400, 410, 350, 62, 420, 330, "Mo\\' Hits All Stars"],
#  'rip old dad': [81, 410, 350, 450, 420, 330, 'The.wav'],
#  "don't worry": [400, 33, 350, 450, 420, 330, 'Just G featuring Emtee'],
#  'tell the vision': [400, 410, 350, 19, 420, 330, 'Pop Smoke'],
#  'for me': [88, 410, 350, 450, 420, 330, 'The Beat-Oven'],
#  'death sentence': [70, 410, 350, 450, 420, 330, 'Amerado'],
#  'guestlist': [400, 410, 350, 450, 2, 330, 'Frenna'],
#  'graduation': [400, 410, 350, 53, 420, 330, 'PlaTBoss'],
#  'eyes off me': [94, 410, 350, 450, 420, 330, 'Stella Mwangi'],
#  'second sermon': [2, 410, 350, 27, 22, 6, 'Black Sherif'],
#  'la hustle': [400, 410, 34, 450, 420, 330, 'Medikal'],
#  'condemn': [400, 26, 350, 450, 420, 330, 'Jay Bahd'],
#  'in my bed': [400, 410, 350, 450, 420, 4, 'Rotimi'],
#  'goboyi': [400, 67, 350, 450, 420, 330, 'Odumodublvck, Reeplay'],
#  'david': [400, 410, 350, 450, 60, 330, 'Blxckie'],
#  'eazy': [400, 410, 350, 450, 420, 18, 'Nasty C'],
#  'longtime': [400, 410, 350, 450, 1, 330, 'WizKid'],
#  'last day out': [46, 410, 350, 450, 420, 330, 'T6lu'],
#  'uomo': [400,
#   17,
#   350,
#   450,
#   420,
#   330,
#   'Pappy Kojo featuring Sarkodie and KiddBlack'],
#  '4 you': [400, 66, 350, 450, 420, 330, 'Yung D3mz'],
#  'intense': [400, 28, 350, 450, 420, 330, 'Blackway, Busta Rhymes'],
#  'question for the gods': [50, 410, 350, 450, 58, 330, 'M3NSA'],
#  'k:hova': [400, 410, 350, 450, 47, 330, 'K.O'],
#  'foreign': [400, 55, 350, 450, 420, 330, 'ameen'],
#  'rise of the underdogs 2': [400,
#   74,
#   350,
#   450,
#   420,
#   16,
#   'Show Dem Camp featuring Tomi Thomas'],
#  'casino': [400, 410, 18, 450, 420, 330, 'Sho Madjozi'],
#  'over the top': [400, 410, 350, 56, 420, 330, 'SMILEY'],
#  'siberia': [400, 410, 350, 450, 12, 330, 'Headie One'],
#  "we don't play": [64, 410, 350, 450, 420, 330, 'Givtti'],
#  'could have been worse': [400, 27, 350, 450, 420, 330, 'CDQ'],
#  'problem': [400, 410, 350, 39, 420, 330, 'Kaptain'],
#  'best i ever had': [400, 410, 15, 450, 21, 26, 'Nasty C'],
#  'body on me': [61, 410, 350, 450, 420, 330, 'Sudxn'],
#  'matriculation': [400, 410, 350, 7, 420, 330, 'PlaTBoss'],
#  'clash': [400, 410, 350, 23, 420, 330, 'Dave'],
#  'hmm': [400, 410, 12, 450, 39, 330, 'G4 Boyz'],
#  'stay with me': [92, 410, 350, 450, 420, 330, 'Layzee Ella'],
#  'east to west': [400, 410, 350, 38, 420, 330, 'Dremo'],
#  'kivuruga': [20, 410, 350, 450, 420, 330, 'Bushali and  Ghanaian Stallion'],
#  'midf': [400, 410, 17, 450, 15, 330, 'Ycee'],
#  'fire in the ghetto': [400,
#   13,
#   350,
#   450,
#   420,
#   330,
#   'Kwesta featuring Troublle'],
#  'run the cheque': [400, 52, 350, 450, 420, 330, 'D-Truce'],
#  '40 bars': [400, 410, 29, 450, 420, 330, 'Emtee'],
#  'my heart': [400, 410, 350, 450, 54, 330, 'Pappy Kojo'],
#  'touch down': [18, 410, 350, 450, 420, 330, 'Kvng Dav'],
#  'dumelang': [400, 410, 350, 450, 420, 44, 'Tumi Tladi'],
#  'non living thing': [24, 410, 350, 450, 420, 330, 'Sarkodie'],
#  'mbougeul': [10, 410, 350, 450, 420, 330, 'Shampagne Baby'],
#  'a million': [400, 410, 350, 450, 11, 330, 'Mannywellz'],
#  'pockets': [400, 410, 350, 450, 420, 11, 'Octopizzo'],
#  'ball till we fall': [400, 410, 350, 450, 25, 330, 'Kida Kudz'],
#  'okay': [9, 410, 350, 450, 420, 330, 'Franglish and  Tyga'],
#  'bazenga': [400, 410, 350, 450, 420, 25, 'Ethic Entertainment'],
#  'where you dey': [400, 31, 350, 450, 420, 330, 'Kokopee, Erigga'],
#  'sorry': [400, 410, 350, 63, 420, 330, 'Balloranking'],
#  'vibration': [14, 410, 1, 33, 44, 13, 'Sarkodie and  VIC MENSA'],
#  'kokonsa': [400, 410, 350, 450, 420, 21, 'Omar Sterling'],
#  'attention': [400, 22, 350, 450, 420, 330, 'PsychoYP'],
#  'hustlers prayer': [84, 410, 350, 450, 420, 330, '25K'],
#  'big brother': [400, 410, 44, 450, 420, 330, 'Blaqbonez'],
#  'rappers': [400, 16, 14, 450, 420, 330, 'Dreylo feat. Dremo'],
#  'missing you': [69, 410, 350, 450, 420, 330, 'Dead Peepol'],
#  'wossu': [30, 410, 350, 450, 420, 330, 'kuuku black'],
#  'uthini': [55, 410, 350, 450, 420, 330, 'Costa Titch'],
#  'nikwa ni shoke': [400, 410, 350, 450, 420, 37, 'Khaligraph Jones'],
#  'yafun yafun': [4, 410, 350, 450, 420, 12, 'Ajebo Hustlers'],
#  'dkm': [76, 410, 350, 450, 420, 23, 'Loti'],
#  'living it up': [400, 410, 350, 48, 420, 330, 'PlaTBoss'],
#  'sinner': [400, 72, 350, 450, 27, 39, "Smallgod, Headie One, O'Kenneth"],
#  'many nites': [400, 410, 350, 10, 420, 330, 'Erigga'],
#  'cassette': [400, 65, 350, 450, 420, 330, 'Nanky'],
#  'level up': [400, 410, 350, 450, 24, 330, 'Kmw'],
#  'three': [400, 36, 350, 450, 420, 330, 'Kweku Lee'],
#  'real ones': [400, 410, 350, 450, 53, 330, 'Breeder LW'],
#  'rapstar': [400, 410, 350, 51, 420, 330, 'POLO G'],
#  'if its on': [400, 85, 350, 450, 420, 330, 'Silverstone Barz'],
#  'mood swings': [400, 410, 350, 41, 420, 330, 'Pop Smoke'],
#  'korope': [77, 410, 350, 450, 420, 330, 'Lil Kesh and  Naira Marley'],
#  'top': [65, 410, 350, 450, 420, 330, 'Danagog'],
#  'bout a million': [400, 410, 350, 26, 420, 330, 'Pop Smoke'],
#  'tycoon': [7, 9, 350, 32, 63, 14, 'Show Dem Camp'],
#  'right now reloaded': [400, 410, 9, 450, 420, 330, 'Gemini Major'],
#  'drive by': [400, 39, 350, 450, 420, 330, 'So$aVelli'],
#  'my brudda': [400, 410, 350, 450, 34, 330, 'Yung Nnelg'],
#  'badder than bad': [12, 410, 350, 450, 420, 330, 'Jbwai'],
#  'squander': [400, 20, 350, 450, 420, 330, 'Falz'],
#  'oulalalah': [400, 24, 350, 450, 420, 330, 'Samba Peuzzi'],
#  'system': [400, 410, 350, 1, 420, 330, 'Dave'],
#  'motley crew': [400, 410, 350, 46, 420, 330, 'Post Malone'],
#  'blessing': [400, 410, 40, 450, 420, 330, 'VIC MENSA'],
#  'shut up': [400, 410, 32, 450, 420, 330, 'Blaqbonez'],
#  'like dat': [400, 44, 350, 450, 420, 330, 'Skillz 8Figure'],
#  '1 sima': [400, 37, 350, 450, 420, 330, 'Pappy Kojo '],
#  'red light green light': [400, 410, 350, 50, 420, 330, 'DaBaby'],
#  'tonongo': [400, 410, 350, 42, 420, 330, 'Lojay'],
#  'african girl bad': [400, 410, 350, 450, 6, 330, 'Zoro'],
#  'django': [400, 410, 350, 450, 20, 330, 'Frenna'],
#  "we're all alone": [400, 410, 350, 43, 420, 330, 'Dave'],
#  'early momo': [400, 410, 30, 11, 420, 330, 'Vector'],
#  'smoke from fire': [400, 410, 350, 450, 50, 330, 'Bas'],
#  'balling': [400, 410, 350, 25, 420, 330, 'PlaTBoss'],
#  'married to the game': [99, 410, 350, 67, 420, 330, 'TenTik'],
#  'winning': [400, 410, 47, 450, 31, 32, 'Kwesi Arthur'],
#  'wavy': [400, 410, 350, 450, 28, 38, 'Khaligraph Jones'],
#  'alakori': [400, 410, 350, 450, 3, 330, 'Falz'],
#  'call me baby': [31, 410, 31, 450, 420, 330, 'Cheque'],
#  'public enemy': [71, 410, 350, 450, 420, 330, 'INFAMOUSIZAK'],
#  'everywhere': [400, 32, 350, 450, 420, 330, 'Straffitti featuring Buju'],
#  'fierce': [400, 410, 350, 450, 420, 28, 'Laycon'],
#  'ego': [400, 410, 350, 34, 420, 330, 'Dremo'],
#  'saneba': [16, 410, 350, 450, 420, 330, 'TiDraps'],
#  '1. confusion': [400, 49, 350, 450, 420, 330, 'M.anifest'],
#  'crown of clay': [22,
#   6,
#   6,
#   8,
#   64,
#   36,
#   'Vector,  Khaligraph Jones and  Dip Doundou Guiss'],
#  'more time': [400, 410, 350, 57, 420, 330, 'Pop Smoke'],
#  'ye x4': [400, 410, 350, 450, 35, 31, 'Blxckie'],
#  'heathrow': [400, 61, 350, 450, 420, 330, "Droxx & Mo'gunz"],
#  '50 miss calls': [79,
#   410,
#   350,
#   450,
#   420,
#   330,
#   'Tony Ross,  JoeBoy and  Layzee Ella'],
#  'lekki epe': [400, 30, 350, 450, 420, 330, 'Maxino feat. Vector'],
#  'la go': [400, 410, 350, 450, 420, 2, 'Kiff No Beat'],
#  'dior': [400, 410, 350, 30, 420, 330, 'Pop Smoke'],
#  'ofr3': [5, 410, 350, 450, 420, 15, '$pacely'],
#  'solace': [400, 410, 350, 450, 42, 330, 'Ajebo Hustlers'],
#  'jiggy bop': [400, 410, 46, 450, 420, 330, 'Alpha P'],
#  'woo baby': [400, 410, 350, 47, 420, 330, 'Pop Smoke'],
#  'city of kings': [400, 410, 11, 450, 420, 330, 'PsychoYP'],
#  'one time': [85, 410, 350, 450, 420, 330, 'Willy Monfret'],
#  'once again dey don dey vex me': [400,
#   410,
#   28,
#   450,
#   420,
#   330,
#   'Ace DJ Xquisite'],
#  'tbdk': [400, 410, 8, 450, 32, 330, 'M.I Abaga'],
#  'knights': [43, 410, 350, 450, 420, 330, 'Darrell Cole'],
#  'action figure': [400, 25, 350, 450, 420, 330, 'Gemini Major and AKA'],
#  'kaku': [36, 410, 350, 450, 420, 330, 'Eleniyan'],
#  'dick appointment': [400, 410, 350, 22, 420, 330, 'Erigga'],
#  'pololo': [3, 410, 350, 450, 420, 330, 'MHD'],
#  'ayo': [73, 410, 350, 450, 420, 330, "Mink's"],
#  'the live report': [400, 410, 26, 450, 420, 330, 'AQ'],
#  'barbxc3xa4dos': [39, 410, 350, 450, 420, 330, 'Shaykeh'],
#  'heartbreaker': [90, 50, 20, 450, 14, 24, 'Blaqbonez'],
#  'survive': [49, 410, 350, 450, 420, 330, 'Jaido P'],
#  'amigo': [400, 410, 350, 450, 55, 330, 'Lous and The Yakuza'],
#  'i be': [400, 12, 350, 450, 420, 330, 'Pappy Kojo featuring Manu Crooks'],
#  'rbg': [400, 410, 350, 450, 420, 22, 'Elzo Jamdong'],
#  'text my ex': [400, 56, 350, 450, 420, 330, 'D-Truce'],
#  '1 of 1': [400, 410, 27, 450, 420, 330, 'Cassper Nyovest'],
#  'jack': [48, 410, 3, 6, 4, 5, 'Nasty C'],
#  'ox': [400, 410, 350, 450, 49, 330, "Gabe 'Nandez"],
#  'we move': [400, 43, 350, 450, 420, 330, 'Stonebwoy'],
#  'w.a.g': [400, 410, 350, 450, 420, 35, 'Rouge'],
#  'ballance': [400, 80, 350, 450, 420, 330, 'Durella'],
#  'eyes but no eyes': [11, 410, 350, 450, 420, 330, 'M3NSA'],
#  'kubo': [400,
#   53,
#   50,
#   450,
#   420,
#   330,
#   'Kwesta featuring K.O, Focalistic and Bassie'],
#  'whorephobia': [82, 410, 350, 450, 420, 330, 'SGaWD'],
#  'on the streets': [400,
#   35,
#   350,
#   450,
#   420,
#   330,
#   'Kweku Smoke featuring Kwesi Arthur'],
#  'first sermon': [100, 75, 350, 450, 13, 30, 'Black Sherif'],
#  'champagne already?': [400, 410, 23, 450, 420, 330, 'LADIPOE'],
#  'vipers': [400, 410, 2, 31, 420, 330, 'Show Dem Camp'],
#  'greatness': [40, 410, 350, 450, 420, 330, 'Femi One'],
#  'stay high': [400, 410, 350, 35, 420, 330, 'Juice WRLD'],
#  'flex and ball': [400, 34, 350, 450, 420, 330, 'PsychoYP'],
#  'pon pon pon': [400, 410, 350, 55, 420, 330, 'Dagrin'],
#  'barima': [53, 410, 350, 450, 420, 330, 'Kwaku DMC'],
#  'intro': [400, 410, 350, 64, 420, 330, 'Sarkodie'],
#  'long way from home': [400, 410, 350, 450, 16, 330, 'PsychoYP'],
#  'many things': [33, 410, 350, 450, 420, 330, 'Ruqiz'],
#  'thoho khulu part 3': [400, 60, 350, 450, 420, 330, 'King Lutendo'],
#  'omo x 100': [45, 71, 350, 450, 420, 8, 'Reminisce'],
#  'rap messiah': [400, 410, 41, 450, 420, 330, 'Ladipoe'],
#  'up': [37, 410, 350, 450, 420, 330, 'Finedope'],
#  'a': [400, 410, 19, 450, 420, 330, 'Jesse Jagz'],
#  'die there': [400, 410, 16, 450, 420, 330, 'Illbliss'],
#  'zaza': [62, 410, 350, 450, 420, 330, 'Brian Simba'],
#  'that year': [400, 410, 37, 450, 420, 330, 'Show Dem Camp'],
#  'all the above': [400, 1, 350, 450, 420, 330, 'Show Dem Camp'],
#  'rise up': [400, 83, 350, 450, 420, 330, '2Baba & Falz'],
#  'what you telling me': [400, 410, 43, 450, 420, 330, 'Zilla Oaks'],
#  'bigger picture': [74, 410, 350, 450, 420, 330, 'Thutmose'],
#  'from dusk till dawn': [400, 410, 4, 450, 420, 330, '25K'],
#  'peace of mind': [34, 410, 350, 450, 420, 330, 'OG Hyper'],
#  'cheki': [400, 410, 350, 450, 62, 330, 'Oznardi'],
#  'play play': [400, 410, 350, 450, 9, 330, 'J Hus'],
#  'africana': [400, 410, 350, 450, 36, 330, 'Silverstone Barz'],
#  'soil': [41, 410, 350, 450, 420, 330, 'Priddy Ugly'],
#  'guala': [400, 11, 350, 450, 420, 330, 'Teezee'],
#  'align': [54, 5, 350, 24, 420, 330, 'Show Dem Camp'],
#  'all i need': [400, 48, 350, 450, 420, 330, 'Yung6ix'],
#  'fais ça bien': [400, 410, 350, 450, 38, 330, 'Damso'],
#  'ama': [98, 410, 350, 450, 420, 330, 'Medikal'],
#  'sore': [400, 14, 5, 450, 19, 40, 'Yaw Tog, Stormzy & Kwesi Arthur'],
#  'dawgi': [400, 40, 350, 450, 420, 330, 'Amerado'],
#  'animalistic': [400, 410, 350, 450, 10, 330, 'Kida Kudz'],
#  'medusa': [400, 410, 350, 450, 41, 330, 'H Magnum'],
#  'good news': [400, 410, 350, 44, 420, 330, 'Pop Smoke'],
#  'i want': [86, 410, 350, 450, 420, 33, 'Chris Kaiga'],
#  'ponmo': [400, 410, 350, 61, 420, 330, 'Mohbad'],
#  'black and white': [400, 410, 33, 450, 5, 330, 'Nasty C'],
#  'law of attraction': [400, 410, 350, 45, 420, 330, 'Dave'],
#  'breathe': [400, 410, 7, 450, 420, 29, 'A-Q'],
#  'waterbody': [400, 62, 350, 450, 420, 330, 'mwami'],
#  'check yourself': [400, 68, 350, 3, 420, 330, 'Kaptain'],
#  'my crew': [96, 73, 350, 450, 420, 330, 'Kiiwii'],
#  'coachella': [95, 410, 49, 18, 23, 9, 'Sarkodie and  Kwesi Arthur'],
#  'late at night': [400, 410, 350, 15, 420, 330, 'Roddy Ricch']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    if k in d:
        keys[x] = d1[d.index(k)]
    if k in e:
        keys[x] = e1[e.index(k)]
    if k in f:
        keys[x] = f1[f.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 334

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
post7 = [x[6] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x] + post6[x])/6 for x in range(0, 334)]

# %%
data = {'song':song,'artist':post7,'apple':post1,'audiomark':post2,'youtube':post3, 'boom': post4, 'spotify': post5, 'deezer': post6, 'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,335)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:50]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv(f'week{w}-hiphop50.csv')
df.to_csv(f'week{w}-hiphop.csv')

# %%
 df2 = pd.read_csv(f'week{w-1}-hiphop50.csv')

# %%
a = list(df2['song'])
a1 = a.copy()
x = 0
for i in a:
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df1['song'])
b1 = b.copy()
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
song = []
for x in b:
    if x in a:
        song.append(a1[a.index(x)])
    else:
        song.append(b1[b.index(x)])

# %%
df1['song'] = song

# %%
a = list(df2['song'])
b = list(df1['song'])
c = list(df2['weeks on chart'])
i = 0
prev = []
weeks = []
for x in b:
    if x in a:
        prev.append(a.index(x) + 1)
        weeks.append(c[i] + 1)
    else:
        prev.append(0)
        weeks.append(1)
    i += 1
df1['Previous week'] = prev
df1['weeks on chart'] = weeks

# %%
df1.to_csv(f'week{w}-hiphop50.csv')
df1.to_csv('C:\\Users\\faree\\Desktop\\music charts\\weekly charts\\weekly\\hiphop50.csv')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\docs\\hiphop50.json')
df1.to_json(f'C:\\Users\\faree\\Desktop\\webboard\\week{w}\\hiphop50.json')

# %%
df1
# Out:
#                                                    song  \
# rank
# 1                          Crown Of Clay (feat. Pheelz)
# 2                                                Tycoon
# 3                                                  Jack
# 4                                             Vibration
# 5                        Coachella (feat. Kwesi Arthur)
# 6                          Heartbreaker (feat. Nasty C)
# 7                                         Second Sermon
# 8                                          Sore (Remix)
# 9                                              Euphoria
# 10                                         First Sermon
# 11                                    Align ft. LadiPoe
# 12                                              Feeling
# 13                                      Best I Ever Had
# 14                                               Sinner
# 15                                Omo X 100 ft. Olamide
# 16     Winning (Official Music Video) (feat. VIC MENSA)
# 17    Y3 Y3 DOM (feat. Skyface SDW, Reggie, Kwaku DM...
# 18                                       Check Yourself
# 19                                               vipers
# 20                                           early momo
# 21                           All My Life (feat. Oxlade)
# 22                              Midf (Money I Dey Find)
# 23                                No Fear (feat. Moliy)
# 24                                      Black And White
# 25                          TBDK (feat. Sinzu & Erigga)
# 26                                  KOLO (feat. Oxlade)
# 27                                Rappers (feat. Dremo)
# 28                                                  Hmm
# 29                                          Yafun Yafun
# 30                                Question For The Gods
# 31                                                 Ofr3
# 32                                         Call Me Baby
# 33                                  married to the game
# 34                                                Ye x4
# 35                                                 wavy
# 36                                          loose guard
# 37               Kubo (feat. Bassie, Focalistic & K.O.)
# 38             Who Be This Guy (feat. FALZ & M.I ABAGA)
# 39              Rise Of The Underdogs 2 ft. Tomi Thomas
# 40                                            Decisions
# 41                                Breathe (feat. Chike)
# 42                              My Crew (feat. Lil5ive)
# 43                                       DKM (Ma Pa Mi)
# 44                                               I Want
# 45                                               system
# 46                                                 Feel
# 47                          Dimension ft. Skepta & Rema
# 48                                            Koleyewon
# 49                                        matriculation
# 50                                       hustler's tale
#
#                                                 artist  Previous week  \
# rank
# 1     Vector,  Khaligraph Jones and  Dip Doundou Guiss              1
# 2                                        Show Dem Camp              5
# 3                                              Nasty C              2
# 4                              Sarkodie and  VIC MENSA              8
# 5                           Sarkodie and  Kwesi Arthur              3
# 6                                            Blaqbonez              4
# 7                                         Black Sherif              6
# 8                      Yaw Tog, Stormzy & Kwesi Arthur             10
# 9                                             PsychoYP              7
# 10                                        Black Sherif              9
# 11                                       Show Dem Camp             20
# 12                                   LADIPOE and  Buju             11
# 13                                             Nasty C             12
# 14                     Smallgod, Headie One, O'Kenneth             24
# 15                                           Reminisce             14
# 16                                        Kwesi Arthur             15
# 17                                            Jay Bahd             17
# 18                                             Kaptain             19
# 19                                       Show Dem Camp              0
# 20                                              Vector              0
# 21                                           M.I Abaga             21
# 22                                                Ycee             23
# 23                                           M.anifest             30
# 24                                             Nasty C             27
# 25                                           M.I Abaga             22
# 26                                         Ice Prince              26
# 27                                  Dreylo feat. Dremo             25
# 28                                             G4 Boyz             32
# 29                                      Ajebo Hustlers             29
# 30                                               M3NSA             28
# 31                                             $pacely             31
# 32                                              Cheque             34
# 33                                              TenTik              0
# 34                                             Blxckie             13
# 35                                    Khaligraph Jones              0
# 36                             Legendary Styles & Falz              0
# 37         Kwesta featuring K.O, Focalistic and Bassie             33
# 38                                             Kheengz             37
# 39                 Show Dem Camp featuring Tomi Thomas             39
# 40                                            Jay Bahd             36
# 41                                                 A-Q             18
# 42                                              Kiiwii             16
# 43                                                Loti             40
# 44                                         Chris Kaiga             42
# 45                                                Dave              0
# 46                                           Mrolaide              44
# 47                                                Jae5             45
# 48                                        Naira Marley             46
# 49                                            PlaTBoss              0
# 50                                            PlaTBoss              0
#
#       weeks on chart
# rank
# 1                  6
# 2                  7
# 3                  7
# 4                  7
# 5                  4
# 6                  7
# 7                  7
# 8                  7
# 9                  7
# 10                 7
# 11                 7
# 12                 7
# 13                 4
# 14                 4
# 15                 4
# 16                 5
# 17                 7
# 18                 4
# 19                 1
# 20                 1
# 21                 4
# 22                 6
# 23                 5
# 24                 3
# 25                 4
# 26                 4
# 27                 4
# 28                 5
# 29                 2
# 30                 5
# 31                 2
# 32                 4
# 33                 1
# 34                 2
# 35                 1
# 36                 1
# 37                 4
# 38                 4
# 39                 5
# 40                 4
# 41                 2
# 42                 3
# 43                 5
# 44                 2
# 45                 1
# 46                 2
# 47                 2
# 48                 2
# 49                 1
# 50                 1

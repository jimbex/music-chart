# %%
import pandas as pd
df1 = pd.read_csv('apple_afrohiphop-week24.csv')
df2 = pd.read_csv('audio_afrohiphop-week24.csv')
df3 = pd.read_csv('youtube_afrohiphop-week24.csv')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    if '(' in i:
        c[x] = i[: i.index('(')]
    c[x] = c[x].strip().lower()
    x += 1

# %%
songs = a + b + c
songs = set(songs)

# %%
songs
# Out:
# {'1 of 1',
#  '1 sima',
#  '1. confusion',
#  '4 you',
#  '40 bars',
#  'a',
#  'about money',
#  'action figure',
#  'african knockout',
#  'all i need',
#  'all my life',
#  'ama',
#  'amadlozi',
#  'asampepe',
#  'attention',
#  'balance',
#  'banga',
#  'batman remix',
#  'best i ever had',
#  'bible n rifle',
#  'big brother',
#  'big toy',
#  'black',
#  'black and white',
#  'blessing ft. vic mensa',
#  'body on me',
#  'bourdillon love',
#  'breathe',
#  'brown',
#  'bruddah',
#  'bruxos',
#  'bugia',
#  'casino',
#  'cassette',
#  'champagne already?',
#  'change',
#  'check yourself',
#  'chris',
#  'city of kings',
#  'class clown',
#  'coachella',
#  'colonization',
#  'condemn',
#  'confusion',
#  'corns',
#  'could have been worse',
#  'crown of clay',
#  'dawgi',
#  'dawn',
#  'deep in da streets',
#  'die there',
#  "don't worry",
#  'drive by',
#  'e go be',
#  'early momo',
#  'ekapa',
#  'emtee - ithemba [c-mix]',
#  'ere beketemaw',
#  'euphoria',
#  'every weekend',
#  'everywhere',
#  'faut pas me d\\xc3\\xa9ranger',
#  'feelin u',
#  'feeling',
#  'fire in the ghetto',
#  'first sermon',
#  'flex and ball',
#  'foreign',
#  'forward',
#  'fresh',
#  'gas',
#  'ghost',
#  'glory',
#  'go down',
#  'goboyi',
#  'guala',
#  'guarded up',
#  'happy day',
#  'heartbreaker',
#  'heathrow',
#  'heavy on the game',
#  'history',
#  'hmm',
#  'hut',
#  'i be',
#  'i be your mate',
#  'i want',
#  'intense',
#  'iprc',
#  'ipromise',
#  'jailer',
#  'jiggy bop',
#  'justice',
#  'ka$h app',
#  'kolo',
#  'kubo',
#  'la hustle remix ft. criss waddle & joey b [the truth album]',
#  'la mine',
#  'lady with a choppa',
#  'laqhasha',
#  'lekki epe',
#  'like dat',
#  'lil n****s',
#  'long way',
#  'loose guard',
#  'loving you',
#  'lovlov',
#  'magun 2.0',
#  'mainland to island',
#  'makaveli',
#  'married to the game',
#  'mask off',
#  'mehia sika',
#  'midf',
#  'molade',
#  'mona lisa',
#  'monster',
#  'mood',
#  'mr talk and do',
#  'musazvituma',
#  'ndovu ni kuu',
#  'network',
#  'nikwa ni shoke',
#  'no fear',
#  'no fugazy',
#  'nomakanjani',
#  'odeshi',
#  'on connait \\xc3\\xa7a',
#  'on fire',
#  'on my job',
#  'on the move',
#  'on the streets',
#  'once again dey don dey vex me',
#  'ops',
#  'oulalalah',
#  'own your throne',
#  'paris',
#  'prada tears/la costa nostra',
#  'problems',
#  'rap messiah',
#  'rappers',
#  'rbg',
#  'right now reloaded',
#  'rock',
#  'roll call',
#  'run the cheque',
#  'safara',
#  'sahwira',
#  'se\\xc3\\xb1orita',
#  'shut up',
#  'sika',
#  'sinner',
#  'skrrr!',
#  'snakes in the crib',
#  'somebody',
#  'sore',
#  'squander',
#  'steve biko',
#  'stfu',
#  'talk',
#  'tbdk',
#  'text my ex',
#  'that year',
#  'the 5 year plan',
#  'the live report',
#  'the target',
#  'the warm up',
#  'this one loud oh!',
#  'thoho khulu part 3',
#  'three',
#  'tiktok girl',
#  'toxic',
#  'trap sequel',
#  'truth',
#  'understanding love',
#  'uomo',
#  'use to this',
#  'w.a.g',
#  'waterbody',
#  'we go better pass yesterday',
#  'we move',
#  'what you telling me',
#  'where you dey',
#  'who be this guy',
#  'winning',
#  'x sarkodie - wavy',
#  'y3 y3 dom',
#  'yarn dust',
#  'ye x 4',
#  'zombie'}

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [500]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(510)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(450)

# %%
x = 0
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    if i in b and len(final[i]) < 5:
        final[i].append(b2[b.index(i)])
    if i in c and len(final[i]) < 5:
        final[i].append(c2[c.index(i)])
    x += 1

# %%
final
# Out:
# {'the resurrection': [212, 510, 262, 'Bugzy Malone', 'Bugzy Malone'],
#  'satisfied': [66, 72, 75, 'Mercy Chinwo', 'Mercy Chinwo'],
#  'the cross: my gaze': [207, 47, 450, 'Mercy Chinwo', 'Mercy Chinwo'],
#  'bad hair': [500, 510, 192, 'Nasty C'],
#  'anloga junction': [500, 125, 450, 'Stonebwoy'],
#  'kapacity': [500, 510, 202, 'Kaptain'],
#  'abba gold': [500, 510, 204, 'ABBA'],
#  'trench baby': [500, 131, 450, 'Lil Zay Osama'],
#  'the lion king: the gift': [214, 510, 450, 'Beyoncé'],
#  'watch the throne': [500, 510, 225, 'Jay-Z'],
#  'twelve a.m': [211, 22, 239, 'EP - Crayon', 'Crayon'],
#  'haram!': [205, 510, 450, 'GoldLink'],
#  'live from nkrumah from vol ii: home run': [500, 158, 450, 'Kwesi Arthur'],
#  'yes and amen': [134, 510, 245, 'Tope Alabi', 'Tope Alabi'],
#  'heavy is the head': [228, 510, 136, 'Stormzy', 'Stormzy'],
#  'in the lonely hour': [241, 510, 450, 'Sam Smith'],
#  'hot pink': [500, 61, 450, 'Doja Cat'],
#  'too faithful': [144, 510, 159, 'Moses Bliss', 'Moses Bliss'],
#  'views': [128, 510, 68, 'Drake', 'Drake'],
#  'dangerous': [500, 510, 276, 'Michael Jackson'],
#  'flu game': [500, 510, 228, 'AJ Tracey'],
#  'ancient dreams in a modern land': [500, 510, 266, 'Marina'],
#  'feed tha streets ll': [92, 510, 450, 'Roddy Ricch'],
#  'east atlanta love letter': [64, 510, 162, '6LACK', '6lack'],
#  'drip or drown 2': [500, 196, 450, 'Gunna'],
#  'good news': [500, 83, 450, 'Megan Thee Stallion'],
#  'superstar': [9, 98, 13, 'Wizkid', 'Wizkid'],
#  'christopher': [500, 510, 220, 'Hulvey'],
#  'opera - the ultimate collection': [500, 510, 327, 'Andrea Bocelli'],
#  'roadtocdk': [500, 182, 450, 'Zlatan'],
#  'man of the woods': [500, 510, 312, 'Justin Timberlake'],
#  "i'll say it for you": [500, 26, 151, 'Dax', 'Dax'],
#  'soulfly': [38, 44, 29, 'Rod Wave', 'Rod Wave'],
#  'culture': [185, 28, 153, 'Migos', 'Migos'],
#  'the mayor of lagos': [151, 151, 95, 'Mayorkun', 'Mayorkun'],
#  'isodotun': [238, 510, 450, 'Sola Allyson'],
#  'adventures of august and hanggliderboy': [500, 510, 177, 'August Ocean'],
#  'amazing grace': [500, 152, 450, 'MEDIKAL'],
#  'the message': [87, 67, 450, 'Minister GUC', 'Minister GUC'],
#  'hood boy dreams': [97, 510, 450, 'EP - Jeriq'],
#  'ok orchestra': [500, 510, 209, 'AJR'],
#  'hunger games 3': [500, 173, 450, 'Rod Wave'],
#  'nobody: the extended playlist': [500, 90, 450, 'DJ Neptune'],
#  'platinum heart': [73, 510, 450, 'Toosii'],
#  'no.6 collaborations project': [500, 510, 69, 'Ed Sheeran'],
#  'justice': [10, 510, 31, 'Justin Bieber', 'Justin Bieber'],
#  'so much fun': [190, 102, 450, 'Young Thug', 'Young Thug'],
#  'let there be light.': [500, 510, 234, 'Hillsong Worship'],
#  'a good time': [60, 38, 137, 'Davido', 'Davido'],
#  'adhd': [500, 510, 48, 'Joyner Lucas'],
#  'beam me up scotty': [47, 510, 450, 'Nicki Minaj'],
#  "ghetto lenny's love songs": [59, 510, 92, 'SAINt JHN', 'SAINt JHN'],
#  "because i love y'all": [500, 197, 450, 'Kevo Muney'],
#  'swimming': [500, 510, 186, 'MAC MILLER'],
#  'my beautiful dark twisted fantasy': [500, 510, 227, 'Kanye West'],
#  'ptsd': [500, 87, 450, 'Rod Wave'],
#  'practice makes perfect': [500, 190, 450, 'SR'],
#  'codename, vol. 2': [500, 510, 193, 'Dremo'],
#  'the human condition': [108, 510, 27, 'Jon Bellion', 'Jon Bellion'],
#  'best of davido': [500, 510, 45, 'DaVido'],
#  'legends never die': [84, 510, 28, 'Juice WRLD', 'Juice Wrld'],
#  'the african gentleman': [500, 187, 450, 'Ric Hassani'],
#  'perfect picture': [500, 206, 450, 'Dremo'],
#  'top': [91,
#   58,
#   450,
#   'YoungBoy Never Broke Again',
#   'YoungBoy Never Broke Again'],
#  'last day of summer': [500, 510, 189, 'Summer Walker'],
#  'zulu man with some power': [105, 510, 57, 'Nasty C', 'Nasty C'],
#  'meet the woo 2': [56, 510, 450, 'Pop Smoke'],
#  'viral infection 1.0': [500, 100, 450, 'Ayanfe Viral'],
#  'herstory': [500, 510, 190, 'Young M.A'],
#  'investments 6': [500, 510, 201, 'Yung Bleu'],
#  'back of my mind': [154, 510, 450, 'H.E.R.'],
#  '?': [183, 510, 50, 'XXXTENTACION', 'XXXTentacion'],
#  'heaven or hell': [140, 191, 450, 'Don Toliver', 'Don Toliver'],
#  'tha carter iv': [500, 510, 224, 'Lil Wayne'],
#  '\\u00ccr\\u00cc': [500, 510, 115, 'Sola Allyson'],
#  'afro pop vol. 1': [86, 18, 319, 'Adekunle Gold', 'Adekunle Gold'],
#  'the greatest showman': [500, 510, 64, 'Various Artists'],
#  'twice as tall': [7, 11, 14, 'Burna Boy', 'Burna Boy'],
#  'late nights: the song': [500, 510, 207, 'Jeremih'],
#  'building bridges': [500, 202, 450, 'Smallgod'],
#  'beyond bulletproof': [500, 208, 450, 'Mozzy'],
#  't r a p s o u l': [194, 109, 450, 'Bryson Tiller', 'Bryson Tiller'],
#  'the highlights': [500, 510, 34, 'The Weeknd'],
#  'herstory in the making': [500, 56, 179, 'Young M.A', 'Young M.A'],
#  'know you': [500, 55, 450, 'Ladipoe'],
#  'there is more': [500, 510, 210, 'Hillsong Worship'],
#  'oxygene': [70, 62, 154, 'EP - Oxlade', 'Oxlade'],
#  'l.i.f.e': [223,
#   510,
#   244,
#   'Leaving an Impact for Eternity (Deluxe Edition) - Burna Boy',
#   'Burna Boy'],
#  'oṣó': [237, 510, 450, 'Brymo'],
#  'deal with it': [500, 73, 450, 'Phyno'],
#  "king's disease": [500, 510, 195, 'Nas'],
#  'chipwrecked': [500, 510, 329, 'Alvin And The Chipmunks'],
#  'at easter': [500, 510, 173, 'Hillsong Worship'],
#  'plastic hearts': [500, 510, 235, 'Miley Cyrus'],
#  'timeless ep': [500, 188, 450, 'Aje'],
#  "a gangsta's pain": [75, 510, 450, 'Moneybagg Yo'],
#  'simisola': [148, 24, 450, 'Simi', 'Simi'],
#  'ignorance is bliss': [177, 510, 275, 'Skepta', 'Skepta'],
#  'soundgod fest vol.1': [500, 37, 450, 'Runtown'],
#  'wunna': [67, 119, 450, 'Gunna', 'Gunna'],
#  'big conspiracy': [27, 510, 18, 'J Hus', 'J Hus'],
#  'three': [500, 40, 450, 'Patoranking'],
#  'free 6lack': [218, 510, 450, '6LACK'],
#  'top memba': [79, 510, 450, 'Kida Kudz'],
#  'nobody is listening': [500, 510, 309, 'ZAYN'],
#  'project baby 2: all grown up': [225, 510, 450, 'Kodak Black'],
#  'astroworld': [49, 510, 22, 'Travis Scott', 'Travis Scott'],
#  'teenage fever': [500, 510, 194, 'Kaash Paige'],
#  'outside': [65, 510, 38, 'Burna Boy', 'Burna Boy'],
#  'good kid, m.a.a.d city': [115, 510, 140, 'Kendrick Lamar', 'Kendrick Lamar'],
#  'top prize': [500, 14, 450, 'ALKALINE'],
#  'bad commando': [500, 49, 270, 'Rema', 'Rema'],
#  'happier than ever': [81, 510, 450, 'Billie Eilish'],
#  'the last rocket': [500, 510, 191, 'Takeoff'],
#  'wanted dread and alive': [500, 510, 324, 'Peter Tosh'],
#  'polaris': [500, 510, 222, 'Aitch'],
#  'drinking under the streetlights': [500, 510, 185, 'Powfu'],
#  'blackstar': [500, 174, 450, 'Kelvyn Boy'],
#  'lv n attn': [1, 20, 4, 'EP - Lojay & Sarz', 'Lojay & Sarz'],
#  'some nights': [500, 510, 251, 'fun.'],
#  'cray cray': [500, 139, 450, 'Crayon'],
#  "lucille's grandson": [500, 180, 450, 'Kevo Muney'],
#  'what have we done': [51, 7, 47, 'EP - Omah Lay', 'Omah Lay'],
#  'die a legend': [117, 510, 248, 'Polo G', 'POLO G'],
#  'over it': [74, 510, 450, 'Summer Walker'],
#  'tha carter v': [158, 510, 450, 'Lil Wayne'],
#  'the pinkprint': [182, 510, 450, 'Nicki Minaj'],
#  'run the world': [500, 510, 315, 'Run The World'],
#  'spontaneous praise, vol. 1': [500, 510, 331, 'Laolu Gbenjo'],
#  'love scars: the 5 stages of emotions': [171,
#   147,
#   450,
#   'Yung Bleu',
#   'Yung Bleu'],
#  'self portrait': [500, 510, 241, 'Sasha Sloan'],
#  'wild west': [55, 42, 17, 'Central Cee', 'Central Cee'],
#  'this is not the tape, sorry for the wait 2': [500, 198, 450, 'Kwesi Arthur'],
#  'afro series': [500, 162, 450, 'Terri'],
#  'crossover: live from music city': [500, 510, 120, 'Travis Greene'],
#  'his glory alone': [500, 510, 215, 'KB'],
#  'mi 2: the movie': [123, 510, 450, 'M.I Abaga'],
#  'rolling papers': [500, 510, 184, 'Wiz Khalifa'],
#  'the gospel of the kingdom': [36, 510, 180, 'Dunsin Oyekan', 'Dunsin Oyekan'],
#  'for you': [500, 209, 450, 'Vedo'],
#  '6locc 6a6y': [500, 103, 450, 'Lil Loaded'],
#  'living in bondage': [500, 510, 183, 'prettyboydo'],
#  'collection one': [122, 510, 450, 'SAINt JHN'],
#  'nobody safe': [500, 106, 450, 'Rich The Kid & YoungBoy Never Broke Again'],
#  'super hits': [500, 510, 298, 'Oriental Brothers International Band'],
#  'baby reaper ep': [500, 510, 267, 'YXNG K.A'],
#  'legendary': [500, 148, 450, 'Tyga'],
#  'not all heroes wear capes': [118, 510, 450, 'Metro Boomin'],
#  'pray 4 love': [135, 59, 450, 'Rod Wave', 'Rod Wave'],
#  'blacc hollywood': [500, 510, 325, 'Wiz Khalifa'],
#  'playboy': [162, 510, 450, 'Tory Lanez'],
#  'the backend child': [500, 126, 450, 'NoCap'],
#  'nf': [500, 510, 101, 'NF'],
#  'maverick city vol. 3 part 1': [155, 510, 450, 'Maverick City Music'],
#  'mi2 the movie': [500, 510, 306, 'M.I'],
#  'bill israel': [500, 510, 328, 'Kodak Black'],
#  'shoot for the stars aim for the moon': [22,
#   510,
#   112,
#   'Pop Smoke',
#   'Pop Smoke'],
#  'scorpion': [102, 510, 106, 'Drake', 'Drake'],
#  'razor': [500, 30, 450, 'Cheque'],
#  'scaled and icy': [500, 510, 71, 'Twenty One Pilots'],
#  'gully': [500, 510, 260, 'Various Artists'],
#  'off the yak': [76, 23, 141, 'Young M.A', 'Young M.A'],
#  'send them to coventry': [176, 510, 74, 'Pa Salieu', 'Pa Salieu'],
#  'make e no cause fight': [500, 510, 156, 'Ajebutter22 and BOJ'],
#  'vhs 2.0': [500, 510, 286, 'X Ambassadors'],
#  'mayor of the streets': [500, 203, 450, 'Rah Swish'],
#  'empress': [500, 177, 450, 'Yemi Alade'],
#  'a living sacrifice': [500, 510, 281, 'Joshua Mike-Bamiloye'],
#  'nothings ever good enough': [500, 510, 80, 'Iann Dior'],
#  '4play': [130, 510, 450, 'EP - Olakira'],
#  'shiesty season - spring deluxe': [500,
#   85,
#   163,
#   'Pooh Shiesty',
#   'Pooh Shiesty'],
#  "just cause y'all waited 2": [26, 9, 110, 'Lil Durk', 'Lil Durk'],
#  'be right back': [77, 510, 450, 'Jorja Smith'],
#  'championships': [175, 510, 450, 'Meek Mill'],
#  'syre': [500, 510, 265, 'Jaden'],
#  'ea$t n we$t': [58, 510, 61, 'EP - Dremo & Jeriq', 'Dremo'],
#  'fast & furious 9: the fast saga': [181, 510, 450, 'Various Artists'],
#  'american teen': [145, 510, 128, 'Khalid', 'Khalid'],
#  'malone': [500, 510, 132, 'Gabzy'],
#  'how to kill a rockstar': [500, 510, 218, 'MASN'],
#  "the life of pi'erre 5": [46, 510, 97, "Pi\\'erre Bourne", "Pi'erre Bourne"],
#  'stuck ina vault': [500, 510, 307, 'Shaybo'],
#  'teezastar': [500, 510, 254, 'T Flamez'],
#  'common sense': [112, 510, 293, 'J Hus', 'J Hus'],
#  'chilombo': [110, 510, 450, 'Jhené Aiko'],
#  'still taking risks': [500, 144, 450, 'Quando Rondo'],
#  'before the chaos-ep': [500, 510, 30, 'Erigga'],
#  'a better time': [13, 41, 25, 'Davido', 'Davido'],
#  'zombie': [500, 510, 230, 'Fela Kuti'],
#  'a love letter to you 4': [500, 510, 304, 'Trippie Redd'],
#  'signed to the streets 2.5': [500, 150, 450, 'Lil Durk'],
#  'asa': [124, 510, 96, 'Asa', 'A\\u1e63a'],
#  'black panther the song music from and inspired by': [500,
#   510,
#   94,
#   'Kendrick Lamar'],
#  'glory sound prep': [500, 510, 107, 'Jon Bellion'],
#  'the of': [5, 510, 450, 'eason - J. Cole'],
#  'knock madness': [500, 510, 295, 'Hopsin'],
#  'the leaktape': [202, 510, 450, 'EP - Peruzzi'],
#  'black history project': [500, 510, 119, 'The Spirituals'],
#  'father of 4': [120, 510, 219, 'Offset', 'Offset'],
#  'the marshall mathers lp2': [500, 510, 146, 'Eminem'],
#  'the voice': [35, 510, 111, 'Lil Durk', 'Lil Durk'],
#  'blame it on baby': [500, 510, 322, 'DaBaby'],
#  'apollo': [30, 1, 55, 'Fireboy DML', 'Fireboy DML'],
#  'tattletales': [500, 51, 450, '6ix9ine'],
#  'sol': [500, 510, 143, '\\u00bfT\\u00e9o?'],
#  'shockwave': [232, 178, 16, 'Marshmello', 'Marshmello'],
#  'scam': [109, 510, 41, 'EP - G4 Boyz', 'G4 Boyz'],
#  'laughter, tears & goosebumps': [50, 10, 158, 'Fireboy DML', 'Fireboy DML'],
#  'love diaries of an introvert': [500, 510, 294, 'Tatiana Manaois'],
#  'everything you heard is true': [500, 510, 131, 'Odunsi (The Engine)'],
#  'rum & boogie': [37, 54, 229, 'Peruzzi', 'Peruzzi'],
#  'wasteland, baby!': [500, 510, 167, 'Hozier'],
#  'greenleaf soundtrack - season 2': [500, 510, 278, 'Various Artists'],
#  'chrome eccentric ep': [500, 12, 450, 'Zinoleesky'],
#  'mandy & the jungle': [90, 510, 166, 'Santi', 'Cruel Santino'],
#  'the idea of her': [500, 138, 450, 'Ali Gatie'],
#  'seed': [500, 164, 450, 'Gyakie'],
#  'underestimated': [500, 212, 450, 'Jhacari'],
#  'the prodigy': [500, 169, 450, 'Skillibeng'],
#  'light': [150, 15, 450, 'MohBad', 'MohBad'],
#  'therapy session': [500, 510, 197, 'NF'],
#  'pluto x baby pluto': [210,
#   75,
#   450,
#   'Future & Lil Uzi Vert',
#   'Future & Lil Uzi Vert'],
#  'redemption': [200, 510, 450, 'Burna Boy'],
#  'moments in between': [213, 510, 148, 'Ruth B.', 'Ruth B.'],
#  'grandson, vol. 1': [500, 129, 450, 'King Von'],
#  'dreams worth more than money': [500, 510, 100, 'Meek Mill'],
#  '\\u00f7': [500, 510, 37, 'Ed Sheeran'],
#  'spider-man: into the spider-verse': [500, 510, 214, 'Various Artists'],
#  'flavour of africa': [192, 510, 450, 'Flavour'],
#  'breakthrough': [500, 510, 258, 'Various Artists'],
#  'after hours': [125, 510, 125, 'The Weeknd', 'The Weeknd'],
#  'thank you for believing': [126, 510, 305, 'Toosii', 'Toosii'],
#  'music to be murdered by - side b': [500, 510, 81, 'Eminem'],
#  'inside': [500, 510, 203, 'Bo Burnham'],
#  'what happens in lagos': [500, 510, 272, 'Ajebutter22'],
#  'the search': [186, 510, 46, 'NF', 'NF'],
#  'the erigma ii': [500, 510, 91, 'Erigga'],
#  'high off life': [99, 16, 450, 'Future', 'Future'],
#  'euphoria': [500, 510, 90, 'Labrinth'],
#  'happy birthday! 20 birthday songs': [500,
#   510,
#   144,
#   'Happy Occasion Singers'],
#  'deezer sessions': [500, 510, 256, 'Jorja Smith'],
#  'soundman vol. 1': [39, 510, 36, 'StarBoy', 'Starboy'],
#  'no winter without snow': [500, 510, 337, 'Felix Snow'],
#  'free spirit': [116, 510, 291, 'Khalid', 'Khalid'],
#  'artist 2.0': [165,
#   166,
#   450,
#   'A Boogie wit da Hoodie',
#   'A Boogie Wit da Hoodie'],
#  'carpe diem': [34, 3, 79, 'Olamide', 'Olamide'],
#  'hoodie szn': [500, 69, 450, 'A Boogie Wit Da Hoodie'],
#  'mixed emotions': [500, 110, 188, 'Luh Kel', 'Abra Cadabra'],
#  'bobby tarantino ii': [500, 510, 109, 'Logic'],
#  'wondaland': [12, 4, 19, 'Teni', 'Teni'],
#  'boo of the booless': [16, 25, 63, 'Chike', 'Chiké'],
#  'long live love': [500, 510, 247, 'Kirk Franklin'],
#  'back from the edge': [500, 510, 280, 'James Arthur'],
#  'let it shine': [500, 510, 223, 'Various Artists'],
#  'hopeless romantic': [57, 510, 35, 'EP - Tomi Thomas', 'Tomi Thomas'],
#  '1.5 way or no way': [500, 145, 450, 'Yung Mal'],
#  'ojekoo': [500, 510, 187, 'Juls'],
#  'until death call my name': [500, 96, 450, 'YoungBoy Never Broke Again'],
#  'my struggle': [160, 510, 450, 'Unfoonk & Young Stoner Life'],
#  'billionaire sheikh riddim': [500,
#   170,
#   450,
#   'Teejay, Shatta Wale, Beenie Man, Demarco & More'],
#  'the life of pablo': [193, 510, 450, 'Kanye West'],
#  'jesus is king': [201, 510, 165, 'Kanye West', 'Kanye West'],
#  'graduation': [500, 510, 172, 'Kanye West'],
#  'purpose': [230, 510, 168, 'Justin Bieber', 'Justin Bieber'],
#  'soyoyo': [500, 510, 145, 'Musiliu Haruna Ishola'],
#  'not one of them': [500, 163, 450, 'Dee Watkins'],
#  'gongo aso': [208, 510, 450, '9ice'],
#  'chulo vibes': [500, 76, 450, 'Timaya'],
#  'clouds': [500, 510, 76, 'NF'],
#  'tropical depression riddim': [500,
#   133,
#   450,
#   'VARIOUS ARTISTE (KRANIUM, TEEJAY, SHATTA WALE, JAHMEIL & MORE)'],
#  'old church basement': [15,
#   510,
#   40,
#   'Elevation Worship & Maverick City Music',
#   'Elevation Worship'],
#  'studying abroad: extended stay': [107, 510, 450, 'Masego'],
#  'eternal atake': [500, 130, 450, 'Lil Uzi Vert'],
#  'black love': [500, 184, 450, 'Sarkodie'],
#  'edna': [500, 510, 169, 'Headie One'],
#  'featuring ty dolla $ign': [500, 510, 231, 'Ty Dolla $ign'],
#  'btr': [500, 510, 289, 'Big Time Rush'],
#  'mainland to island': [500, 181, 450, 'Oladips x Zlatan'],
#  'while the world was burning': [61, 510, 58, 'SAINt JHN', 'SAINt JHN'],
#  'don dada': [500, 211, 450, 'Yungeen Ace'],
#  'kpanlogo': [500, 179, 450, 'Darkovibes'],
#  'haitian boy kodak': [32, 45, 450, 'Kodak Black', 'Kodak Black'],
#  'era i 2002': [500, 510, 259, 'Era'],
#  'love songs 4 the streets 2': [500, 48, 450, 'Lil Durk'],
#  'endless': [500, 510, 226, 'Straffitti'],
#  'ice daddy': [180, 201, 450, 'Gucci Mane', 'Gucci Mane'],
#  'beautiful thugger girls': [83, 510, 450, 'Young Thug'],
#  'king of love': [188, 31, 450, 'Kizz Daniel', 'Kizz Daniel'],
#  'cusp': [500, 510, 178, 'Ameen'],
#  'type beats| rap|afro-pop|rnb|trap/hiphop|trapsoul 2020 instrumentals': [500,
#   134,
#   450,
#   'Ryzy.A Beats'],
#  'culture ii': [133, 510, 108, 'Migos', 'Migos'],
#  "just cause y''all waited": [220, 510, 450, 'Lil Durk'],
#  'forever': [196, 510, 450, 'Popcaan'],
#  'lol': [500, 88, 450, 'Naira Marley'],
#  'high supremacy riddim': [500,
#   160,
#   450,
#   'Various Artiste (Tommy Lee Sparta, Teejay, Jahvinci, Shatta Wale & More)'],
#  'the circus': [500, 510, 326, 'Mick Jenkins'],
#  'alagbe': [215, 89, 450, 'Qdot', 'Qdot'],
#  'future hndrxx presents: the wizrd': [216, 189, 450, 'Future', 'Future'],
#  'pandemic': [4, 510, 5, 'EP - Ruger', 'Ruger'],
#  "when it's all said and done... take time": [71, 510, 88, 'GIVĒON', 'Giveon'],
#  'rema': [227, 510, 450, 'EP - Rema'],
#  'the beauty of becoming': [500, 107, 450, 'Rotimi'],
#  'product of my environment': [62, 510, 56, 'Abra Cadabra', 'Abra Cadabra'],
#  'table for two': [500, 176, 450, 'Korede Bello'],
#  'evolution': [500, 510, 82, 'Joyner Lucas'],
#  'savage mode ii': [114,
#   68,
#   117,
#   '21 Savage & Metro Boomin',
#   '21 Savage & Metro Boomin'],
#  'depressing songs 2020': [500, 510, 292, 'Various Artists'],
#  'the palmwine express': [82, 142, 155, 'Show Dem Camp', 'Show Dem Camp'],
#  'distant relatives': [500, 510, 83, 'Damian Marley'],
#  'indigo': [141, 510, 242, 'Chris Brown', 'Chris Brown'],
#  'slime season': [500, 510, 318, 'Young Thug'],
#  'rema freestyle ep': [500, 94, 102, 'Rema', 'Rema'],
#  'positions': [132, 510, 450, 'Ariana Grande'],
#  'pastor baby': [500, 510, 314, 'Zumzy Brown'],
#  'before the chao': [48, 510, 450, 'P - Erigga'],
#  'lil durk presents: loyal bros': [500, 66, 450, 'Only The Family'],
#  'wildfire': [500, 510, 238, 'prettyboydo'],
#  'big grim reaper': [500, 143, 450, 'Big Scarr'],
#  'street sermons': [500, 510, 84, 'Morray '],
#  "the angel you don't know": [28, 510, 32, 'Amaarae', 'amaarae'],
#  '4 your eyez only': [235, 510, 164, 'J. Cole', 'J. Cole'],
#  'heaven': [500, 510, 297, 'JayMikee'],
#  'anti': [161, 510, 85, 'Rihanna', 'Rihanna'],
#  'northsbest': [500, 510, 323, 'Lil Mosey'],
#  '199x': [163, 510, 98, 'Suté Iwar', 'Sut\\u00e9 Iwar'],
#  'the prince i became': [500, 65, 450, 'Ric Hassani'],
#  'for broken ears': [40, 32, 320, 'Tems', 'Tems'],
#  'the voice of the heroes': [14, 510, 3, 'Lil Baby & Lil Durk', 'Lil Baby'],
#  'freedom': [500, 510, 138, 'Akon'],
#  'sex over love': [6, 52, 9, 'Blaqbonez', 'Blaqbonez'],
#  'all my demons greeting me as a friend': [88, 510, 152, 'AURORA', 'AURORA'],
#  'best of': [500, 510, 236, 'Lucky Dube'],
#  'more life': [146, 510, 450, 'Drake'],
#  'original copy': [500, 186, 450, 'Cuppy'],
#  'yellow': [103, 510, 52, 'Brymo', 'Brymo'],
#  'awake': [500, 510, 114, 'Illenium'],
#  'wins & losses': [149, 510, 450, 'Meek Mill'],
#  'when we all fall asleep, where do we go?': [184,
#   510,
#   59,
#   'Billie Eilish',
#   'Billie Eilish'],
#  'meet the woo': [139, 510, 139, 'Pop Smoke', 'Pop Smoke'],
#  'rodeo': [500, 510, 104, 'Travis Scott'],
#  'grass 2 grace': [500, 510, 171, '2Face Idibia'],
#  '8 letters': [500, 510, 279, "Why Don't We"],
#  'different world': [500, 510, 105, 'Alan Walker'],
#  'cultural praise': [20,
#   33,
#   51,
#   'KCee & Okwesili Eze Group',
#   'Kcee & Okwesili Eze Group'],
#  'zaza vibes': [224, 101, 450, 'L.A.X', 'L.A.X'],
#  'pandemic 2': [500, 165, 450, 'Ruger'],
#  'birds in the trap sing mcknight': [226, 510, 450, 'Travis Scott'],
#  'free x': [500, 510, 255, 'XXXTentacion'],
#  'b4 the storm': [96, 510, 450, 'Internet Money'],
#  'john vuli gate': [500, 214, 450, 'Mapara A Jazz'],
#  'jordi': [8, 510, 2, 'Maroon 5', 'Maroon 5'],
#  'on god ii': [500, 199, 450, 'Big Yavo'],
#  'a beautiful space': [500, 168, 450, 'Grace Weber'],
#  'frontstreet': [500, 510, 261, 'OFB'],
#  'ayo': [42, 510, 44, 'Wizkid', 'Wizkid'],
#  'all the little lights': [500, 510, 211, 'Passenger'],
#  'yp & azanti, vol. 1': [173, 510, 65, 'PsychoYP & Azanti', 'PsychoYP'],
#  'beauty behind the madness': [143, 510, 450, 'The Weeknd'],
#  'high tension': [33, 5, 43, 'Bella Shmurda', 'Bella Shmurda'],
#  'top shotta': [500, 155, 450, 'NLE Choppa'],
#  'casting crowns': [500, 510, 300, 'Casting Crowns'],
#  'starboy': [106, 510, 450, 'The Weeknd'],
#  'imagination & the misfit kid': [500, 510, 199, 'Labrinth'],
#  'strings and bling': [169, 510, 49, 'Nasty C', 'Nasty C'],
#  'culture iii': [119, 510, 6, 'Migos', 'Migos'],
#  'reaper szn': [234, 510, 311, 'YXNG K.A', 'YXNG K.A'],
#  "just cause y'all waited": [500, 53, 450, 'Lil Durk'],
#  'dark lane demo tapes': [104, 510, 134, 'Drake', 'Drake'],
#  'a taste of sugar': [233, 510, 450, 'EP - Sugarbana'],
#  'time': [500, 70, 450, 'Yaw Tog'],
#  "torilyna's secret book": [199, 204, 450, 'EP - Tori Keeche', 'TORI KEECHE'],
#  'realms': [500, 80, 450, 'Wande Coal'],
#  'straff from nigeria': [500, 510, 147, 'Straffitti'],
#  'we': [500, 510, 287, 'Gnash'],
#  'freedom.': [240, 510, 99, 'EP - Justin Bieber', 'Justin Bieber'],
#  'you': [500, 175, 450, 'Ali Gatie'],
#  'boyfriend': [45, 19, 60, 'CKay', 'CKay'],
#  'kut da fan on': [500, 161, 450, 'HOTBOII'],
#  'off the record': [500, 104, 450, 'Reekado Banks'],
#  'drip harder': [500, 510, 116, 'Lil Baby'],
#  'michael bolton: greatest hits': [500, 510, 264, 'Michael Bolton'],
#  '...shall we begin...': [17, 39, 450, 'Laycon', 'Laycon'],
#  'aje': [500, 132, 450, 'Jaywon'],
#  'ypszn2': [500, 510, 296, 'PsychoYP'],
#  'ìrì': [127, 510, 450, 'Sola Allyson'],
#  'the king is coming': [189, 510, 450, 'Nathaniel Bassey'],
#  'mother nature': [172, 510, 450, 'Angelique Kidjo'],
#  'the beautiful & damned': [500, 510, 127, 'G-Eazy'],
#  'recovery': [500, 510, 206, 'Eminem'],
#  'immobilarity': [500, 510, 334, 'Raekwon'],
#  'state of mind': [203, 510, 450, 'Lord B'],
#  "welcome to o'block": [222, 21, 450, 'King Von', 'King Von'],
#  'slime language 2': [29,
#   64,
#   233,
#   'Young Stoner Life, Young Thug & Gunna',
#   'Young Stoner Life, Young Thug & Gunna'],
#  '17': [204, 510, 450, 'XXXTENTACION'],
#  'love goes': [95, 510, 450, 'Sam Smith'],
#  'goodbye & good riddance': [68, 510, 15, 'Juice WRLD', 'Juice Wrld'],
#  'fruit': [500, 510, 332, 'Fruit'],
#  'la maquina': [500, 510, 288, 'Conway the Machine'],
#  'billionaire': [500, 77, 450, 'Teni'],
#  'shottaz 4eva': [500, 35, 450, 'MO3'],
#  'queen': [221, 510, 450, 'Nicki Minaj'],
#  'kedu america': [500, 510, 212, 'Chief Stephen Osita Osadebe'],
#  'top chef gotit': [209, 84, 123, 'Lil Gotit', 'Lil Gotit'],
#  'pink planet': [500, 79, 243, 'Pink Sweat$', 'Pink Sweat$'],
#  'get layd': [53, 50, 53, 'EP - Omah Lay', 'Omah Lay'],
#  'african giant': [24, 510, 11, 'Burna Boy', 'Burna Boy'],
#  'partymobile': [500, 510, 263, 'PARTYNEXTDOOR'],
#  'misunderstood': [500, 183, 450, 'JayDaYoungan'],
#  'taste ep': [500, 200, 450, 'Nandy'],
#  'silver': [500, 510, 316, 'Fourplay'],
#  'ybnl': [500, 510, 124, 'Olamide'],
#  'citizen of the world': [72, 99, 175, 'King Perryy', 'King Perryy'],
#  'homesick': [500, 121, 450, 'Trevor Daniel'],
#  'omo charlie champagne vol1': [500, 36, 450, 'Simi'],
#  'the goat': [63, 91, 149, 'Polo G', 'Polo G'],
#  'labrinth, sia & diplo present... lsd': [500, 510, 249, 'LSD'],
#  'made in lagos': [3, 6, 7, 'Wizkid', 'Wizkid'],
#  'wildboy': [500, 157, 450, 'Calboy'],
#  'fever': [500, 210, 450, 'Megan Thee Stallion'],
#  'strange bird': [500, 510, 330, 'Augie March'],
#  'levon james': [500, 86, 450, 'King Von'],
#  'arojinle': [142, 510, 121, 'Adeyinka Alaseyori', 'Adeyinka Alaseyori'],
#  '38 baby 2': [500, 207, 450, 'YoungBoy Never Broke Again'],
#  'signed to the streets 3': [137, 111, 450, 'Lil Durk', 'Lil Durk'],
#  'gratitude': [138, 17, 450, 'Timaya', 'Timaya'],
#  'only the generals part ii': [500, 167, 450, 'Kevin Gates'],
#  'yabasi': [43, 124, 450, 'Basketmouth', 'Basketmouth'],
#  'true 2 myself': [156, 510, 450, 'Lil Tjay'],
#  'ecstasy': [500, 136, 450, 'Lil Kesh'],
#  'hall of fame': [2, 510, 1, 'Polo G', 'POLO G'],
#  "hollywood's bleeding": [41, 510, 62, 'Post Malone', 'Post Malone'],
#  'perception': [500, 510, 103, 'NF'],
#  'kommunity service': [500, 115, 450, 'YG & Mozzy'],
#  'free dem boyz': [168, 510, 200, '42 Dugg', '42 Dugg'],
#  '6pc hot ep': [500, 510, 208, '6lack'],
#  'ghetto gospel': [500, 43, 450, 'Rod Wave'],
#  'pregame rituals': [500, 510, 310, '2KBABY'],
#  'restless ii': [500, 116, 450, 'Simi'],
#  'changes': [239, 510, 135, 'Justin Bieber', 'Justin Bieber'],
#  'heartbreak hotel': [500, 510, 308, 'Phora'],
#  'mirage': [100, 510, 317, 'Mannywellz', 'Mannywellz'],
#  'blackmagic': [500, 510, 333, 'BlackMagic'],
#  'die 4 respect': [500, 510, 118, 'DDG'],
#  'eyan mayweather': [166, 510, 450, 'Olamide'],
#  'spiral: from the book of saw soundtrack': [500, 510, 54, '21 Savage'],
#  'jackboy': [147, 127, 450, 'JACKBOYS & Travis Scott', 'Jackboy'],
#  '2014 forest hills drive': [89, 510, 217, 'J. Cole', 'J. Cole'],
#  's.c.a.m': [500, 93, 450, 'G4 Boyz'],
#  'the off-season': [500, 510, 10, 'J. Cole'],
#  'rema compilation': [500, 8, 213, 'Rema', 'Rema'],
#  'my turn': [54, 510, 130, 'Lil Baby', 'Lil Baby'],
#  'psychodrama': [113, 510, 39, 'Dave', 'Dave'],
#  'i decided.': [500, 510, 216, 'Big Sean'],
#  'ultimate collection': [219, 510, 450, 'Don Moen'],
#  'something else': [500, 71, 450, 'Mr Eazi'],
#  'rora': [500, 154, 450, 'Reekado Banks'],
#  'sour': [21, 510, 23, 'Olivia Rodrigo', 'Olivia Rodrigo'],
#  'the prodigal': [500, 156, 450, 'Mr. P'],
#  'jubilee: juneteenth edition': [191, 510, 450, 'Maverick City Music'],
#  'best of 50 cent': [500, 510, 240, '50 Cent'],
#  'l.o.v.e.': [500, 118, 450, 'Luh Kel'],
#  'leave some day': [500, 195, 450, 'Kevo Muney'],
#  'shiesty season': [195,
#   34,
#   450,
#   'Spring Deluxe - Pooh Shiesty',
#   'Pooh Shiesty'],
#  'wind of glory': [500, 510, 196, 'Sis. Chinyere Udoma'],
#  'x': [197, 510, 450, 'Ed Sheeran'],
#  "love yourself \\u7d50 'answer'": [500, 510, 285, 'BTS'],
#  'cincoriginals': [500, 510, 129, 'Tobe Nwigwe'],
#  'happy birthday kodak': [25, 137, 24, 'EP - Kodak Black', 'Kodak Black'],
#  'stoney': [231, 510, 336, 'Post Malone', 'Post Malone'],
#  'nicotine': [500, 113, 450, 'Trevor Daniel'],
#  'my dear melancholy,': [206, 510, 450, 'The Weeknd'],
#  'hymns ancient & modern': [500,
#   510,
#   282,
#   'Sidney Sussex College Choir, Cambridge'],
#  'honorable': [500, 122, 450, 'Hotkid'],
#  'issa song': [500, 510, 290, '21 Savage'],
#  'the very best of don williams': [500, 510, 181, 'Don Williams'],
#  'a.m. paradox': [500, 510, 182, 'Brent Faiyaz'],
#  'please excuse me for being antisocial': [44,
#   57,
#   66,
#   'Roddy Ricch',
#   'Roddy Ricch'],
#  'uy scuti': [152, 172, 86, 'Olamide', 'Olamide'],
#  'new era': [500, 29, 450, 'Kiss Daniel'],
#  'the spirit of light': [178, 510, 450, 'Tope Alabi & Ty Bello'],
#  'greatest lord': [500, 114, 450, 'SINACH'],
#  'gospel worship 2021': [500, 510, 274, 'Various Artists'],
#  '23 is back': [500, 60, 450, 'JayDaYoungan'],
#  '20 songs of inspiration': [500, 510, 273, 'Jim Reeves'],
#  'roots': [18, 128, 33, 'The Cavemen.', 'NSG'],
#  'i love girls with trobul': [129, 95, 198, 'Sarz & WurlD', 'Sarz X WurlD'],
#  'mr. boombastic': [500, 146, 450, 'Blaqbonez'],
#  'a boy from tandale': [500, 141, 450, 'Diamond Platnumz'],
#  'death race for love': [78, 510, 20, 'Juice WRLD', 'Juice Wrld'],
#  'built for whatever': [500, 159, 450, 'Tee Grizzley'],
#  'professional rapper': [500, 510, 246, 'Lil Dicky'],
#  'dying to live': [111, 510, 450, 'Kodak Black'],
#  'damn.': [131, 510, 67, 'Kendrick Lamar', 'Kendrick Lamar'],
#  'this is acting': [170, 510, 450, 'Sia'],
#  'we all shine': [500, 153, 450, 'YNW Melly'],
#  '!': [500, 185, 450, 'Trippie Redd'],
#  'love & light': [500, 27, 450, 'Joeboy'],
#  'jackboys': [500, 510, 269, 'JACKBOYS'],
#  'wish me well 3': [500, 194, 450, 'YFN Lucci'],
#  'nothing was the same': [174, 510, 450, 'Drake'],
#  '100': [500, 510, 271, 'KB'],
#  'okwu nwoke': [500, 510, 221, 'Beepee D Rapgod'],
#  'live at the royal albert hall': [500, 510, 321, 'Snarky Puppy'],
#  'anthems & glory': [94, 510, 21, 'Todd Dulaney', 'Todd Dulaney'],
#  'afrodisíaco': [500, 140, 450, 'Rauw Alejandro'],
#  'man of galilee': [23, 13, 72, 'Judikay', 'Judikay'],
#  'dum and dummer 2': [500, 108, 450, 'Young Dolph & Key Glock'],
#  "just cause y''all waited 2": [500, 46, 450, 'Lil Durk'],
#  'hallelujah again': [52, 510, 133, 'Nathaniel Bassey', 'Nathaniel Bassey'],
#  'somewhere between beauty & magic': [11, 2, 8, 'Joeboy', 'Joeboy'],
#  'ctrl': [179, 510, 450, 'SZA'],
#  'fuji the sound': [164, 510, 284, 'EP - K1 De Ultimate', 'K1 De Ultimate'],
#  'beerbongs & bentleys': [121, 510, 450, 'Post Malone'],
#  'el dorado': [500, 510, 77, '24kgoldn'],
#  'khaled khaled': [19, 510, 12, 'DJ Khaled', 'DJ Khaled'],
#  'legend - the best of bob marley and the wailers': [500,
#   510,
#   176,
#   'Bob Marley & The Wailers'],
#  'glory in his presence': [500, 510, 122, 'Benjamin Dube'],
#  'divinely uninspired to a hellish extent': [93, 510, 450, 'Lewis Capaldi'],
#  'no love lost': [159, 510, 450, 'Blxst'],
#  'bed of stone': [500, 510, 301, 'A\\u1e63a'],
#  'f*ck love': [236, 510, 150, 'The Kid LAROI', 'The Kid Laroi'],
#  'ready to die': [500, 510, 253, 'The Notorious B.I.G.'],
#  'soundgod fest reloaded': [98, 74, 450, 'Runtown', 'Runtown'],
#  'loyalty over royalty': [500, 135, 450, 'CJ'],
#  'the course of the inevitable': [500, 510, 277, 'Lloyd Banks'],
#  'summertime shootout 3: coldest summer ever': [500, 510, 303, 'Fabolous'],
#  'revenge is sweet': [500, 510, 93, 'Krept & Konan'],
#  'take care': [167, 510, 450, 'Drake'],
#  'chronicles of corizo': [500, 510, 42, 'Corizo'],
#  'destined 2 win': [85, 510, 26, 'Lil Tjay', 'Lil Tjay'],
#  'solid focus riddim': [500, 117, 450, 'Popcaan, Zamunda, Furnace'],
#  'only if you knew': [500, 510, 335, 'Prezzy Krane'],
#  'too late too lit': [31, 105, 142, 'KDDO', 'KDDO'],
#  'no bad songz': [500, 510, 70, 'Kizz Daniel'],
#  'sounds from the other side': [69, 510, 78, 'Wizkid', 'Wizkid'],
#  'resurrection': [157, 510, 450, 'Hugo P'],
#  '÷': [198, 510, 450, 'Ed Sheeran'],
#  '7': [500, 78, 450, 'Lil Nas X'],
#  'snakes & ladders': [500, 510, 299, 'Chip'],
#  'i am > i was': [217, 510, 161, '21 Savage', '21 Savage'],
#  'runaway': [500, 510, 257, 'Passenger'],
#  'soul searching': [500, 510, 268, 'Bazzi'],
#  'illegal remixes vol 1: love, lies & luxury': [500, 171, 450, 'GoodyBoy'],
#  'survivors guilt: the mixtape//': [500, 510, 313, 'KennyHoopla'],
#  'gold': [229, 510, 450, 'Adekunle Gold'],
#  'still sleep?': [500, 510, 73, 'Sleepy Hallow'],
#  'ayra starr': [80, 510, 252, 'EP - Ayra Starr', 'Ayra Starr'],
#  'orange print': [500, 192, 174, 'Larry June', 'Larry June'],
#  'regulate... g funk era part ii the ep': [500, 510, 237, 'Warren G'],
#  'fulfilment': [500, 510, 283, 'Yinka Ayefele'],
#  'gravity': [500, 510, 170, 'Lecrae'],
#  'hakuna matata': [500, 63, 450, 'Dotman'],
#  'trap symphony ep': [500, 81, 450, 'Roddy Ricch'],
#  'music': [500, 510, 126, 'Sia']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 554

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x]/3) for x in range(0, 554)]

# %%
data = {'song':song,'artist':post4,'apple':post1,'audiomark':post2,'deezer':post3,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,555)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:100]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv('week24-song100.csv')
df.to_csv('week24.csv')

# %%
df
# Out:
#                                  song             artist  apple  audiomark  \
# rank
# 1                        Made In Lagos             Wizkid      3          6
# 2     Somewhere Between Beauty & Magic             Joeboy     11          2
# 3                            LV N ATTN  EP - Lojay & Sarz      1         20
# 4                            WONDALAND               Teni     12          4
# 5                        Twice As Tall          Burna Boy      7         11
# ...                                ...                ...    ...        ...
# 550                              Fruit              Fruit    500        510
# 551           Blackmagic (Version 1.0)         BlackMagic    500        510
# 552                       Immobilarity            Raekwon    500        510
# 553                   Only If You Knew       Prezzy Krane    500        510
# 554             No Winter Without Snow         Felix Snow    500        510
#
#       deezer           RT
# rank
# 1          7    11.333333
# 2          8    15.666667
# 3          4    22.333333
# 4         19    22.333333
# 5         14    22.666667
# ...      ...          ...
# 550      332  1120.666667
# 551      333  1121.000000
# 552      334  1121.333333
# 553      335  1121.666667
# 554      337  1122.333333
#
# [554 rows x 6 columns]

# %%
import pandas as pd
from datetime import datetime
m = datetime.today().strftime('%B')
d = datetime.today().strftime('%d')
w = datetime.today().strftime('%V')
w = int(w)
d = int(d)

# %%
df1 = pd.read_csv(f'apple_afrobeats-week{w}.csv', encoding='utf-8')
df2 = pd.read_csv(f'audio_afrobeat-week{w}.csv', encoding='utf-8')
df3 = pd.read_csv(f'youtube_afrobeats-week{w}.csv', encoding='utf-8')
df4 = pd.read_csv(f'boom_afrobeat-week{w}.csv', encoding='utf-8')
df5 = pd.read_csv(f'spotify_afrobeats-week{w}.csv', encoding='utf-8')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]
df4 = df4[['song', 'artist']]
df5 = df5[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    i = i.lower()
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        a[x] = a[x].replace('feat', '(feat')
    if 'remix' in i:
        a[x] = a[x].replace('remix', '(remix')
    if '  ' in i:
        a[x] = a[x].replace('  ', ' ')
    if '(' in a[x]:
        a[x] = a[x][: a[x].index('(')]
    if '\\' in i:
        a[x] = a[x].replace('\\', '') 
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    i = i.lower()
    if 'remix' in i:
        b[x] = i.replace('remix', '(remix')
    if 'ft' in i:
        b[x] = b[x].replace('ft', '(ft')
    if 'feat' in i:
        b[x] = b[x].replace('feat', '(feat')
    if '  ' in i:
        b[x] = b[x].replace('  ', ' ')
    if '(' in b[x]:
        b[x] = b[x][: b[x].index('(')]
    if '\\' in i:
        b[x] = b[x].replace('\\', '') 
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    i = i.lower()
    if 'ft' in i:
        c[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        c[x] = c[x].replace('feat', '(feat')
    if 'remix' in i:
        c[x] = c[x].replace('remix', '(remix')
    if '  ' in i:
        c[x] = c[x].replace('  ', ' ')
    if '(' in c[x]:
        c[x] = c[x][: c[x].index('(')]
    if '\\' in i:
        c[x] = c[x].replace('\\', '')  
    c[x] = c[x].strip().lower()
    x += 1

# %%
d = list(df4['song'])
d1 = d.copy()
d2 = list(df4['artist'])
x = 0
for i in d:
    i = i.lower()
    if 'ft' in i:
        d[x] = i.replace('ft', '(ft') + ')'
    if 'feat' in i:
        d[x] = d[x].replace('feat', '(feat')
    if 'remix' in i:
        d[x] = d[x].replace('remix', '(remix')
    if '  ' in d[x]:
        d[x] = d[x].replace('  ', ' ')
    x += 1
x = 0
for i in d:
    if '(' in i:
        d[x] = i[: i.index('(')]
    if '\\' in i:
        d[x] = d[x].replace('\\', '') 
    d[x] = d[x].strip().lower()
    x += 1

# %%
e = list(df5['song'])
e1 = e.copy()
e2 = list(df5['artist'])
x = 0
for i in e:
    i = i.lower()
    if 'ft' in i:
        e[x] = e[x].replace('ft', '(ft')
    if 'feat' in i:
        e[x] = e[x].replace('feat', '(feat')
    if 'remix' in i:
        e[x] = e[x].replace('remix', '(remix')
    if '  ' in i:
        e[x] = e[x].replace('  ', ' ')
    if '(' in e[x]:
        e[x] = e[x][: e[x].index('(')]
    if '\\' in i:
        e[x] = e[x].replace('\\', '') 
    e[x] = e[x].strip().lower()
    x += 1

# %%
songs = a + b + c + d + e
songs = set(songs)

# %%
len(songs)
# Out:
# 339

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [300]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(310)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(250)

# %%
x = 0
for i in songs:
    if i in d:
        final[i].append(d.index(i) + 1)
    else:
        final[i].append(350)

# %%
x = 0
for i in songs:
    if i in e:
        final[i].append(e.index(i) + 1)
    else:
        final[i].append(290)

# %%
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    elif i in b and len(final[i]) < 6:
        final[i].append(b2[b.index(i)])
    elif i in c and len(final[i]) < 6:
        final[i].append(c2[c.index(i)])
    elif i in d and len(final[i]) < 6:
        final[i].append(d2[d.index(i)])
    elif i in e and len(final[i]) < 6:
        final[i].append(e2[e.index(i)])

# %%
final
# Out:
# {'i spy': [300, 310, 250, 350, 98, 'Lila Iké'],
#  'world': [300, 60, 250, 350, 290, 'Dangbana Republik, Bella Shmurda'],
#  'sponono': [300, 310, 250, 350, 75, 'Kabza De Small'],
#  'blessing': [300, 310, 250, 350, 149, 'Stonebwoy'],
#  'sere': [20, 32, 250, 350, 290, 'Spinall,  Fireboy DML and  6LACK'],
#  'injure me': [61, 76, 250, 11, 290, 'Teni'],
#  'omo x 100': [300, 45, 250, 350, 290, 'Reminisce'],
#  'confident': [300, 46, 250, 350, 290, 'Savage X Buju'],
#  'away': [300, 74, 250, 350, 7, 'Ayra Starr'],
#  'money man': [51, 310, 250, 350, 290, 'Malcolm Nuna'],
#  'rotate': [300, 310, 250, 19, 290, 'Mr Eazi'],
#  'chargie': [300, 34, 250, 350, 290, 'Reekado Banks, Teejay & Lord Afrixana'],
#  'eli': [300, 310, 250, 350, 97, 'Fireboy DML'],
#  'midnight crush': [86, 310, 250, 350, 290, 'Jeune Lio'],
#  'dream girl': [300, 310, 250, 350, 22, 'Global Remix - Ir Sais'],
#  'mercy': [16, 6, 52, 350, 290, 'Falz'],
#  'lv n attn': [80, 310, 250, 350, 290, 'Lojay and  Sarz'],
#  'soweto blues': [300, 310, 250, 350, 21, 'Juls'],
#  'a million': [300, 310, 250, 350, 105, 'Mannywellz'],
#  'princess cuts': [300, 310, 250, 350, 23, 'Headie One'],
#  'comfortable': [300, 310, 250, 350, 160, 'Preme'],
#  'i no go give up on you': [300, 310, 250, 350, 101, 'Mr Eazi'],
#  'joy': [73, 310, 250, 350, 290, 'BadTheSoundBoy'],
#  'higher': [300, 310, 250, 350, 81, 'Tems'],
#  'so lovely': [300, 310, 250, 350, 121, 'Buju'],
#  'cho cho': [300, 310, 250, 15, 290, 'Zlatan'],
#  'outside': [6, 310, 8, 2, 290, 'Buju'],
#  'cash app': [300, 68, 250, 350, 290, 'Bella Shmurda'],
#  'attention': [300, 310, 250, 350, 54, 'Tiwa Savage'],
#  'pepe': [300, 310, 44, 7, 290, 'Davido'],
#  'peaking': [300, 61, 250, 350, 290, 'Tay Iwar'],
#  'whine it': [300, 310, 250, 350, 95, 'Patoranking'],
#  'ginger me': [300, 310, 250, 350, 20, 'Rema'],
#  'slow down': [22, 310, 21, 350, 13, 'King Promise'],
#  'iyo': [300, 13, 250, 350, 290, 'Diamond Platnumz'],
#  'peace of mind': [300, 310, 250, 350, 51, 'Rema'],
#  'big thug boys': [300, 310, 250, 350, 124, 'AV'],
#  'shopping spree': [13, 310, 250, 350, 290, 'Davido'],
#  'party next door': [46,
#   12,
#   250,
#   350,
#   290,
#   'Dangbana Republik and  Bella Shmurda'],
#  'in those eyes': [300, 52, 250, 350, 290, 'Ogranya'],
#  'blessed': [52, 310, 250, 350, 41, 'Wizkid'],
#  'godly': [300, 73, 20, 350, 9, 'Omah Lay'],
#  'every weekend': [300, 80, 250, 350, 290, 'DJ Tunez & J. Anthoni'],
#  'let dem kno': [300, 310, 16, 350, 290, 'Smallgod'],
#  'd & g': [300, 310, 250, 350, 6, 'DaVido'],
#  'drunk guitar': [300, 310, 250, 350, 110, 'NSG'],
#  'one time': [60, 310, 250, 350, 290, 'Moelogo'],
#  'solace': [14, 310, 250, 350, 290, 'Ajebo Hustlers'],
#  'luva luva': [300, 310, 250, 350, 138, 'Runtown'],
#  'bank on it': [41, 310, 250, 350, 290, 'Burna Boy'],
#  'new york city girl': [300, 310, 250, 350, 147, 'Fireboy DML'],
#  'the best': [78, 78, 37, 350, 290, 'Davido'],
#  'sghubu ses excellent': [300, 310, 250, 350, 155, 'Focalistic'],
#  'bia': [69, 310, 250, 350, 290, 'Phyno'],
#  'this your body': [300, 48, 250, 40, 290, 'Skales and Davido'],
#  'simmer': [300, 310, 250, 350, 111, 'Mahalia'],
#  'know your worth': [300, 310, 250, 350, 44, 'Khalid'],
#  'right here': [300, 56, 250, 350, 290, 'Walshy Fire, Terri, Cloud Beats'],
#  'pinda': [300, 88, 250, 350, 290, 'Nedy Music'],
#  'dance': [300, 94, 250, 350, 290, 'Humblesmith'],
#  'sizophelelaphi': [300, 93, 250, 350, 290, 'Msaki and Oskido'],
#  'wonder mama': [43, 310, 250, 350, 290, 'MHD'],
#  'joro kini joro': [300, 310, 250, 18, 290, 'Wizerd'],
#  'carolina': [71, 310, 250, 350, 290, 'Yung D3mz'],
#  'pami': [300, 310, 250, 350, 16, 'DJ Tunez'],
#  'korope': [77, 310, 250, 350, 290, 'Lil Kesh and  Naira Marley'],
#  'ndombolo': [300, 35, 250, 350, 290, 'Alikiba'],
#  'kilofese': [300, 310, 250, 46, 290, 'Zinoleesky'],
#  'ja ara e': [300, 310, 250, 350, 102, 'Burna Boy'],
#  'squander': [300, 310, 40, 4, 290, 'Niniola'],
#  'better than i imagined [feat. h.e.r. & meshell ndegeocello]': [300,
#   310,
#   250,
#   350,
#   73,
#   'DJ Tunez Remix - Robert Glasper'],
#  'carefully': [300, 310, 250, 350, 92, 'Nana Fofie'],
#  'focus': [300, 66, 250, 350, 290, 'Joeboy'],
#  'trouble': [300, 310, 250, 350, 112, 'DRB Lasgidi, Boj, Fresh L., Tems'],
#  'iphupho': [300, 38, 250, 350, 290, 'Jabzz Dimitri featuring Kuhle'],
#  'all mine': [300, 4, 250, 350, 290, 'Kinsolo'],
#  'professor peller': [25, 9, 250, 350, 290, 'Seyi Vibez'],
#  'free your mind': [300, 25, 250, 350, 290, 'Blaq Jerzee & Jux'],
#  'pray': [18, 310, 250, 350, 290, 'Victony'],
#  'mad at me': [68, 310, 250, 350, 290, 'The Flowolf'],
#  'my daddy': [300, 310, 250, 26, 290, 'Greatman Takit'],
#  'stuntin': [75,
#   310,
#   250,
#   350,
#   290,
#   'Mix Master David,  Verse Simmonds and  Oxlade'],
#  'sika aba fie': [300,
#   67,
#   250,
#   350,
#   290,
#   'Kweku Darlington, Yaw Tog, Kweku Flick'],
#  'dollas and cents': [300, 310, 250, 350, 126, 'TOBi'],
#  'w i l d': [35, 310, 250, 350, 290, 'Lady Donli'],
#  'nu riddim': [300, 310, 250, 350, 88, 'Ycee'],
#  'temptation': [300, 310, 250, 350, 94, 'Tiwa Savage'],
#  'fireboy dml': [300, 310, 6, 350, 290, 'Fireboy DML'],
#  'mad': [300, 310, 250, 350, 35, 'Sarz'],
#  'non living thing': [8, 1, 250, 350, 290, 'Sarkodie'],
#  'lenu': [300, 310, 250, 350, 55, 'Remix - Buju'],
#  'rock': [11, 11, 10, 350, 290, 'Olamide'],
#  'nnobody': [300, 310, 250, 350, 122, 'Nnabu'],
#  'whyne': [300, 310, 250, 25, 290, 'Akuchi'],
#  'e be mad': [300, 310, 250, 350, 29, 'Mr Eazi'],
#  'round 2': [300, 8, 250, 350, 290, 'Sarkodie'],
#  'rumour': [300, 310, 250, 350, 61, 'Kaien Cruz'],
#  'understand': [3, 10, 46, 350, 290, 'Omah Lay'],
#  'for you': [300, 70, 25, 29, 30, 'Teni featuring Davido'],
#  'bounce': [23, 310, 5, 24, 162, 'Ruger'],
#  'sugar daddy': [300, 310, 250, 37, 290, 'Dj Enimoney'],
#  '6am': [300, 310, 250, 43, 290, 'Blaq Jerzee'],
#  'pronto': [300, 310, 38, 35, 290, 'Ajebo Hustlers'],
#  'kubo': [300,
#   81,
#   250,
#   350,
#   290,
#   'Kwesta featuring K.O, Focalistic and Bassie'],
#  'jackpot': [300, 310, 250, 47, 290, 'Crayon'],
#  'dimension': [53, 310, 13, 350, 80, 'JAE5'],
#  'pretty girl': [300, 310, 250, 350, 33, 'Adekunle Gold'],
#  'lemonade': [300, 57, 250, 350, 290, 'Ria sean'],
#  'ojoro': [300, 310, 250, 350, 167, 'DJ Neptune'],
#  'no sleeping': [58, 310, 250, 350, 290, '1da Banton'],
#  'jennifer': [300, 21, 250, 350, 290, 'Guchi ft Rayvanny'],
#  'pempe': [300, 310, 250, 17, 290, 'Seyi Shay'],
#  'sokoma': [300, 55, 250, 350, 290, 'Blaq Jerzee, Marioo and Eddy Kenzo'],
#  'focus vibe': [300, 310, 250, 39, 290, 'Slimcase'],
#  'oshofree': [74, 310, 250, 350, 290, 'YKB'],
#  'lento': [300, 310, 250, 350, 74, 'Mr Eazi'],
#  'sinner': [2, 310, 250, 350, 290, 'Adekunle Gold and  Lucky Daye'],
#  'ckay': [300, 310, 28, 350, 290, 'CKay'],
#  'lagos anthem': [300, 310, 250, 34, 290, 'Zlatan'],
#  'real life': [300, 310, 250, 350, 4, 'Burna Boy'],
#  'touch it': [300, 23, 250, 350, 290, 'KiDi'],
#  'antidote': [300, 310, 250, 350, 1, 'Nao'],
#  'brown skin': [300, 53, 250, 350, 290, 'Masterkraft'],
#  'essence': [5, 310, 1, 9, 3, 'Wizkid'],
#  'southy love': [27, 310, 31, 350, 290, 'Peruzzi'],
#  'yaba buluku': [300, 310, 3, 350, 290, 'Dj Tarico'],
#  'domitilla': [300, 310, 250, 350, 164, 'Lisa Yaro'],
#  'koroba': [300, 310, 250, 350, 38, 'Tiwa Savage'],
#  'smooth mf': [300, 310, 250, 350, 49, 'Agho'],
#  'dangerous love': [300, 310, 250, 350, 150, 'Møme Edit - Tiwa Savage'],
#  'surround me': [300, 310, 250, 350, 66, 'Ayotemi'],
#  'the recipe': [300, 310, 250, 350, 93, 'Aluna'],
#  'kabaa': [300, 310, 250, 48, 290, 'Idowest'],
#  "can't let you go": [300, 310, 250, 350, 12, 'Stefflon Don'],
#  'lady': [57, 310, 250, 350, 290, 'Nchinye'],
#  't.y.b': [67, 310, 250, 350, 290, 'Del B,  Phyno and  Mufasa'],
#  'focus dance beat': [300, 49, 250, 350, 290, 'AJIMOVOIX_DRUMS'],
#  'mandy': [300, 310, 250, 350, 5, 'Scribz Riley'],
#  'lo lo': [300, 310, 250, 350, 14, 'Omah Lay'],
#  'unconditionally': [36, 310, 250, 350, 290, 'Ajebutter 22 and  Oxlade'],
#  'karma': [300, 310, 250, 350, 123, 'Cuppy'],
#  'tekiller': [300, 29, 250, 350, 290, 'CDQ'],
#  'under pressure': [300, 310, 250, 350, 168, 'Jay Teazer'],
#  'shege': [56, 310, 250, 350, 290, 'Purple Plutonian'],
#  'my oasis': [300, 310, 250, 350, 151, 'Sam Smith'],
#  'sweet escape': [59, 310, 250, 350, 290, 'Mizzle'],
#  'body': [300, 310, 250, 350, 154, 'Reen'],
#  'fkn around': [300, 310, 250, 350, 120, 'Cuppy Remix - Phony Ppl'],
#  'wishes': [300, 310, 250, 350, 115, 'Juls'],
#  'fine fine': [300, 310, 50, 350, 290, 'Korede Bello'],
#  'bloody samaritan': [17, 3, 53, 350, 144, 'Ayra Starr'],
#  'kilofeshe': [300, 310, 41, 350, 290, 'Zinoleesky'],
#  'wow': [21, 310, 250, 350, 290, 'Marioo'],
#  'badman love': [300, 310, 250, 350, 87, 'Remix - Skales'],
#  'repeat': [300, 310, 250, 350, 106, 'J Hus'],
#  'energy': [300, 310, 250, 350, 163, 'Pa Salieu'],
#  'nirvana': [300, 310, 250, 350, 137, 'Skepta'],
#  'berna reloaded': [300, 310, 55, 350, 290, 'Fally Ipupa'],
#  'gupta': [300, 58, 250, 350, 290, 'Focalistic and Mr JazziQ'],
#  'dis moi comment.': [63, 310, 250, 350, 290, 'Tayc'],
#  'yawa': [300, 310, 250, 350, 169, 'R2Bees'],
#  'smile': [300, 310, 250, 350, 27, 'WizKid'],
#  'everytime': [300, 310, 250, 350, 79, 'Spinall'],
#  'duduke': [300, 92, 250, 350, 290, 'Simi and Deja'],
#  'leggo': [85, 310, 250, 350, 290, 'Serge Ibaka and  Tayc'],
#  'wonderful': [300, 310, 250, 350, 99, 'Burna Boy'],
#  'baby go': [81, 310, 250, 350, 290, 'Otile Brown and  Kizz Daniel'],
#  '4am': [300, 310, 250, 350, 19, 'Manny Norté'],
#  'require': [300, 310, 250, 350, 89, 'DJ Tunez'],
#  'longtime': [300, 310, 250, 350, 28, 'WizKid'],
#  'baby': [300, 50, 250, 350, 290, 'Brainee'],
#  'first sermon': [300, 15, 250, 350, 290, 'Black Sherif'],
#  'petty': [300, 91, 250, 350, 290, 'Olamide'],
#  'off you': [300, 310, 45, 22, 290, 'Young Jonn'],
#  'attitude': [300, 62, 250, 350, 290, 'Harmonize'],
#  'money': [300, 310, 250, 38, 290, 'terri'],
#  'jafafa': [300, 310, 250, 36, 290, 'Chinko Ekun'],
#  'feel good': [48, 310, 250, 350, 290, 'MohBad'],
#  'doudou': [300, 310, 250, 350, 91, 'Aya Nakamura'],
#  'simple instruction': [300, 44, 250, 350, 290, 'Smallgod, R2Bees'],
#  'love somebody': [300, 310, 250, 350, 2, 'Rotimi'],
#  'find your way back': [300, 310, 250, 350, 85, 'Beyoncé'],
#  'boom bam': [300, 310, 250, 350, 56, 'Not3s'],
#  'music messiah': [300, 20, 250, 6, 143, 'DJ Neptune'],
#  'love nobody': [300, 310, 250, 350, 90, 'WurlD'],
#  'feeling': [7, 19, 9, 5, 290, 'LADIPOE and  Buju'],
#  'forever': [300, 310, 47, 350, 290, 'Gyakie'],
#  'guestlist': [300, 310, 250, 350, 65, 'Frenna'],
#  'kolo': [66, 310, 36, 350, 37, 'Ice Prince'],
#  'play play': [300, 310, 250, 350, 70, 'J Hus'],
#  'monalisa': [24, 310, 2, 350, 290, 'Lojay and  Sarz'],
#  'frenemies': [54, 310, 250, 350, 290, 'Rexxie'],
#  'say cheese': [300, 310, 250, 350, 34, 'KiDi'],
#  'enter body': [300, 310, 250, 350, 116, 'DJ Flex'],
#  'oh my': [300, 310, 250, 350, 63, 'Lavaud'],
#  'make up your mind': [300, 310, 250, 350, 125, 'Ice Prince'],
#  'kamata': [300, 31, 250, 350, 290, 'Diamond Platnumz'],
#  'story': [300, 310, 250, 16, 290, 'Greatman Takit'],
#  'marry me': [300, 310, 250, 350, 117, 'Smallgod'],
#  'yote sawa': [300, 24, 250, 350, 290, 'Nandy'],
#  'verified': [79, 310, 250, 27, 290, 'Laycon'],
#  'sweetie odo': [300, 310, 250, 350, 142, 'Juls'],
#  'naira marley': [10, 310, 35, 350, 290, 'Zinoleesky'],
#  'yafun yafun': [42, 310, 250, 350, 290, 'Ajebo Hustlers'],
#  'the don': [300, 310, 250, 350, 45, 'Mr Eazi'],
#  'send me nudes': [70, 310, 250, 350, 290, 'KiDi'],
#  'joro': [300, 310, 250, 350, 77, 'WizKid'],
#  'cassette': [300, 90, 250, 350, 290, 'Nanky'],
#  'don dada': [300, 310, 250, 14, 290, 'Timaya'],
#  'end of the wicked': [300, 310, 250, 350, 161, 'Cruel Santino'],
#  'somebody': [40, 310, 250, 350, 290, 'Olamide'],
#  'dear': [49, 310, 250, 350, 290, 'Big Fizzo and  Jux'],
#  'epo': [300, 310, 250, 350, 119, 'Joe El'],
#  'ayra starr': [300, 310, 49, 350, 290, 'MavinRecords'],
#  'soundgasm': [12, 18, 7, 350, 290, 'Rema'],
#  'midnight boom': [300,
#   310,
#   250,
#   350,
#   130,
#   'with ChocQuibTown & Afro B - Ir Sais'],
#  'ksm': [300, 39, 250, 350, 290, 'Naza'],
#  'infinity': [300, 310, 15, 350, 290, 'Olamide'],
#  'i dont mind': [39, 310, 250, 350, 290, 'Tosin Robeck'],
#  'silver tongue devil': [300, 310, 250, 350, 11, 'Masego'],
#  'enjoy': [300, 310, 17, 350, 290, 'Tekno'],
#  'ginger': [82, 75, 29, 33, 39, 'Wizkid'],
#  'i miss you': [300, 41, 250, 350, 290, 'Joda Kgosi'],
#  'currently': [300, 64, 250, 350, 290, 'Kizz Daniel'],
#  'be honest': [300, 310, 250, 350, 69, 'Jorja Smith'],
#  'champion': [300, 310, 250, 350, 46, 'Fireboy DML'],
#  'beamer': [300, 310, 250, 350, 128, 'Rema'],
#  'baajo': [37, 310, 250, 350, 82, 'Kwesi Arthur and  Joeboy'],
#  'tattoo': [300, 310, 250, 350, 47, 'Fireboy DML'],
#  'enjoyment': [62, 17, 30, 350, 158, 'Yemi Alade'],
#  'ke star': [300, 72, 4, 350, 159, 'Focalistic featuring Vigro Deep'],
#  'olofofo': [300, 310, 250, 20, 290, 'Victor AD'],
#  'cut soap': [300, 22, 250, 350, 290, 'DJ Xclusive and Rulerboy'],
#  'fancy': [44, 310, 250, 350, 290, 'Uche Malik'],
#  'kpk': [300, 47, 43, 8, 290, 'Rexxie and MohBad'],
#  'location': [300, 310, 250, 350, 48, 'Dave'],
#  'akekho': [300, 86, 250, 350, 290, 'Kekelingo'],
#  'risky': [300, 310, 250, 350, 107, 'DaVido'],
#  'testimony': [19, 14, 12, 350, 58, 'Buju'],
#  'walk on the beach': [300, 79, 250, 350, 290, 'Femi Leye'],
#  'coming': [76, 63, 24, 13, 290, 'Naira Marley and  Busiswa'],
#  'angelina': [300, 83, 250, 350, 131, 'Dreamboy'],
#  'all the above': [300, 30, 250, 350, 290, 'Show Dem Camp'],
#  'roju': [300, 82, 250, 350, 290, 'Chiké'],
#  'chop n pray': [300, 310, 250, 350, 104, 'WurlD'],
#  'blessings remix': [300, 310, 250, 350, 15, 'Angel'],
#  'ryde': [300, 310, 250, 350, 57, 'Niniola'],
#  'back to the sender': [300, 85, 250, 350, 290, 'Quamina MP'],
#  'on it': [300, 310, 250, 350, 84, 'Crumz'],
#  'new couple': [300, 40, 250, 350, 290, 'Nandy'],
#  'it is what it is': [47, 310, 34, 350, 290, 'Adekunle Gold'],
#  'sore': [300, 65, 250, 350, 290, 'Yaw Tog, Stormzy & Kwesi Arthur'],
#  "i don't know": [300, 310, 250, 350, 148, 'Nana Rogues'],
#  'do to me': [300, 310, 250, 350, 67, 'H.E.R.'],
#  'in my bed': [300, 310, 250, 350, 26, 'Rotimi'],
#  'the key': [38, 310, 250, 49, 290, 'Tems'],
#  'flavour': [300, 310, 48, 350, 290, 'Flavour'],
#  'beg friend': [300, 310, 250, 350, 157, 'Juls'],
#  'la la': [28, 310, 23, 3, 290, 'Davido'],
#  'black': [30, 5, 250, 350, 290, 'Victor AD'],
#  'fine wine': [65, 43, 250, 350, 290, 'R2Bees'],
#  'last dance': [45, 310, 250, 350, 290, 'A-STAR'],
#  'hallelu': [300, 71, 18, 31, 290, 'Masterkraft'],
#  'roll it': [300, 310, 250, 350, 145, 'Richie Benson'],
#  'gal policy': [300, 310, 250, 350, 32, 'Kranium'],
#  'so crazy': [300, 310, 250, 350, 109, 'DaVido'],
#  'gimme love': [300, 310, 250, 350, 156, 'Remix - Seyi Shay'],
#  'constantly': [300, 310, 250, 42, 290, 'Speroachbeatz'],
#  'no stress': [300, 310, 250, 350, 8, 'WizKid'],
#  'times two': [300, 95, 250, 350, 290, 'WANI'],
#  'holy ground': [300, 310, 250, 350, 100, 'DaVido'],
#  'koleyewon': [300, 310, 250, 32, 290, 'Naira Marley'],
#  'system': [4, 310, 250, 350, 53, 'Dave and  Wizkid'],
#  'it go bad': [300, 310, 250, 350, 60, 'Nnabu'],
#  "god's work": [300, 310, 250, 350, 71, 'IAMDDB'],
#  'already': [300, 310, 250, 350, 31, 'Beyoncé'],
#  'changanya': [300, 89, 250, 350, 290, 'Jay Rox x Jux'],
#  'kilometre': [29, 310, 26, 28, 290, 'Burna Boy'],
#  'vanity': [300, 87, 250, 350, 290, 'MzVee and Kelvyn Boy'],
#  'loco': [300, 310, 42, 44, 290, 'KDDO'],
#  'moslado': [300, 310, 250, 350, 72, 'Teni'],
#  'african girl bad': [300, 310, 250, 350, 76, 'Zoro'],
#  'pamela': [300, 310, 250, 350, 78, 'Wauve'],
#  'far away': [9, 310, 250, 350, 290, 'Dangbana Republik and  Bella Shmurda'],
#  'celebration': [300, 69, 250, 350, 290, 'Joeboy'],
#  'eve bounce': [300, 310, 250, 350, 17, 'Remix - Yung L'],
#  'see through': [300, 310, 250, 350, 50, 'Chip'],
#  'simple things [feat. tory lanez & rema]': [300, 310, 250, 350, 152, 'DJDS'],
#  'somebody baby': [83, 310, 39, 12, 290, 'Davido and  Peruzzi'],
#  'bobo': [300, 310, 250, 350, 62, 'Aya Nakamura'],
#  'peace': [300, 310, 250, 350, 52, 'Mannywellz'],
#  'dkt': [72, 310, 250, 350, 290, 'Oxlade'],
#  'obodo': [300, 310, 250, 50, 290, 'JINNY SAVAGE'],
#  'show me': [32, 77, 11, 23, 290, 'Joeboy'],
#  'bling': [34, 310, 22, 350, 290, 'Blaqbonez'],
#  'peru': [1, 310, 250, 1, 290, 'Fireboy DML'],
#  'too correct': [300, 310, 250, 30, 290, 'Crayon'],
#  'dumebi': [300, 310, 250, 350, 153, 'Rema'],
#  'bad shit': [300, 310, 250, 350, 68, 'Jarreau Vandal'],
#  'look at her': [26,
#   310,
#   250,
#   350,
#   290,
#   'Nqobilxc3xa9,  Nadia Rose and  Dancegod Lloyd'],
#  'peteru': [300, 310, 250, 10, 290, 'Greatman Takit'],
#  'do yourself': [84, 310, 250, 350, 290, 'Angelique Kidjo and  Burna Boy'],
#  'nimekuzoea': [300, 27, 250, 350, 290, 'Nandy'],
#  'jemeni': [300, 51, 250, 350, 290, 'Aymos and Focalistic'],
#  'juju': [300, 310, 250, 350, 127, 'Zubi'],
#  'damn': [300, 310, 250, 350, 10, 'Omah Lay'],
#  'nobody': [300, 310, 250, 350, 146, 'DJ Neptune'],
#  'better thing': [15, 310, 250, 350, 290, 'Joeboy'],
#  'gum body': [300, 310, 250, 350, 43, 'Burna Boy'],
#  '23': [300, 310, 32, 350, 290, 'Burna Boy'],
#  'tonongo': [300, 54, 250, 350, 290, 'Lojay, Sarz'],
#  'anybody': [300, 310, 250, 350, 64, 'Burna Boy'],
#  'oreke': [300, 310, 250, 350, 42, 'E Kelly'],
#  'history': [300, 310, 33, 350, 290, 'Cheque'],
#  'holy ghost fire': [300, 310, 250, 21, 290, 'KDDO'],
#  'praise': [300, 26, 250, 350, 290, 'Fameye'],
#  'hurricane': [300, 59, 250, 350, 290, 'Tomi Thomas'],
#  'y3 y3 dom': [300, 16, 250, 350, 290, 'Jay Bahd'],
#  'solo': [300, 310, 250, 350, 108, 'Shakka'],
#  'who talk': [31, 2, 250, 350, 290, 'Moelogo'],
#  'rappers': [300, 42, 250, 350, 290, 'Dreylo featuring Dremo'],
#  'all': [33, 28, 250, 350, 290, 'Rexxie'],
#  'egbon': [300, 310, 250, 45, 290, 'Masterkraft'],
#  'killa': [300, 310, 250, 350, 36, 'Teyana Taylor'],
#  'gat me singing': [300, 310, 250, 41, 290, 'Luddy Dave'],
#  'lonely': [300, 310, 250, 350, 24, 'Joeboy'],
#  'hold on': [300, 310, 250, 350, 165, 'Oxlade'],
#  'rise up': [50, 7, 250, 350, 290, '2Baba and  Falz'],
#  'sans moi': [64, 310, 250, 350, 290, 'Franglish and  Aya Nakamura'],
#  'dorime': [300, 36, 250, 350, 290, 'Samklef'],
#  'ball till we fall': [300,
#   84,
#   250,
#   350,
#   290,
#   'Kida Kudz featuring Bella Shmurda'],
#  'celebrate me': [300, 33, 27, 350, 290, 'Patoranking'],
#  'wasted energy': [300, 310, 250, 350, 59, 'Remix - Alicia Keys'],
#  'salute': [300, 37, 250, 350, 290, 'Alikiba'],
#  'door': [300, 310, 14, 350, 290, 'Joeboy'],
#  "baby i'm jealous": [300, 310, 250, 350, 18, 'Mr Eazi'],
#  'wicked': [300, 310, 250, 350, 83, 'Juls'],
#  'take me home': [300, 310, 250, 350, 103, 'Lady Donli'],
#  'come over': [300, 310, 250, 350, 25, 'Jorja Smith']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    if k in d:
        keys[x] = d1[d.index(k)]
    if k in e:
        keys[x] = e1[e.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 339

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x])/5 for x in range(0, 339)]

# %%
data = {'song':song,'artist':post6,'apple':post1,'audio':post2,'youtube':post3,'boom':post4,'spotify':post5,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,340)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:50]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv(f'week{w}-afrobeats50.csv')
df.to_csv(f'week{w}-afrobeats.csv')

# %%
df2 = pd.read_csv(f'week{w-1}-afrobeats50.csv')

# %%
a = list(df2['song'])
a1 = a.copy()
x = 0
for i in a:
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df1['song'])
b1 = b.copy()
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
song = []
for x in b:
    if x in a:
        song.append(a1[a.index(x)])
    else:
        song.append(b1[b.index(x)])

# %%
df1['song'] = song

# %%
a = list(df2['song'])
b = list(df1['song'])
c = list(df2['weeks on chart'])
i = 0
prev = []
weeks = []
for x in b:
    if x in a:
        prev.append(a.index(x) + 1)
        weeks.append(c[i] + 1)
    else:
        prev.append(0)
        weeks.append(1)
    i += 1
df1['Previous week'] = prev
df1['weeks on chart'] = weeks

# %%
df1.to_csv(f'week{w}-afrobeats50.csv')
df1.to_csv('C:\\Users\\faree\\Desktop\\music charts\\weekly charts\\weekly\\afrobeats50.csv')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\docs\\afrobeats50.json')
df1.to_json(f'C:\\Users\\faree\\Desktop\\webboard\\week{w}\\afrobeats50.json')

# %%
df1
# Out:
#                                             song  \
# rank
# 1                       Ginger (feat. Burna Boy)
# 2                           Essence (feat. Tems)
# 3                                        Feeling
# 4                                        Show Me
# 5                                      Testimony
# 6                         FOR YOU (feat. Davido)
# 7                                         Coming
# 8                        Bounce (Official Video)
# 9                               Bloody Samaritan
# 10                                       Outside
# 11                                     Enjoyment
# 12           La La (Official Video) (feat. CKay)
# 13                         Rock (Official Video)
# 14                                     Soundgasm
# 15                                     Kilometre
# 16                                     INJURE ME
# 17          KPK (Remix) ft. Sho Madjozi & MohBad
# 18                      Understand (Lyric Video)
# 19        Hallelu (feat. Bella Shmurda & Zlatan)
# 20                        Mercy (Official Audio)
# 21                                     Slow Down
# 22                                 Music Messiah
# 23                                 Somebody Baby
# 24                                         Godly
# 25                           KOLO (feat. Oxlade)
# 26                    Dimension (Official Video)
# 27                     The Best (feat. Mayorkun)
# 28                                          Peru
# 29                    Ke Star (feat. Vigro Deep)
# 30              Non Living Thing (feat. Oxlade)
# 31    Who Talk (feat. Adekunle Gold & Ria Sean)
# 32             Professor  Peller (feat. Zlatan)
# 33                        Black (feat. Mr Eazi)
# 34                                This Your Body
# 35                                       The Key
# 36                                 Sere Remix
# 37                                      Squander
# 38                                    Rise Up
# 39                               Party Next Door
# 40                                          PEPE
# 41           All (Official Audio) (feat. Davido)
# 42                         Verified ft. Mayorkun
# 43                         System (feat. WizKid)
# 44                              Off You ft. KiDi
# 45                           Pronto ft. Omah Lay
# 46                                      Monalisa
# 47                                          AWAY
# 48                             Loco ft. Mayorkun
# 49                                  Naira Marley
# 50       Fine Wine (feat. King Promise & Joeboy)
#
#                                     artist  Previous week  weeks on chart
# rank
# 1                                   Wizkid              1               6
# 2                                   Wizkid              3               6
# 3                        LADIPOE and  Buju              2               6
# 4                                   Joeboy              4               6
# 5                                     Buju              5               6
# 6                    Teni featuring Davido              7               6
# 7                Naira Marley and  Busiswa              6               6
# 8                                    Ruger             11               3
# 9                               Ayra Starr              0               1
# 10                                    Buju              9               6
# 11                              Yemi Alade              8               6
# 12                                  Davido             10               6
# 13                                 Olamide             13               6
# 14                                    Rema             14               4
# 15                               Burna Boy             19               6
# 16                                    Teni             15               6
# 17                       Rexxie and MohBad             16               6
# 18                                Omah Lay             12               6
# 19                             Masterkraft             17               4
# 20                                    Falz              0               1
# 21                            King Promise             18               6
# 22                              DJ Neptune             26               3
# 23                     Davido and  Peruzzi             20               4
# 24                                Omah Lay             21               5
# 25                              Ice Prince             24               6
# 26                                    JAE5             22               5
# 27                                  Davido             25               6
# 28                             Fireboy DML             28               2
# 29         Focalistic featuring Vigro Deep             27               4
# 30                                Sarkodie              0               1
# 31                                 Moelogo              0               1
# 32                              Seyi Vibez              0               1
# 33                               Victor AD              0               1
# 34                       Skales and Davido             29               6
# 35                                    Tems             32               5
# 36        Spinall,  Fireboy DML and  6LACK              0               1
# 37                                 Niniola             23               4
# 38                         2Baba and  Falz             49               6
# 39    Dangbana Republik and  Bella Shmurda             31               6
# 40                                  Davido             35               2
# 41                                  Rexxie             33               4
# 42                                  Laycon             34               5
# 43                        Dave and  Wizkid              0               1
# 44                              Young Jonn             38               5
# 45                          Ajebo Hustlers             39               4
# 46                         Lojay and  Sarz             41               3
# 47                              Ayra Starr             44               4
# 48                                    KDDO             43               5
# 49                              Zinoleesky             46               2
# 50                                  R2Bees             42               2

# %%
import pandas as pd
from datetime import datetime
m = datetime.today().strftime('%B')
d = datetime.today().strftime('%d')
w = datetime.today().strftime('%V')
w = int(w)
d = int(d)

# %%
df1 = pd.read_csv(f'apple_afrobeats-week{w}.csv', encoding='utf-8')
df2 = pd.read_csv(f'audio_afrobeat-week{w}.csv', encoding='utf-8')
df3 = pd.read_csv(f'youtube_afrobeats-week{w}.csv', encoding='utf-8')
df4 = pd.read_csv(f'boom_afrobeat-week{w}.csv', encoding='utf-8')
df5 = pd.read_csv(f'spotify_afrobeats-week{w}.csv', encoding='utf-8')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]
df4 = df4[['song', 'artist']]
df5 = df5[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        a[x] = a[x].replace('feat', '(feat')
    if 'remix' in i:
        a[x] = a[x].replace('remix', '(remix')
    if '  ' in i:
        a[x] = a[x].replace('  ', ' ')
    if '(' in i:
        a[x] = a[x][: i.index('(')]
    if '\\' in i:
        a[x] = a[x].replace('\\', '') 
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        b[x] = b[x].replace('feat', '(feat')
    if 'remix' in i:
        b[x] = b[x].replace('remix', '(remix')
    if '  ' in i:
        b[x] = b[x].replace('  ', ' ')
    if '(' in i:
        b[x] = b[x][: i.index('(')]
    if '\\' in i:
        b[x] = b[x].replace('\\', '') 
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    if 'ft' in i:
        c[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        c[x] = c[x].replace('feat', '(feat')
    if 'remix' in i:
        c[x] = c[x].replace('remix', '(remix')
    if '  ' in i:
        c[x] = c[x].replace('  ', ' ')
    if '(' in i:
        c[x] = c[x][: i.index('(')]
    if '\\' in i:
        c[x] = c[x].replace('\\', '')  
    c[x] = c[x].strip().lower()
    x += 1

# %%
d = list(df4['song'])
d1 = d.copy()
d2 = list(df4['artist'])
x = 0
for i in d:
    if 'ft' in i:
        d[x] = i.replace('ft', '(ft') + ')'
    if 'feat' in i:
        d[x] = d[x].replace('feat', '(feat')
    if 'remix' in i:
        d[x] = d[x].replace('remix', '(remix')
    if '  ' in i:
        d[x] = d[x].replace('  ', ' ')
    x += 1
x = 0
for i in d:
    if '(' in i:
        d[x] = i[: i.index('(')]
    if '\\' in i:
        d[x] = d[x].replace('\\', '') 
    d[x] = d[x].strip().lower()
    x += 1

# %%
e = list(df5['song'])
e1 = e.copy()
e2 = list(df5['artist'])
x = 0
for i in e:
    if 'ft' in i:
        e[x] = e[x].replace('ft', '(ft')
    if 'feat' in i:
        e[x] = e[x].replace('feat', '(feat')
    if 'remix' in i:
        e[x] = e[x].replace('remix', '(remix')
    if '  ' in i:
        e[x] = e[x].replace('  ', ' ')
    if '(' in i:
        e[x] = e[x][: i.index('(')]
    if '\\' in i:
        e[x] = e[x].replace('\\', '') 
    e[x] = e[x].strip().lower()
    x += 1

# %%
songs = a + b + c + d + e
songs = set(songs)

# %%
songs
# Out:
# {'23',
#  '4am',
#  '6am',
#  'a million',
#  'african girl bad',
#  'akekho',
#  'all',
#  'all mine remix',
#  'all the above',
#  'already',
#  'angelina',
#  'antidote',
#  'anybody',
#  'attention',
#  'attitude',
#  'away',
#  'ayra starr',
#  'baajo',
#  'baby',
#  'baby go',
#  "baby i'm jealous",
#  'back to the sender',
#  'bad shit',
#  'badman love',
#  'ball till we fall',
#  'bank on it',
#  'be honest',
#  'beamer',
#  'beg friend',
#  'berna reloaded',
#  'better than i imagined [feat. h.e.r. & meshell ndegeocello]',
#  'better thing',
#  'bia',
#  'big thug boys',
#  'black',
#  'blessed',
#  'blessing',
#  'blessings remix',
#  'bling',
#  'bling (ft. amaarae & buju',
#  'bloody samaritan',
#  'bobo',
#  'body',
#  'boom bam',
#  'bounce',
#  'brown skin',
#  "can't let you go",
#  'carefully',
#  'carolina',
#  'cash app',
#  'cassette',
#  'celebrate me',
#  'celebration',
#  'champion',
#  'changanya',
#  'chargie',
#  'cho cho',
#  'chop n pray',
#  'ckay',
#  'come over',
#  'comfortable',
#  'coming',
#  'confident',
#  'constantly',
#  'currently',
#  'cut soap',
#  'd & g',
#  'damn',
#  'dance',
#  'dangerous love',
#  'dear',
#  'dimension',
#  'dis moi comment.',
#  'dkt',
#  'do to me',
#  'do yourself',
#  'dollas and cents',
#  'domitilla',
#  'don dada',
#  'door',
#  'dorime',
#  'doudou',
#  'dream girl',
#  'drunk guitar',
#  'duduke',
#  'dumebi',
#  'e be mad',
#  'egbon',
#  'eli',
#  'end of the wicked',
#  'energy',
#  'enjoy',
#  'enjoyment',
#  'enter body',
#  'epo',
#  'essence',
#  'eve bounce',
#  'every weekend',
#  'everytime',
#  'fancy',
#  'far away',
#  'feel good',
#  'feeling',
#  'find your way back',
#  'fine fine',
#  'fine wine',
#  'fireboy dml',
#  'first sermon',
#  'fkn around',
#  'flavour',
#  'focus',
#  'focus dance beat',
#  'focus vibe',
#  'for you',
#  'forever',
#  'free your mind',
#  'frenemies',
#  'gal policy',
#  'gat me singing',
#  'gimme love',
#  'ginger',
#  'ginger me',
#  "god's work",
#  'godly',
#  'guestlist',
#  'gum body',
#  'gupta',
#  'hallelu',
#  'higher',
#  'history',
#  'hold on',
#  'holy ghost fire',
#  'holy ground',
#  'hurricane',
#  "i don't know",
#  'i dont mind',
#  'i miss you',
#  'i no go give up on you',
#  'i spy',
#  'in my bed',
#  'in those eyes',
#  'infinity',
#  'injure me',
#  'iphupho',
#  'it go bad',
#  'it is what it is',
#  'iyo',
#  'ja ara e',
#  'jackpot',
#  'jafafa',
#  'jemeni',
#  'jennifer remix',
#  'joro',
#  'joro kini joro',
#  'joy',
#  'juju',
#  'kabaa',
#  'kamata',
#  'karma',
#  'ke star',
#  'killa',
#  'kilofese',
#  'kilofeshe',
#  'kilometre',
#  'know your worth',
#  'koleyewon',
#  'kolo',
#  'koroba',
#  'korope',
#  'kpk',
#  'ksm',
#  'kubo',
#  'la la',
#  'lady',
#  'lagos anthem',
#  'last dance',
#  'leggo',
#  'lemonade',
#  'lento',
#  'lenu',
#  'let dem kno',
#  'lo lo',
#  'location',
#  'loco',
#  'lonely',
#  'longtime',
#  'look at her',
#  'love nobody',
#  'love somebody',
#  'luva luva',
#  'lv n attn (feat. wizkid',
#  'mad',
#  'mad at me',
#  'make up your mind',
#  'mandy',
#  'marry me',
#  'mercy',
#  'midnight boom',
#  'midnight crush',
#  'monalisa',
#  'money',
#  'money man',
#  'moslado',
#  'music messiah',
#  'my daddy',
#  'my oasis',
#  'naira marley',
#  'ndombolo',
#  'new couple',
#  'new york city girl',
#  'nimekuzoea',
#  'nirvana',
#  'nnobody',
#  'no sleeping',
#  'no stress',
#  'nobody',
#  'non living thing',
#  'nu riddim',
#  'obodo',
#  'off you',
#  'oh my',
#  'ojoro',
#  'olofofo',
#  'omo x 100',
#  'on it',
#  'one time',
#  'oreke',
#  'oshofree',
#  'outside',
#  'pamela',
#  'pami',
#  'party next door',
#  'peace',
#  'peace of mind',
#  'peaking',
#  'pempe',
#  'pepe',
#  'peru',
#  'peteru',
#  'petty',
#  'pinda',
#  'play play',
#  'praise',
#  'pray',
#  'pretty girl',
#  'princess cuts',
#  'professor peller',
#  'professor peller (',
#  'pronto',
#  'rappers',
#  'real life',
#  'repeat',
#  'require',
#  'right here',
#  'rise up',
#  'risky',
#  'rock',
#  'roju',
#  'roll it',
#  'rotate',
#  'round 2',
#  'rumour',
#  'ryde',
#  'salute',
#  'sans moi',
#  'say cheese',
#  'see through',
#  'send me nudes',
#  'sere',
#  'sere remix',
#  'sghubu ses excellent',
#  'shege',
#  'shopping spree',
#  'show me',
#  'sika aba fie',
#  'silver tongue devil',
#  'simmer',
#  'simple instruction',
#  'simple things [feat. tory lanez & rema]',
#  'sinner',
#  'sizophelelaphi',
#  'slow down',
#  'smile',
#  'smooth mf',
#  'so crazy',
#  'so lovely',
#  'sokoma',
#  'solace',
#  'solo',
#  'somebody',
#  'somebody baby',
#  'sore',
#  'soundgasm',
#  'southy love',
#  'soweto blues',
#  'sponono',
#  'squander',
#  'story',
#  'stuntin',
#  'sugar daddy',
#  'surround me',
#  'sweet escape',
#  'sweetie odo',
#  'system',
#  't.y.b',
#  'take me home',
#  'tattoo',
#  'tekiller',
#  'temptation',
#  'testimony',
#  'the best',
#  'the don',
#  'the key',
#  'the recipe',
#  'this your body',
#  'times two',
#  'tonongo',
#  'too correct',
#  'touch it',
#  'trouble',
#  'unconditionally',
#  'under pressure',
#  'understand',
#  'vanity',
#  'verified',
#  'w i l d',
#  'walk on the beach',
#  'wasted energy',
#  'whine it',
#  'who talk',
#  'whyne',
#  'wicked',
#  'wishes',
#  'wonder mama',
#  'wonderful',
#  'world',
#  'wow',
#  'y3 y3 dom',
#  'yaba buluku',
#  'yafun yafun',
#  'yawa',
#  'yote sawa'}

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [300]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(310)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(250)

# %%
x = 0
for i in songs:
    if i in d:
        final[i].append(d.index(i) + 1)
    else:
        final[i].append(350)

# %%
x = 0
for i in songs:
    if i in e:
        final[i].append(e.index(i) + 1)
    else:
        final[i].append(290)

# %%
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    elif i in b and len(final[i]) < 6:
        final[i].append(b2[b.index(i)])
    elif i in c and len(final[i]) < 6:
        final[i].append(c2[c.index(i)])
    elif i in d and len(final[i]) < 6:
        final[i].append(d2[d.index(i)])
    elif i in e and len(final[i]) < 6:
        final[i].append(e2[e.index(i)])

# %%
final
# Out:
# {'dimension': [37, 310, 12, 350, 66, 'JAE5'],
#  'pinda': [300, 80, 250, 350, 290, 'Nedy Music'],
#  'fkn around': [300, 310, 250, 350, 90, 'Cuppy Remix - Phony Ppl'],
#  'take me home': [300, 310, 250, 350, 78, 'Lady Donli'],
#  'testimony': [4, 6, 44, 350, 10, 'Buju'],
#  'lenu': [300, 310, 250, 350, 61, 'Remix - Buju'],
#  'far away': [5, 310, 250, 350, 290, 'Dangbana Republik and  Bella Shmurda'],
#  'ke star': [300, 64, 8, 350, 144, 'Focalistic featuring Vigro Deep'],
#  'temptation': [300, 310, 250, 350, 80, 'Tiwa Savage'],
#  'kilofese': [300, 310, 250, 45, 290, 'Zinoleesky'],
#  'salute': [300, 29, 250, 350, 290, 'Alikiba'],
#  'figure 8': [73, 310, 250, 350, 290, 'Kida Kudz and  Gemitaiz'],
#  "can't let you go": [300, 310, 250, 350, 14, 'Stefflon Don'],
#  'southy love': [16, 310, 28, 350, 290, 'Peruzzi'],
#  'e be mad': [300, 310, 250, 350, 38, 'Mr Eazi'],
#  'bobo': [300, 310, 250, 350, 43, 'Aya Nakamura'],
#  'lemonade': [300, 49, 250, 350, 290, 'Ria sean'],
#  'ball till we fall': [300,
#   76,
#   250,
#   350,
#   290,
#   'Kida Kudz featuring Bella Shmurda'],
#  'do to me': [300, 310, 250, 350, 50, 'H.E.R.'],
#  'i no go give up on you': [300, 310, 250, 350, 101, 'Mr Eazi'],
#  'baby': [300, 42, 250, 350, 290, 'Brainee'],
#  'proppa': [300, 310, 250, 350, 121, 'Etana'],
#  'ja ara e': [300, 310, 250, 350, 76, 'Burna Boy'],
#  'princess cuts': [300, 310, 250, 350, 29, 'Headie One'],
#  'rise up': [34, 85, 250, 350, 290, '2Baba and  Falz'],
#  'be honest': [300, 310, 250, 350, 87, 'Jorja Smith'],
#  'loco': [300, 310, 37, 43, 290, 'KDDO'],
#  'comfortable': [300, 310, 250, 350, 131, 'Preme'],
#  '4am': [300, 310, 250, 350, 58, 'Manny Norté'],
#  "god's work": [300, 310, 250, 350, 44, 'IAMDDB'],
#  'cut soap': [300, 14, 250, 350, 290, 'DJ Xclusive and Rulerboy'],
#  'plenty feat. sons of sonix': [300, 310, 250, 350, 145, 'Ambré'],
#  'roll it': [300, 310, 250, 350, 153, 'Richie Benson'],
#  'bounse': [300, 310, 27, 350, 122, 'Rema'],
#  'feel good': [31, 2, 250, 350, 290, 'MohBad'],
#  'kabaa': [300, 310, 250, 47, 290, 'Idowest'],
#  'lento': [300, 310, 250, 350, 57, 'Mr Eazi'],
#  'do yourself': [77, 310, 250, 350, 290, 'Angelique Kidjo and  Burna Boy'],
#  'feeling': [6, 11, 9, 4, 290, 'LADIPOE and  Buju'],
#  'smile': [300, 310, 250, 350, 30, 'WizKid'],
#  'eli': [300, 310, 250, 350, 156, 'Fireboy DML'],
#  'kilofeshe': [79, 310, 33, 350, 290, 'Zinoleesky'],
#  'enjoy': [300, 310, 16, 350, 290, 'Tekno'],
#  'say cheese': [300, 310, 250, 350, 47, 'KiDi'],
#  'slow down': [11, 310, 24, 350, 7, 'King Promise'],
#  'cho cho': [300, 310, 250, 14, 290, 'Zlatan'],
#  'blessing': [300, 310, 250, 350, 160, 'Stonebwoy'],
#  'new couple': [300, 32, 250, 350, 290, 'Nandy'],
#  'all': [20, 20, 250, 350, 290, 'Rexxie'],
#  'make up your mind': [300, 310, 250, 350, 125, 'Ice Prince'],
#  'ginger me': [300, 310, 250, 350, 20, 'Rema'],
#  'don dada': [300, 310, 250, 13, 290, 'Timaya'],
#  'sokoma': [300, 47, 250, 350, 290, 'Blaq Jerzee, Marioo and Eddy Kenzo'],
#  'money': [300, 310, 250, 37, 290, 'terri'],
#  'bling': [22, 310, 54, 350, 290, 'Blaqbonez'],
#  'focus': [300, 58, 250, 350, 290, 'Joeboy'],
#  'gal policy': [300, 310, 250, 350, 40, 'Kranium'],
#  'professor peller': [15, 310, 250, 350, 290, 'Seyi Vibez'],
#  'dorime': [300, 28, 250, 350, 290, 'Samklef'],
#  'sorrow, tears and blood': [300, 310, 250, 350, 155, 'GoldLink'],
#  'ginger': [74, 67, 23, 32, 4, 'Wizkid'],
#  'see through': [300, 310, 250, 350, 53, 'Chip'],
#  'dis moi comment.': [47, 310, 250, 350, 290, 'Tayc'],
#  'koleyewon': [300, 310, 250, 31, 290, 'Naira Marley'],
#  'confident': [300, 38, 250, 350, 290, 'Savage X Buju'],
#  'solace': [12, 310, 250, 350, 290, 'Ajebo Hustlers'],
#  'd & g': [300, 310, 250, 350, 8, 'DaVido'],
#  'peteru': [300, 310, 250, 9, 290, 'Greatman Takit'],
#  'sore': [300, 57, 250, 350, 290, 'Yaw Tog, Stormzy & Kwesi Arthur'],
#  'jackpot': [300, 310, 250, 46, 290, 'Crayon'],
#  'in those eyes': [300, 44, 250, 350, 290, 'Ogranya'],
#  'higher': [300, 310, 250, 350, 62, 'Tems'],
#  'carefully': [300, 310, 250, 350, 79, 'Nana Fofie'],
#  'so long': [70, 310, 250, 350, 290, 'Sjxy'],
#  'focus dance beat': [300, 41, 250, 350, 290, 'AJIMOVOIX_DRUMS'],
#  'play play': [300, 310, 250, 350, 55, 'J Hus'],
#  'love nobody': [300, 310, 250, 350, 86, 'WurlD'],
#  'duduke': [300, 84, 250, 350, 290, 'Simi and Deja'],
#  'la la': [17, 310, 15, 1, 290, 'Davido'],
#  'know your worth': [300, 310, 250, 350, 23, 'Khalid'],
#  'lagos anthem': [300, 310, 250, 33, 290, 'Zlatan'],
#  'curious': [300, 310, 250, 350, 128, 'VanJess'],
#  'nnobody': [300, 310, 250, 350, 149, 'Nnabu'],
#  'peaking': [300, 53, 250, 350, 290, 'Tay Iwar'],
#  "baby i'm jealous": [300, 310, 250, 350, 26, 'Mr Eazi'],
#  'wonder mama': [27, 310, 250, 350, 290, 'MHD'],
#  'doudou': [300, 310, 250, 350, 99, 'Aya Nakamura'],
#  'kamata': [300, 23, 250, 350, 290, 'Diamond Platnumz'],
#  'find your way back': [300, 310, 250, 350, 77, 'Beyoncé'],
#  'olofofo': [300, 310, 250, 19, 290, 'Victor AD'],
#  'petty': [300, 83, 250, 350, 290, 'Olamide'],
#  'pami': [300, 310, 250, 350, 70, 'DJ Tunez'],
#  'it go bad': [300, 310, 250, 350, 48, 'Nnabu'],
#  'anybody': [300, 310, 250, 350, 97, 'Burna Boy'],
#  'better than i imagined [feat. h.e.r. & meshell ndegeocello]': [300,
#   310,
#   250,
#   350,
#   45,
#   'DJ Tunez Remix - Robert Glasper'],
#  'baajo': [68, 310, 250, 350, 130, 'Kwesi Arthur and  Joeboy'],
#  'rappers': [300, 34, 250, 350, 290, 'Dreylo featuring Dremo'],
#  'yaba buluku': [300, 310, 7, 350, 290, 'Dj Tarico'],
#  'dangerous love': [300, 310, 250, 350, 159, 'Møme Edit - Tiwa Savage'],
#  'longtime': [300, 310, 250, 350, 33, 'WizKid'],
#  'walk on the beach': [300, 71, 250, 350, 290, 'Femi Leye'],
#  'silver tongue devil': [300, 310, 250, 350, 17, 'Masego'],
#  'the best': [66, 70, 30, 350, 290, 'Davido'],
#  'currently': [300, 56, 250, 350, 290, 'Kizz Daniel'],
#  'sizophelelaphi': [300, 86, 250, 350, 290, 'Oskido and Msaki'],
#  'story': [300, 310, 250, 15, 290, 'Greatman Takit'],
#  'i miss you': [300, 33, 250, 350, 290, 'Joda Kgosi'],
#  'door': [300, 310, 38, 350, 290, 'Joeboy'],
#  'rock': [7, 3, 11, 350, 290, 'Olamide'],
#  'ndombolo': [300, 27, 250, 350, 290, 'Alikiba'],
#  'dollas and cents': [300, 310, 250, 350, 132, 'TOBi'],
#  'essence': [3, 310, 2, 8, 60, 'Wizkid'],
#  'injure me': [46, 68, 250, 10, 290, 'Teni'],
#  'mad at me': [52, 310, 250, 350, 290, 'The Flowolf'],
#  'hurricane': [300, 51, 250, 350, 290, 'Tomi Thomas'],
#  'verified': [67, 310, 250, 26, 290, 'Laycon'],
#  'blessings remix': [300, 310, 250, 350, 49, 'Angel'],
#  'bling ft. amaarae & buju': [300, 310, 43, 350, 290, 'Blaqbonez'],
#  'jafafa': [300, 310, 250, 35, 290, 'Chinko Ekun'],
#  'frenemies': [38, 310, 250, 350, 290, 'Rexxie'],
#  'enter body': [300, 310, 250, 350, 141, 'DJ Flex'],
#  'yote sawa': [300, 16, 250, 350, 290, 'Nandy'],
#  'dream girl': [300, 310, 250, 350, 56, 'Global Remix - Ir Sais'],
#  'lo lo': [300, 310, 250, 350, 21, 'Omah Lay'],
#  'smooth mf': [300, 310, 250, 350, 85, 'Agho'],
#  'fine wine': [49, 35, 250, 350, 290, 'R2Bees'],
#  'peru': [19, 310, 250, 49, 290, 'Fireboy DML'],
#  'brown skin': [300, 45, 250, 350, 290, 'Masterkraft'],
#  'right here': [300, 48, 250, 350, 290, 'Walshy Fire, Terri, Cloud Beats'],
#  '6am': [300, 310, 250, 42, 290, 'Blaq Jerzee'],
#  'joro kini joro': [300, 310, 250, 17, 290, 'Wizerd'],
#  'egbon': [64, 310, 250, 44, 290, 'Masterkraft and  Phyno'],
#  'all my life': [300, 310, 48, 350, 290, 'M.I Abaga'],
#  'ksm': [300, 31, 250, 350, 290, 'Naza'],
#  'simple instruction': [300, 36, 250, 350, 290, 'Smallgod, R2Bees'],
#  'monalisa': [14, 310, 5, 350, 290, 'Lojay and  Sarz'],
#  'iyo': [300, 5, 250, 350, 290, 'Diamond Platnumz'],
#  'gat me singing': [300, 310, 250, 40, 290, 'Luddy Dave'],
#  'whyne': [300, 310, 250, 24, 290, 'Akuchi'],
#  'nimekuzoea': [300, 19, 250, 350, 290, 'Nandy'],
#  'unconditionally': [24, 310, 250, 350, 290, 'Ajebutter 22 and  Oxlade'],
#  'nu riddim': [300, 310, 250, 350, 74, 'Ycee'],
#  'fancy': [28, 310, 250, 350, 290, 'Uche Malik'],
#  'fiesta': [300, 310, 250, 350, 126, 'Opvibes'],
#  'sinner': [9, 310, 250, 350, 290, 'Adekunle Gold and  Lucky Daye'],
#  'one time': [45, 310, 250, 350, 290, 'Moelogo'],
#  'flavour': [300, 310, 49, 350, 290, 'Flavour'],
#  'oh my gawd': [300, 310, 250, 350, 151, 'Mr Eazi'],
#  'eve bounce': [300, 310, 250, 350, 19, 'Remix - Yung L'],
#  'so lovely': [300, 310, 250, 350, 143, 'Buju'],
#  'it is what it is': [44, 310, 25, 350, 290, 'Adekunle Gold'],
#  'fine fine': [300, 310, 41, 350, 290, 'Korede Bello'],
#  'pempe': [300, 310, 250, 16, 290, 'Seyi Shay'],
#  'ryde': [300, 310, 250, 350, 72, 'Niniola'],
#  'antidote': [300, 310, 250, 350, 1, 'Nao'],
#  'wonderful': [300, 310, 250, 350, 65, 'Burna Boy'],
#  'sleepless nights': [300, 310, 250, 350, 157, 'Trey Songz'],
#  'y3 y3 dom': [300, 8, 250, 350, 290, 'Jay Bahd'],
#  'everytime': [300, 310, 250, 350, 46, 'Spinall'],
#  'forever': [75, 310, 42, 350, 290, 'Gyakie and  Omah Lay'],
#  'going out of my way': [300, 310, 250, 350, 108, 'M.O'],
#  'wicked': [300, 310, 250, 350, 113, 'Juls'],
#  'vanity': [300, 79, 250, 350, 290, 'MzVee and Kelvyn Boy'],
#  'guestlist': [300, 310, 250, 350, 89, 'Frenna'],
#  'tekiller': [300, 21, 250, 350, 290, 'CDQ'],
#  'enjoyment': [32, 9, 50, 350, 127, 'Yemi Alade'],
#  'times two': [300, 88, 250, 350, 290, 'WANI'],
#  'peace of mind': [300, 310, 250, 350, 73, 'Rema'],
#  'system': [2, 310, 250, 350, 109, 'Dave and  Wizkid'],
#  'angelina': [300, 75, 250, 350, 107, 'Dreamboy'],
#  'roju': [300, 74, 250, 350, 290, 'Chiké'],
#  'bounce': [13, 310, 3, 23, 290, 'Ruger'],
#  'pretty girl': [300, 310, 250, 350, 42, 'Adekunle Gold'],
#  'chop n pray': [300, 310, 250, 350, 100, 'WurlD'],
#  'music messiah': [300, 12, 250, 5, 290, 'DJ Neptune'],
#  'oh my': [300, 310, 250, 350, 118, 'Lavaud'],
#  'too correct': [300, 310, 250, 29, 290, 'Crayon'],
#  'somebody baby': [76, 310, 36, 11, 290, 'Davido and  Peruzzi'],
#  'coming': [62, 55, 13, 12, 290, 'Naira Marley and  Busiswa'],
#  'back to the sender': [300, 77, 250, 350, 290, 'Quamina MP'],
#  'baba nla': [78, 310, 250, 350, 290, 'Dr Dolor and  Buju'],
#  'the don': [300, 310, 250, 350, 105, 'Mr Eazi'],
#  'world': [300, 52, 250, 350, 290, 'Dangbana Republik, Bella Shmurda'],
#  'killa': [300, 310, 250, 350, 32, 'Teyana Taylor'],
#  'i dont mind': [25, 310, 250, 350, 290, 'Tosin Robeck'],
#  'juju': [300, 310, 250, 350, 71, 'Zubi'],
#  'godly': [300, 65, 21, 350, 9, 'Omah Lay'],
#  'peace': [300, 310, 250, 350, 63, 'Mannywellz'],
#  'chargie': [300, 26, 250, 350, 290, 'Reekado Banks, Teejay & Lord Afrixana'],
#  'pronto': [300, 310, 34, 34, 290, 'Ajebo Hustlers'],
#  'rotate': [300, 310, 250, 18, 290, 'Mr Eazi'],
#  'soweto blues': [300, 310, 250, 350, 34, 'Juls'],
#  'this your body': [300, 40, 250, 39, 290, 'Skales and Davido'],
#  'damn': [300, 310, 250, 350, 11, 'Omah Lay'],
#  'sans moi': [48, 310, 250, 350, 290, 'Franglish and  Aya Nakamura'],
#  'squander': [300, 310, 31, 3, 147, 'Niniola'],
#  'strong & solid': [300, 310, 250, 350, 152, 'GMK'],
#  'boom bam': [300, 310, 250, 350, 3, 'Not3s'],
#  'history': [300, 310, 32, 350, 290, 'Cheque'],
#  'no sleeping': [42, 310, 250, 350, 290, '1da Banton'],
#  'dumebi': [300, 310, 250, 350, 154, 'Rema'],
#  'shopping spree': [10, 310, 250, 350, 290, 'Davido'],
#  'off you': [300, 310, 45, 21, 290, 'Kidi'],
#  'gupta': [300, 50, 250, 350, 290, 'Focalistic and Mr JazziQ'],
#  'praise': [300, 18, 250, 350, 290, 'Fameye'],
#  'bad shit': [300, 310, 250, 350, 83, 'Jarreau Vandal'],
#  'sika aba fie': [300,
#   59,
#   250,
#   350,
#   290,
#   'Kweku Darlington, Yaw Tog, Kweku Flick'],
#  'wasted energy': [300, 310, 250, 350, 64, 'Remix - Alicia Keys'],
#  'baby go': [72, 310, 250, 350, 290, 'Otile Brown and  Kizz Daniel'],
#  'the recipe': [300, 310, 250, 350, 84, 'Aluna'],
#  'so crazy': [300, 310, 250, 350, 92, 'DaVido'],
#  't.y.b': [51, 310, 250, 350, 290, 'Del B,  Phyno and  Mufasa'],
#  'badman love': [300, 310, 250, 350, 67, 'Remix - Skales'],
#  'ckay': [300, 310, 22, 350, 290, 'CKay'],
#  'focus vibe': [300, 310, 250, 38, 290, 'Slimcase'],
#  'bank on it': [71, 310, 250, 350, 290, 'Burna Boy'],
#  'joy': [58, 310, 250, 350, 290, 'BadTheSoundBoy'],
#  'away': [300, 66, 250, 350, 15, 'Ayra Starr'],
#  'location': [300, 310, 250, 350, 52, 'Dave'],
#  'beamer': [300, 310, 250, 350, 88, 'Rema'],
#  'a million': [300, 310, 250, 350, 69, 'Mannywellz'],
#  'koroba': [300, 310, 250, 350, 27, 'Tiwa Savage'],
#  'my oasis': [300, 310, 250, 350, 150, 'Sam Smith'],
#  'ayra starr': [300, 310, 46, 350, 290, 'MavinRecords'],
#  'dkt': [57, 310, 250, 350, 290, 'Oxlade'],
#  'oreke': [300, 310, 250, 350, 51, 'E Kelly'],
#  'my daddy': [300, 310, 250, 25, 290, 'Greatman Takit'],
#  'free your mind': [83, 17, 250, 350, 290, 'Blaq Jerzee and  Jux'],
#  'shege': [40, 310, 250, 350, 290, 'Purple Plutonian'],
#  'bia': [53, 310, 250, 350, 290, 'Phyno'],
#  'beg friend': [300, 310, 250, 350, 120, 'Juls'],
#  'lv n attn feat. wizkid': [69, 310, 250, 350, 290, 'Lojay and  Sarz'],
#  'real life': [300, 310, 250, 350, 5, 'Burna Boy'],
#  'carry go': [65, 310, 250, 350, 290, 'Schengen Owner'],
#  'high way': [300, 310, 47, 350, 290, 'Dj Kaywise'],
#  'let dem kno': [300, 310, 56, 350, 290, 'Smallgod'],
#  'i spy': [300, 310, 250, 350, 75, 'Lila Iké'],
#  'korope': [63, 310, 250, 350, 290, 'Lil Kesh and  Naira Marley'],
#  'celebration': [300, 61, 250, 350, 290, 'Joeboy'],
#  'nobody': [300, 310, 250, 350, 146, 'DJ Neptune'],
#  'on it': [300, 310, 250, 350, 115, 'Crumz'],
#  'jemeni': [300, 43, 250, 350, 290, 'Aymos and Focalistic'],
#  'celebrate me': [300, 25, 19, 350, 290, 'Patoranking'],
#  'joro': [300, 310, 250, 350, 104, 'WizKid'],
#  'gum body': [300, 310, 250, 350, 18, 'Burna Boy'],
#  'yafun yafun': [26, 310, 250, 350, 290, 'Ajebo Hustlers'],
#  'leggo': [81, 310, 250, 350, 290, 'Serge Ibaka and  Tayc'],
#  'require': [300, 310, 250, 350, 93, 'DJ Tunez'],
#  'kolo': [50, 310, 35, 350, 59, 'Ice Prince'],
#  'laisse ça': [300, 310, 250, 350, 158, 'Lala &ce'],
#  'show me': [18, 69, 10, 22, 290, 'Joeboy'],
#  'the key': [29, 310, 250, 48, 290, 'Tems'],
#  'kilometre': [61, 310, 20, 27, 290, 'Burna Boy'],
#  'first sermon': [300, 7, 250, 350, 290, 'Black Sherif'],
#  'already': [300, 310, 250, 350, 22, 'Beyoncé'],
#  'pamela': [300, 310, 250, 350, 123, 'Wauve'],
#  'drunk guitar': [300, 310, 250, 350, 94, 'NSG'],
#  'solo': [300, 310, 250, 350, 91, 'Shakka'],
#  'infinity': [300, 310, 14, 350, 290, 'Olamide'],
#  'risky': [300, 310, 250, 350, 129, 'DaVido'],
#  'sponono': [300, 310, 250, 350, 37, 'Kabza De Small'],
#  'lady': [41, 310, 250, 350, 290, 'Nchinye'],
#  'touch it': [300, 15, 250, 350, 290, 'KiDi'],
#  'money man': [35, 310, 250, 350, 290, 'Malcolm Nuna'],
#  'lonely': [300, 310, 250, 350, 24, 'Joeboy'],
#  'holy ghost fire': [300, 310, 250, 20, 290, 'KDDO'],
#  'sugar daddy': [300, 310, 250, 36, 290, 'Dj Enimoney'],
#  'understand': [1, 1, 1, 350, 290, 'Omah Lay'],
#  'cash app': [300, 60, 250, 350, 290, 'Bella Shmurda'],
#  'attitude': [300, 54, 250, 350, 290, 'Harmonize'],
#  'constantly': [300, 310, 250, 41, 290, 'Speroachbeatz'],
#  'hallelu': [300, 63, 18, 30, 290, 'Masterkraft'],
#  'moslado': [300, 310, 250, 350, 36, 'Teni'],
#  'party next door': [30,
#   4,
#   250,
#   350,
#   290,
#   'Dangbana Republik and  Bella Shmurda'],
#  'somebody': [33, 310, 250, 350, 290, 'Olamide'],
#  'champion': [300, 310, 250, 350, 96, 'Fireboy DML'],
#  'marry me': [300, 310, 250, 350, 103, 'Smallgod'],
#  'cassette': [300, 82, 250, 350, 290, 'Nanky'],
#  'african girl bad': [300, 310, 250, 350, 124, 'Zoro'],
#  'luva luva': [300, 310, 250, 350, 119, 'Runtown'],
#  'mad': [300, 310, 250, 350, 39, 'Sarz'],
#  'tonongo': [300, 46, 250, 350, 290, 'Lojay, Sarz'],
#  'attention': [300, 310, 250, 350, 31, 'Tiwa Savage'],
#  'omo x 100': [300, 37, 250, 350, 290, 'Reminisce'],
#  'no stress': [300, 310, 250, 350, 12, 'WizKid'],
#  'midnight crush': [82, 310, 250, 350, 290, 'Jeune Lio'],
#  'stuntin': [60,
#   310,
#   250,
#   350,
#   290,
#   'Mix Master David,  Verse Simmonds and  Oxlade'],
#  'simmer': [300, 310, 250, 350, 106, 'Mahalia'],
#  'iphupho': [300, 30, 250, 350, 290, 'Jabzz Dimitri featuring Kuhle'],
#  'kubo': [300,
#   73,
#   250,
#   350,
#   290,
#   'Kwesta featuring K.O, Focalistic and Bassie'],
#  'dance': [300, 87, 250, 350, 290, 'Humblesmith'],
#  'surround me': [300, 310, 250, 350, 114, 'Ayotemi'],
#  'sacrifices': [300, 310, 250, 350, 68, 'DAP The Contract'],
#  'pepe': [300, 310, 40, 6, 290, 'Davido'],
#  'soundgasm': [8, 10, 4, 350, 290, 'Rema'],
#  'mandy': [300, 310, 250, 350, 2, 'Scribz Riley'],
#  'all the above': [300, 22, 250, 350, 290, 'Show Dem Camp'],
#  'sweet escape': [43, 310, 250, 350, 290, 'Mizzle'],
#  'naira marley': [21, 310, 17, 350, 290, 'Zinoleesky'],
#  'kpk': [300, 39, 39, 7, 290, 'Rexxie and MohBad'],
#  'for you': [300, 62, 29, 28, 54, 'Teni featuring Davido'],
#  'come over': [300, 310, 250, 350, 25, 'Jorja Smith'],
#  'jennifer remix': [300, 13, 250, 350, 290, 'Guchi ft Rayvanny'],
#  'akekho': [300, 78, 250, 350, 290, 'Kekelingo'],
#  'tattoo': [300, 310, 250, 350, 35, 'Fireboy DML'],
#  'tropical breeze': [80, 310, 250, 350, 290, 'Magnom and  Caine'],
#  'outside': [23, 310, 6, 2, 290, 'Buju'],
#  'oshofree': [59, 310, 250, 350, 290, 'YKB'],
#  'buju': [300, 310, 57, 350, 290, 'Buju'],
#  'send me nudes': [54, 310, 250, 350, 290, 'KiDi'],
#  'fireboy dml': [300, 310, 53, 350, 290, 'Fireboy DML'],
#  '23': [300, 310, 26, 350, 290, 'Burna Boy'],
#  'under pressure': [300, 310, 250, 350, 117, 'Jay Teazer'],
#  'trouble': [300, 310, 250, 350, 95, 'DRB Lasgidi, Fresh L., Tems'],
#  'sweetie odo': [300, 310, 250, 350, 116, 'Juls'],
#  'carolina': [56, 310, 250, 350, 290, 'Yung D3mz'],
#  'rumour': [300, 310, 250, 350, 13, 'Kaien Cruz'],
#  'repeat': [300, 310, 250, 350, 98, 'J Hus'],
#  'sere': [55, 24, 250, 350, 290, 'Spinall,  Fireboy DML and  6LACK'],
#  'love somebody': [300, 310, 250, 350, 6, 'Rotimi'],
#  'holy ground': [300, 310, 250, 350, 81, 'DaVido'],
#  'wishes': [300, 310, 250, 350, 148, 'Juls'],
#  'blessed': [36, 310, 250, 350, 16, 'Wizkid'],
#  'in my bed': [300, 310, 250, 350, 28, 'Rotimi'],
#  'changanya': [300, 81, 250, 350, 290, 'Jay Rox x Jux'],
#  'every weekend': [300, 72, 250, 350, 290, 'DJ Tunez & J. Anthoni']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    if k in d:
        keys[x] = d1[d.index(k)]
    if k in e:
        keys[x] = e1[e.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 326

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x])/5 for x in range(0, 326)]

# %%
data = {'song':song,'artist':post6,'apple':post1,'audio':post2,'youtube':post3,'boom':post4,'spotify':post5,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,327)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:50]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv('week29-afrobeats50.csv')
df.to_csv('week29-afrobeats.csv')

# %%
df2 = pd.read_csv('week28-afrobeats50.csv')

# %%
a = list(df2['song'])
a1 = a.copy()
x = 0
for i in a:
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df1['song'])
b1 = b.copy()
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
song = []
for x in b:
    if x in a:
        song.append(a1[a.index(x)])
    else:
        song.append(b1[b.index(x)])

# %%
df1['song'] = song

# %%
a = list(df2['song'])
b = list(df1['song'])
c = list(df2['weeks on chart'])
i = 0
prev = []
weeks = []
for x in b:
    if x in a:
        prev.append(a.index(x) + 1)
        weeks.append(c[i] + 1)
    else:
        prev.append(0)
        weeks.append(1)
    i += 1
df1['Previous week'] = prev
df1['weeks on chart'] = weeks

# %%
df1.to_csv('week29-afrobeats50.csv')
df1.to_csv('C:\\Users\\faree\\Desktop\\music charts\\weekly charts\\weekly\\afrobeats50.csv')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\docs\\afrobeats50.json')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\week29\\afrobeats50.json')

# %%
df1
# Out:
#                                          song  \
# rank
# 1                    Ginger (feat. Burna Boy)
# 2                                     Feeling
# 3                        Essence (feat. Tems)
# 4                                     Show Me
# 5                                   Testimony
# 6                                      Coming
# 7                      FOR YOU (feat. Davido)
# 8                                   Enjoyment
# 9                                     Outside
# 10        La La (Official Video) (feat. CKay)
# 11                    Bounce (Official Video)
# 12                   Understand (Lyric Video)
# 13                      Rock (Official Video)
# 14                                  Soundgasm
# 15                                  INJURE ME
# 16       KPK (Remix) ft. Sho Madjozi & MohBad
# 17     Hallelu (feat. Bella Shmurda & Zlatan)
# 18                                  Slow Down
# 19                                  Kilometre
# 20                              Somebody Baby
# 21                                      Godly
# 22                 Dimension (Official Video)
# 23                                   Squander
# 24                        KOLO (feat. Oxlade)
# 25                  The Best (feat. Mayorkun)
# 26                              Music Messiah
# 27                 Ke Star (feat. Vigro Deep)
# 28                                       Peru
# 29                             This Your Body
# 30                               Feel Good
# 31                            Party Next Door
# 32                                    The Key
# 33        All (Official Audio) (feat. Davido)
# 34                      Verified ft. Mayorkun
# 35                                       PEPE
# 36                        Egbon (feat. Phyno)
# 37              Blessed (feat. Damian Marley)
# 38                           Off You ft. KiDi
# 39                        Pronto ft. Omah Lay
# 40                            Sere (Remix)
# 41                                   Monalisa
# 42    Fine Wine (feat. King Promise & Joeboy)
# 43                          Loco ft. Mayorkun
# 44                                       AWAY
# 45                               Celebrate Me
# 46                               Naira Marley
# 47                          Free Your Mind
# 48            Southy Love (feat. Fireboy DML)
# 49                                 Rise Up
# 50                           It Is What It Is
#
#                                     artist  Previous week  weeks on chart
# rank
# 1                                   Wizkid              1               5
# 2                        LADIPOE and  Buju              2               5
# 3                                   Wizkid              5               5
# 4                                   Joeboy              3               5
# 5                                     Buju             22               5
# 6                Naira Marley and  Busiswa              4               5
# 7                    Teni featuring Davido              7               5
# 8                               Yemi Alade              8               2
# 9                                     Buju              9               5
# 10                                  Davido             10               5
# 11                                   Ruger              6               5
# 12                                Omah Lay             11               5
# 13                                 Olamide             12               5
# 14                                    Rema             13               3
# 15                                    Teni             14               5
# 16                       Rexxie and MohBad             15               5
# 17                             Masterkraft             21               5
# 18                            King Promise             28               5
# 19                               Burna Boy             17               3
# 20                     Davido and  Peruzzi             20               5
# 21                                Omah Lay             27               5
# 22                                    JAE5             25               2
# 23                                 Niniola             38               3
# 24                              Ice Prince             26               4
# 25                                  Davido             29               5
# 26                              DJ Neptune             31               4
# 27         Focalistic featuring Vigro Deep             30               5
# 28                             Fireboy DML              0               1
# 29                       Skales and Davido             33               3
# 30                                  MohBad              0               1
# 31    Dangbana Republik and  Bella Shmurda             34               5
# 32                                    Tems             35               3
# 33                                  Rexxie             36               4
# 34                                  Laycon             37               5
# 35                                  Davido             19               4
# 36                  Masterkraft and  Phyno             16               3
# 37                                  Wizkid             40               3
# 38                                    Kidi             43               5
# 39                          Ajebo Hustlers             24               5
# 40        Spinall,  Fireboy DML and  6LACK              0               1
# 41                         Lojay and  Sarz             44               3
# 42                                  R2Bees             42               4
# 43                                    KDDO             45               4
# 44                              Ayra Starr             48               4
# 45                             Patoranking             47               3
# 46                              Zinoleesky             46               2
# 47                    Blaq Jerzee and  Jux             49               3
# 48                                 Peruzzi             50               4
# 49                         2Baba and  Falz              0               1
# 50                           Adekunle Gold              0               1

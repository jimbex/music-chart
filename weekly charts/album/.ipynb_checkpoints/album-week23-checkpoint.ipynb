# %%
import pandas as pd
df1 = pd.read_csv('apple_album-week23.csv')
df2 = pd.read_csv('audiomack_album-week23.csv')
df3 = pd.read_csv('deezer_album-week23.csv')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]
df4 = df4[['song', 'artist']]
df5 = df5[['song', 'artist']]
df6 = df6[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    if '(' in i:
        c[x] = i[: i.index('(')]
    c[x] = c[x].strip().lower()
    x += 1

# %%
d = list(df4['song'])
d1 = d.copy()
d2 = list(df4['artist'])
x = 0
for i in d:
    if '(' in i:
        d[x] = i[: i.index('(')]
    d[x] = d[x].strip().lower()
    x += 1

# %%
e = list(df5['song'])
e1 = e.copy()
e2 = list(df5['artist'])
x = 0
for i in e:
    if '(' in i:
        e[x] = i[: i.index('(')]
    e[x] = e[x].strip().lower()
    x += 1

# %%
f = list(df6['song'])
f1 = f.copy()
f2 = list(df6['artist'])
x = 0
for i in f:
    if '(' in i:
        f[x] = i[: i.index('(')]
    f[x] = f[x].strip().lower()
    x += 1

# %%
songs = a + b + c + d + e + f
songs = set(songs)

# %%
songs
# Out:
# 372

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [375]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(420)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(350)

# %%
x = 0
for i in songs:
    if i in d:
        final[i].append(d.index(i) + 1)
    else:
        final[i].append(450)

# %%
x = 0
for i in songs:
    if i in e:
        final[i].append(e.index(i) + 1)
    else:
        final[i].append(300)

# %%
x = 0
for i in songs:
    if i in f:
        final[i].append(f.index(i) + 1)
    else:
        final[i].append(325)

# %%
x = 0
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    if i in d and len(final[i]) < 7:
        final[i].append(d2[d.index(i)])
    if i in f and len(final[i]) < 7:
        final[i].append(f2[f.index(i)])
    if i in b and len(final[i]) < 7:
        final[i].append(b2[b.index(i)])
    if i in c and len(final[i]) < 7:
        final[i].append(c2[c.index(i)])
    if i in e and len(final[i]) < 7:
        final[i].append(e2[e.index(i)])
    x += 1

# %%
final
# Out:
# {'save the day': [375, 89, 350, 450, 300, 325, 'Teni'],
#  'rather be myself': [375, 420, 350, 217, 300, 325, 'Russ'],
#  'hell': [375, 420, 350, 146, 300, 325, 'corizo'],
#  'losses': [123, 420, 110, 450, 300, 325, 'Polo G'],
#  'park o x3': [74, 420, 72, 450, 300, 325, 'Lojay, Sarz'],
#  'southy love': [29, 420, 26, 65, 75, 50, 'Peruzzi'],
#  'godly': [51, 10, 50, 38, 39, 14, 'Omah Lay'],
#  'real life': [81, 420, 91, 79, 300, 325, 'Burna Boy'],
#  'high way': [56, 420, 54, 44, 300, 35, 'DJ Kaywise, Phyno'],
#  'cut soap': [375, 420, 350, 225, 300, 325, 'Fiokee & Raybekah'],
#  'can you': [375, 420, 350, 224, 300, 325, 'SHATTA WALE'],
#  'koleyewon': [375, 28, 350, 40, 64, 325, 'Naira Marley'],
#  'piece of me': [91, 420, 97, 450, 300, 325, 'Wizkid'],
#  'no stress': [70, 420, 70, 72, 300, 325, 'Wizkid'],
#  'focus vibe': [375, 38, 350, 450, 300, 325, 'Slimcase'],
#  'birthday': [84, 420, 77, 450, 96, 325, 'Migos'],
#  'freaky': [375, 420, 350, 149, 300, 325, 'Hotkid'],
#  '2040': [94, 420, 86, 450, 300, 325, 'Lil Baby, Lil Durk'],
#  'dick appointment': [375, 91, 350, 450, 300, 325, 'Erigga'],
#  'jowo': [62, 420, 61, 450, 300, 325, 'Davido'],
#  'painting pictures': [60, 420, 51, 450, 65, 97, 'Polo G'],
#  'astronaut in the ocean': [375, 420, 350, 450, 57, 325, 'Masked Wolf'],
#  'call': [375, 98, 350, 450, 300, 325, 'Joeboy'],
#  'loved by you': [33, 29, 31, 450, 26, 76, 'Justin Bieber'],
#  'ruger': [120, 420, 113, 450, 92, 81, 'Ruger'],
#  'aye': [375, 78, 350, 450, 300, 325, 'Naira Marley'],
#  'good woman': [375, 420, 350, 450, 300, 70, 'Flavour'],
#  '20 10 20': [375, 420, 350, 181, 300, 325, 'Burna Boy'],
#  'ameno': [375, 420, 350, 450, 300, 37, 'ERA'],
#  'ke star remix': [375, 420, 350, 19, 300, 325, 'Focalistic & Davido'],
#  'olorun agbaye': [375, 420, 350, 450, 300, 44, 'Nathaniel Bassey'],
#  'rich off pain': [65, 420, 64, 450, 300, 325, 'Lil Baby, Lil Durk, Rod Wave'],
#  'arch angel 222': [375, 420, 350, 450, 132, 325, 'Diamondxx'],
#  'true love': [90, 420, 96, 450, 300, 325, 'Wizkid'],
#  'are you sure': [375, 420, 350, 17, 300, 86, 'Lyta'],
#  'too correct': [63, 17, 62, 23, 300, 51, 'Crayon, Rema'],
#  'ye ye ye': [375, 420, 350, 139, 300, 325, 'Omah Lay'],
#  'party lyfe': [119, 420, 105, 450, 109, 325, 'Polo G'],
#  'dangbana orisa': [375, 420, 350, 91, 300, 325, 'Bella Shmurda'],
#  'abule': [375, 44, 350, 134, 300, 325, 'Patoranking'],
#  'sere': [375, 420, 350, 450, 83, 325, 'Spinall, Fireboy Dml, 6lack'],
#  'it is what it is': [14, 20, 12, 9, 12, 31, 'Adekunle Gold'],
#  'you': [375, 48, 350, 106, 300, 325, 'Omah Lay'],
#  'history': [16, 3, 13, 3, 20, 20, 'Cheque, Fireboy DML'],
#  'flamerz flow': [375, 420, 350, 226, 300, 325, 'Meek Mill'],
#  'why so serious': [375, 420, 350, 209, 300, 325, 'Dax'],
#  'world': [43, 100, 41, 8, 54, 59, 'Dangbana Republik, Bella Shmurda'],
#  'kilofeshe': [61, 420, 60, 36, 28, 325, 'Zinoleesky'],
#  'having our way': [15, 420, 10, 450, 34, 63, 'Migos'],
#  'yadda kunne yaji': [375, 420, 350, 450, 300, 92, 'Hamisu Breaker'],
#  'turn myself in': [375, 420, 350, 195, 300, 325, 'Lil Durk'],
#  'need to know': [375, 420, 350, 450, 300, 33, 'Doja Cat'],
#  'adore you': [375, 420, 350, 223, 300, 325, 'Bizzy Banks'],
#  'feeling': [1, 2, 37, 1, 1, 2, 'LADIPOE, Buju'],
#  'coachella': [375, 83, 350, 450, 300, 325, 'Sarkodie'],
#  'okwaraji': [92, 420, 98, 450, 300, 325, 'Blaqbonez'],
#  'ori': [375, 76, 350, 45, 300, 325, 'Barry Jhay'],
#  'amope': [375, 420, 350, 84, 300, 325, 'Bella Shmurda'],
#  'afar': [375, 95, 350, 147, 300, 325, 'Fireboy DML & Olamide'],
#  'capable god': [375, 42, 350, 450, 300, 325, 'Judikay'],
#  'nothing to me': [375,
#   420,
#   350,
#   213,
#   300,
#   325,
#   'Young Dolph, Snupe Bandz, PaperRoute Woo'],
#  'pepe': [68, 16, 65, 29, 108, 72, 'L.A.X, Davido'],
#  'adura': [375, 71, 350, 112, 300, 325, 'Mohbad'],
#  'euphoria': [375, 420, 350, 198, 300, 325, 'PsychoYP'],
#  'black woman': [375, 420, 350, 199, 300, 325, 'Vybz Kartel'],
#  'essence': [9, 24, 6, 20, 9, 11, 'Wizkid'],
#  'born to win': [375, 420, 350, 160, 300, 325, 'Timaya'],
#  'all love': [375, 420, 350, 99, 300, 325, 'Lil Durk'],
#  'olofofo': [375, 14, 350, 18, 300, 96, 'Victor AD'],
#  'die young': [375, 420, 350, 117, 300, 325, 'Roddy Ricch'],
#  'freestyle': [375, 33, 350, 450, 300, 325, '2jaja'],
#  'ladipoe ft. buju': [375,
#   420,
#   350,
#   183,
#   300,
#   325,
#   'Feelings (Cover By Abami OG) - Abami OG'],
#  'calling my phone': [375, 420, 350, 450, 62, 325, 'Lil Tjay, 6lack'],
#  'apology': [375, 420, 350, 177, 300, 325, 'Jeriq'],
#  'peaches': [50, 39, 49, 450, 31, 69, 'Justin Bieber'],
#  'love': [375, 420, 350, 180, 300, 325, 'Davolee'],
#  '3 headed goat': [375, 420, 350, 105, 300, 325, 'Lil Durk'],
#  'black hearted': [87, 420, 81, 450, 93, 325, 'Polo G'],
#  'triumphant': [375, 15, 350, 33, 300, 325, 'Olamide'],
#  "feelin' peachy": [375, 420, 350, 214, 300, 325, 'Kodak Black'],
#  'aye ope yo': [375, 420, 350, 450, 300, 61, 'Adeyinka Alaseyori'],
#  'omemma': [375, 35, 350, 450, 300, 325, 'Judikay'],
#  'squander': [375, 45, 350, 200, 300, 93, 'Falz'],
#  'roju': [375, 79, 350, 450, 300, 4, 'Chike'],
#  'sho mo mi': [375, 420, 350, 49, 300, 325, 'Bella Shmurda'],
#  'commitment issues': [71, 420, 67, 111, 36, 325, 'Central Cee'],
#  'rock': [3, 1, 2, 2, 3, 7, 'Olamide'],
#  'muje': [375, 420, 350, 69, 300, 325, 'Barry Jhay'],
#  'reckless': [55, 420, 58, 450, 300, 325, 'Wizkid'],
#  'so lovely': [375, 420, 350, 126, 300, 325, 'Buju'],
#  'lemonade': [375,
#   420,
#   350,
#   450,
#   85,
#   325,
#   'Internet money, Gunna, Don Toliver, NAV'],
#  'lole': [375, 53, 350, 450, 300, 325, 'Kendickson'],
#  "can\\'t relate": [375, 34, 350, 450, 300, 325, 'Omah Lay'],
#  'ma pariwo': [375, 420, 350, 70, 300, 325, 'Zinoleesky'],
#  'baddest': [375, 420, 350, 156, 300, 325, 'Yung Bleu, Chris Brown, 2 Chainz'],
#  'infinity': [73, 12, 69, 37, 24, 325, 'Olamide'],
#  'confession': [375, 72, 350, 129, 300, 325, 'Omah Lay'],
#  'man of galilee': [375, 86, 350, 450, 300, 325, 'Judikay'],
#  'flex': [375, 420, 350, 131, 300, 325, 'Kizz Daniel'],
#  'spell': [375, 420, 350, 145, 300, 325, 'Fireboy DML & Wande Coal'],
#  'focus': [64, 5, 63, 7, 30, 38, 'Joeboy'],
#  'malibu': [38, 420, 30, 450, 78, 325, 'Migos'],
#  'hallelu': [54, 420, 53, 30, 21, 43, 'Masterkraft'],
#  'bounse': [34, 420, 3, 155, 16, 17, 'Rema'],
#  'show me': [10, 4, 7, 450, 22, 9, 'Joeboy'],
#  'ginger me': [375, 420, 350, 52, 99, 78, 'Bella Shmurda'],
#  'tomorrow': [375, 420, 350, 194, 300, 325, 'Illest ft Seyi vibez'],
#  'so real': [124, 420, 112, 450, 101, 325, 'Polo G'],
#  'what type of dance': [375, 420, 350, 154, 300, 325, 'DJ Kaywise'],
#  'damn': [375, 59, 350, 143, 300, 325, 'Omah Lay'],
#  'celebration': [375, 420, 350, 98, 300, 325, 'Joeboy'],
#  'wow': [375, 420, 350, 450, 133, 325, 'Tion Wayne'],
#  'clueless': [89, 420, 83, 450, 94, 325, 'Polo G'],
#  'labarin zuciya': [375, 420, 350, 450, 300, 85, 'Rahab saleem'],
#  'friday feeling': [375, 420, 350, 164, 300, 325, 'Fireboy DML'],
#  'colorado': [375, 420, 350, 76, 300, 325, 'Zugo'],
#  'kiss me more': [375, 420, 350, 450, 88, 94, 'Doja Cat'],
#  'ponpon': [108, 420, 117, 450, 113, 325, 'Olamide'],
#  'picture freestyle': [375, 420, 350, 75, 300, 325, 'Seyi Vibez'],
#  'check yourself': [375, 57, 350, 450, 300, 325, 'Kaptain'],
#  'this love': [375, 47, 350, 450, 300, 325, 'Chidinma'],
#  'bad type': [375, 420, 350, 39, 300, 325, 'Seyi Vibez'],
#  'this your body': [375, 30, 350, 54, 89, 325, 'Skales and Davido'],
#  'the box': [375, 420, 350, 113, 300, 325, 'Roddy Ricch'],
#  'picasso': [53, 420, 43, 450, 81, 325, 'Migos, Future'],
#  'arojinle': [375, 420, 350, 450, 300, 60, 'Adeyinka Alaseyori'],
#  'jafafa': [375, 420, 350, 162, 300, 325, 'Chinko Ekun & Mohbad'],
#  'blessed': [31, 420, 28, 450, 55, 325, 'Wizkid'],
#  'p r i d e . i s . t h e . d e v i l': [375,
#   420,
#   350,
#   450,
#   77,
#   325,
#   'J. Cole, Lil Baby'],
#  '365 days': [375, 420, 350, 186, 300, 325, 'OmartheDJ'],
#  '6am in brighton': [375, 420, 350, 450, 130, 325, 'ArrDee'],
#  'thot shit': [375, 420, 350, 185, 300, 47, 'Megan Thee Stallion'],
#  'lv n attn feat. wizkid': [7, 420, 76, 450, 14, 325, 'Lojay, Sarz'],
#  'at my worst': [375, 420, 350, 93, 127, 95, 'Pink Sweat$'],
#  'vaccine': [83, 420, 78, 450, 97, 325, 'Migos'],
#  'be something': [375, 420, 350, 170, 300, 325, 'Polo G'],
#  'cho cho': [375, 69, 350, 31, 60, 32, 'Zlatan'],
#  'kpk': [69, 26, 66, 28, 32, 23, 'Rexxie, MohBad'],
#  'the best': [46, 43, 46, 51, 43, 42, 'Davido'],
#  'maserati': [375, 420, 350, 171, 300, 325, 'Olakira'],
#  'project dreams': [375, 420, 350, 127, 300, 325, 'Roddy Ricch'],
#  'broken guitars': [117, 420, 103, 450, 111, 325, 'Polo G'],
#  'pay day': [375, 420, 350, 67, 300, 325, 'Seyi Vibez'],
#  'big thug boys': [375, 420, 350, 142, 300, 325, 'AV'],
#  "90's": [375, 420, 350, 24, 300, 325, 'Seyi Vibez'],
#  'makaveli': [375, 420, 350, 86, 300, 325, 'Kida Kudz'],
#  'legends': [375, 420, 350, 123, 300, 325, 'Juice WRLD'],
#  'know you': [375, 420, 350, 118, 300, 325, 'Ladipoe'],
#  'marlians anthem': [375, 420, 350, 137, 300, 325, 'MohBad'],
#  'koroba': [375, 420, 350, 450, 300, 99, 'Tiwa Savage'],
#  'god sent': [375, 420, 350, 89, 300, 325, 'Seyi Vibez'],
#  'early momo': [35, 420, 35, 62, 70, 57, 'Vector'],
#  '23': [42, 46, 40, 48, 37, 325, 'Burna Boy'],
#  'loading': [375, 51, 350, 82, 300, 325, 'Olamide'],
#  'splash': [375, 420, 350, 189, 300, 325, 'Tyga'],
#  'mighty wine': [88, 420, 95, 450, 300, 325, 'Wizkid'],
#  'have fun': [375, 420, 350, 184, 300, 325, 'Bad Boy Timz'],
#  'jailer': [106, 420, 116, 450, 106, 325, 'Olamide'],
#  'so much more': [112, 420, 123, 450, 118, 325, 'Olamide'],
#  'lenu': [375, 420, 350, 114, 300, 325, 'Buju'],
#  'happy birthday': [375,
#   420,
#   350,
#   152,
#   300,
#   325,
#   'Simi feat. Adekunle Gold and Deja'],
#  'beautiful mistakes': [375,
#   420,
#   350,
#   450,
#   100,
#   325,
#   'Maroon 5, Megan Thee Stallion'],
#  'another level': [375, 420, 350, 151, 300, 325, 'Olamide'],
#  'too faithful': [375, 56, 350, 450, 300, 325, 'Moses Bliss'],
#  'late at night': [23, 74, 22, 34, 35, 80, 'Roddy Ricch'],
#  'cash app': [72, 82, 68, 43, 51, 25, 'Bella Shmurda, Zlatan, Lincoln'],
#  'obinasom': [375, 87, 350, 450, 300, 325, 'Mercy Chinwo'],
#  'in my maserati': [375, 420, 350, 450, 300, 24, 'Olakira'],
#  'more than gold': [375, 420, 350, 228, 300, 325, 'Judikay'],
#  'sere remix': [375,
#   420,
#   350,
#   116,
#   300,
#   325,
#   'Spinall, Fireboy DML and 6LACK'],
#  'available': [375, 420, 350, 100, 300, 325, 'C Blvck'],
#  'song of angels': [375, 420, 350, 219, 300, 325, 'Judikay'],
#  'light it up': [77, 420, 73, 450, 74, 325, 'Migos, Pop Smoke'],
#  'ntashinda': [375, 420, 350, 215, 300, 325, 'Diamond Platnumz'],
#  'omo ologo': [375, 420, 350, 120, 300, 325, 'Lil Frosh'],
#  'sweet one': [80, 420, 90, 450, 300, 325, 'Wizkid'],
#  'sugar daddy': [375, 70, 350, 450, 300, 325, 'Dj Enimoney'],
#  'catalyst': [375, 420, 350, 41, 300, 325, 'Seyi Vibez'],
#  'outside': [5, 13, 4, 11, 5, 18, 'Buju'],
#  'bad influence': [100, 50, 102, 66, 98, 325, 'Omah Lay'],
#  'body': [13, 420, 11, 32, 17, 15, 'Tion Wayne, Russ Millions'],
#  'injure me': [58, 22, 57, 12, 300, 84, 'Teni'],
#  'sare': [375, 420, 350, 450, 300, 49, 'Ayra Starr'],
#  'way too big': [78, 37, 80, 55, 122, 325, 'Burna Boy'],
#  'lo lo': [375, 88, 350, 128, 300, 325, 'Omah Lay'],
#  'type shit': [44, 420, 36, 450, 80, 325, 'Migos, Cardi B'],
#  'heartbreak anniversary': [95, 420, 99, 450, 47, 325, 'GIV\\xc4\\x92ON'],
#  'boom': [115, 420, 101, 450, 112, 325, 'Polo G'],
#  'why not': [98, 420, 92, 450, 300, 71, 'Migos'],
#  'dimension': [8, 27, 5, 122, 7, 21, 'JAE5'],
#  'longtime': [79, 420, 87, 450, 300, 325, 'Wizkid'],
#  'onemmenma': [375, 420, 350, 450, 300, 67, 'Mercy Chinwo & Chioma Jesus'],
#  'omnipotent': [375, 420, 350, 58, 300, 325, 'Bella Shmurda'],
#  'rockstar': [375, 420, 350, 450, 82, 325, 'DaBaby, Roddy Ricch'],
#  'vision 2020': [375, 420, 350, 63, 300, 325, 'Bella Shmurda'],
#  'don dada': [375, 68, 350, 46, 84, 77, 'Timaya'],
#  'm y . l i f e': [375, 420, 350, 450, 76, 325, 'J. Cole, 21 Savage, Morray'],
#  'gang gang': [59, 420, 52, 450, 50, 325, 'Polo G, Lil Wayne'],
#  'cup of tea': [111, 420, 122, 450, 117, 325, 'Olamide'],
#  'body riddim': [375, 420, 350, 227, 300, 325, 'Runtown'],
#  'oliver twist': [57, 420, 55, 450, 27, 68, 'ArrDee'],
#  'ponmo': [375, 420, 350, 101, 300, 325, 'Mohbad'],
#  'a m a r i': [375, 420, 350, 450, 45, 325, 'J. Cole'],
#  'go away': [375, 420, 350, 136, 300, 325, 'Fireboy DML'],
#  'kilofese': [122, 420, 126, 450, 300, 325, 'Zinoleesky'],
#  'coming': [11, 8, 8, 4, 8, 29, 'Naira Marley, Busiswa'],
#  'sorry': [375, 420, 350, 60, 300, 325, 'MohBad'],
#  'zoom': [375, 420, 350, 124, 300, 325, 'Cheque'],
#  'epidemic': [36, 420, 32, 450, 46, 325, 'Polo G'],
#  'activate': [375, 420, 350, 125, 300, 325, 'Stonebwoy'],
#  'hallelujah challenge praise medley': [375,
#   58,
#   350,
#   450,
#   300,
#   325,
#   'Nathaniel Bassey'],
#  'tattoo': [375, 420, 350, 202, 300, 325, 'Fireboy DML'],
#  'so crazy': [375, 420, 350, 144, 300, 325, 'Davido'],
#  'thunder fire you': [375, 420, 350, 203, 300, 325, 'Ric Hassani'],
#  'enjoy': [375, 96, 350, 450, 300, 46, 'Tekno'],
#  'holy ground': [103, 420, 111, 71, 300, 325, 'Davido'],
#  'door': [375, 18, 350, 47, 300, 73, 'Joeboy'],
#  'forever': [26, 21, 23, 450, 11, 8, 'Gyakie, Omah Lay'],
#  'duduke': [375, 420, 350, 192, 300, 325, 'Simi and Deja'],
#  'chi chi': [375, 420, 350, 61, 300, 325, 'Naira Marley'],
#  'antisocial': [39, 420, 33, 450, 79, 325, 'Migos'],
#  'ag baby': [375, 420, 350, 169, 300, 325, 'Adekunle Gold'],
#  'dama': [375, 420, 350, 450, 300, 62, 'Namenj & Hamisu Breaker'],
#  'lucky': [375, 420, 350, 222, 300, 325, 'Russ'],
#  'somebody baby': [32, 84, 29, 21, 19, 40, 'Davido, Peruzzi'],
#  'sai dake': [375, 420, 350, 450, 300, 58, 'Hamisu Breaker'],
#  'beamer': [375, 420, 350, 187, 300, 325, 'Rema'],
#  'pakurumo': [375, 420, 350, 208, 300, 325, 'Wizkid'],
#  'handle my business': [116, 420, 104, 450, 300, 325, 'Migos'],
#  'something different': [375, 420, 350, 157, 300, 325, 'Adekunle Gold'],
#  'lovely': [375, 420, 350, 450, 134, 325, 'Billie Eilish, Khalid'],
#  'jireh': [375,
#   420,
#   350,
#   450,
#   300,
#   53,
#   'Elevation Worship & Maverick City Music'],
#  'modern day': [75, 420, 71, 450, 91, 34, 'Migos'],
#  'serious': [375,
#   420,
#   350,
#   221,
#   300,
#   325,
#   'DJ pH featuring Cassper Nyovest, Lady Du and Makwa'],
#  'kolo': [30, 420, 27, 53, 40, 65, 'Ice Prince'],
#  'angles': [375, 420, 350, 211, 300, 325, 'Wale'],
#  'level up': [375, 420, 350, 121, 300, 325, 'Burna Boy'],
#  'let it go': [375, 420, 350, 450, 44, 91, 'DJ Khaled'],
#  'jo': [375, 420, 350, 135, 300, 325, 'Teni'],
#  'fem': [375, 420, 350, 92, 300, 325, 'Davido'],
#  'who i want': [101, 420, 94, 450, 300, 325, 'Lil Baby, Lil Durk'],
#  'gat me singing': [375, 93, 350, 450, 300, 325, 'Luddy Dave'],
#  'mandeman': [375, 420, 350, 110, 300, 325, 'Small Doctor'],
#  'kilometre': [12, 7, 9, 14, 18, 36, 'Burna Boy'],
#  'hello brother': [375, 420, 350, 163, 300, 325, 'Omah Lay'],
#  'jackpot': [375, 420, 350, 138, 300, 325, 'Crayon'],
#  'life is good': [375, 420, 350, 150, 300, 325, 'Future'],
#  'rough up': [107, 420, 118, 450, 114, 325, 'Olamide'],
#  'blinding lights': [375, 420, 350, 450, 102, 325, 'The Weeknd'],
#  'smile': [102, 420, 109, 90, 300, 325, 'Wizkid'],
#  'happiness': [375, 420, 350, 73, 300, 325, 'Davolee'],
#  'need for speed': [104, 420, 114, 450, 104, 325, 'Olamide'],
#  'gani a so': [375, 420, 350, 450, 300, 83, 'Zainab Ambato'],
#  'runaway': [375, 420, 350, 450, 52, 325, 'AURORA'],
#  'pempe': [375, 420, 350, 450, 300, 30, 'Seyi Shay & --'],
#  'million little miracles': [375,
#   420,
#   350,
#   450,
#   300,
#   90,
#   'Elevation Worship & Maverick City Music'],
#  'iron man': [375, 420, 350, 196, 300, 325, 'Rema'],
#  'green light': [375, 75, 350, 107, 300, 325, 'Olamide'],
#  'bling': [6, 420, 75, 10, 6, 28, 'Blaqbonez'],
#  'you i live for': [375, 49, 350, 450, 300, 325, 'Moses Bliss'],
#  'pami': [375, 40, 350, 56, 300, 325, 'DJ Tunez'],
#  'celebrate me': [121, 420, 125, 205, 120, 325, 'Patoranking'],
#  'if you no love': [375, 23, 350, 94, 300, 45, 'Chik̩'],
#  'symphony': [375, 420, 350, 130, 300, 325, 'Seyi Vibez'],
#  'sun goes down': [375, 420, 350, 450, 125, 325, 'Lil Nas X'],
#  'wonderful': [375, 420, 350, 109, 300, 325, 'Burna Boy'],
#  'jane': [86, 420, 82, 450, 124, 325, 'Migos'],
#  'off you': [375, 80, 350, 450, 300, 325, 'Young Jonn'],
#  'ke star': [20, 90, 19, 450, 15, 16, 'Focalistic, Davido'],
#  'rotate': [375, 32, 350, 207, 300, 325, 'Mr Eazi'],
#  'ginger': [25, 94, 24, 35, 42, 41, 'Wizkid'],
#  'damages': [375, 420, 350, 83, 63, 325, 'Tems'],
#  'if e happen for lagos': [375, 97, 350, 103, 300, 22, 'Runtown'],
#  'voice of the heroes': [41, 420, 38, 450, 56, 74, 'Lil Baby, Lil Durk'],
#  'i will survive': [375, 420, 350, 168, 300, 325, 'Diamond Jimma'],
#  'onyedikagi': [375, 420, 350, 450, 300, 26, 'Mercy Chinwo'],
#  'egbon': [375, 420, 350, 115, 300, 325, 'Masterkraft'],
#  'toxic': [96, 420, 88, 450, 95, 325, 'Polo G'],
#  'sika': [375, 420, 350, 216, 300, 325, 'Sista Afia'],
#  'rush': [48, 420, 45, 27, 49, 325, 'Dangbana Republik, Bella Shmurda'],
#  'julie': [105, 420, 115, 450, 105, 325, 'Olamide'],
#  'la la': [22, 31, 20, 450, 53, 12, 'Davido'],
#  'hats off': [49, 420, 44, 450, 121, 325, 'Lil Baby, Lil Durk, Travis Scott'],
#  'ball till we fall': [375,
#   420,
#   350,
#   132,
#   300,
#   325,
#   'Kida Kudz featuring Bella Shmurda'],
#  'consent': [375, 420, 350, 174, 300, 325, 'Joeboy'],
#  'do not disturb': [375, 420, 350, 176, 300, 325, 'Omah Lay'],
#  'monalisa': [28, 420, 25, 450, 61, 325, 'Lojay, Sarz'],
#  'love like this': [375, 64, 350, 450, 300, 75, 'Lil Kesh'],
#  'temperature': [375, 420, 350, 218, 300, 325, 'Unfoonk, Young Stoner Life'],
#  'bank on it': [40, 62, 39, 450, 300, 325, 'Burna Boy'],
#  'how it feels': [375, 420, 350, 450, 300, 87, 'Lil Baby & Lil Durk'],
#  'time for me': [93, 420, 85, 450, 300, 325, 'Migos'],
#  'lagos anthem': [375, 63, 350, 182, 300, 325, 'Zlatan'],
#  'anyone': [375, 420, 350, 450, 126, 325, 'Justin Bieber'],
#  'try me': [375, 420, 350, 179, 300, 325, 'Tems'],
#  'roadrunner': [97, 420, 89, 450, 128, 325, 'Migos'],
#  'many nites': [375, 55, 350, 450, 300, 325, 'Erigga'],
#  'only you': [375, 420, 350, 64, 300, 325, 'Bella Shmurda'],
#  'all in': [375, 420, 350, 450, 123, 325, 'Nasty C, T.I.'],
#  'lonely': [375, 66, 350, 42, 107, 325, 'Joeboy'],
#  'your body': [375, 420, 350, 88, 300, 325, 'Mayorkun'],
#  'as e dey go': [375, 420, 350, 166, 300, 325, 'Naira Marley'],
#  'cultural praise': [375, 420, 350, 96, 300, 325, 'Kcee & Okwesili Eze Group'],
#  'leave the door open': [125,
#   420,
#   127,
#   450,
#   68,
#   82,
#   'Bruno Mars, Anderson .Paak, Silk Sonic'],
#  'viral moment': [375, 420, 350, 191, 300, 325, 'Lil Durk'],
#  'confident': [113, 420, 124, 193, 119, 325, 'Savage, Buju'],
#  'what you see': [85, 420, 79, 450, 90, 325, 'Migos, Justin Bieber'],
#  'loved by you [re]': [375, 420, 350, 119, 300, 325, 'GoodyBoy'],
#  'z look jamaican': [375, 420, 350, 188, 300, 325, 'Kodak Black'],
#  'heart of a giant': [114, 420, 100, 450, 131, 325, 'Polo G'],
#  'lukuti': [375, 420, 350, 87, 300, 89, 'DJ AB'],
#  'tonongo': [17, 420, 14, 140, 48, 325, 'Lojay, Sarz'],
#  'for the love of new york': [52,
#   420,
#   42,
#   450,
#   87,
#   325,
#   'Polo G, Nicki Minaj'],
#  'want': [109, 420, 121, 450, 115, 325, 'Olamide'],
#  'somebody': [110, 420, 120, 450, 116, 325, 'Olamide'],
#  'bounce': [4, 6, 350, 450, 4, 6, 'Ruger'],
#  'money': [375, 420, 350, 13, 73, 325, 'Terri, Bella Shmurda, Mohbad'],
#  'felony': [18, 67, 15, 25, 10, 39, 'CKay'],
#  'abu dhabi': [45, 420, 47, 190, 67, 325, 'Ruger'],
#  'need it': [118, 420, 106, 450, 300, 325, 'Migos'],
#  'no return': [66, 420, 56, 450, 59, 56, 'Polo G'],
#  'baba fela': [375, 81, 350, 450, 300, 325, 'Mr Real'],
#  'airplane mode': [375, 73, 350, 104, 300, 27, 'Fireboy DML'],
#  'my bebe': [375, 52, 350, 95, 300, 325, 'Omah Lay'],
#  'soundgasm': [2, 420, 1, 6, 2, 1, 'Rema'],
#  'kizo': [375, 420, 350, 161, 300, 325, 'TMP Offisial'],
#  'butter': [375, 420, 350, 450, 300, 54, 'BTS'],
#  'fall for me': [375, 420, 350, 78, 110, 325, 'Laycon'],
#  'like i do': [375, 420, 350, 173, 300, 325, 'Fireboy DML'],
#  'hold me tight': [375, 420, 350, 133, 300, 325, 'Kcee'],
#  'running': [37, 11, 34, 16, 29, 5, 'Chike, Simi'],
#  'dior': [375, 420, 350, 450, 86, 325, 'Pop Smoke'],
#  'pronto': [19, 77, 18, 26, 23, 52, 'Ajebo Hustlers, Omah Lay'],
#  'cultural praise vol.2': [375,
#   420,
#   350,
#   175,
#   300,
#   325,
#   'Kcee, Okwesili Eze Group'],
#  'montero': [375, 420, 350, 450, 41, 48, 'Lil Nas X'],
#  'currently': [375, 420, 350, 85, 300, 325, 'Kizz Daniel'],
#  'no lele': [375, 420, 350, 206, 300, 325, 'Wizkid'],
#  'lv n attn': [375, 420, 350, 102, 300, 79, 'Lojay, Sarz'],
#  'avalanche': [24, 420, 17, 450, 38, 19, 'Migos'],
#  'wrong road': [375, 420, 350, 210, 300, 325, 'Kevo Muney'],
#  'up': [375, 420, 350, 178, 300, 88, 'Cardi B'],
#  'music messiah': [375, 36, 350, 77, 71, 325, 'DJ Neptune'],
#  'save your tears': [375, 420, 350, 450, 300, 55, 'The Weeknd'],
#  'high fashion': [375, 420, 350, 159, 300, 325, 'Roddy Ricch'],
#  'eru': [375, 420, 350, 172, 300, 325, 'Olamide'],
#  'away': [375, 420, 350, 201, 72, 325, 'Oxlade'],
#  'all my life': [375, 92, 350, 148, 58, 66, 'M.I Abaga'],
#  'giving up': [375, 420, 350, 220, 300, 325, 'Yungeen Ace'],
#  'jehovah overdo': [375, 420, 350, 450, 300, 10, 'Chidinma'],
#  '6am': [375, 54, 350, 450, 300, 325, 'Blaq Jerzee'],
#  'woman': [375, 420, 350, 141, 300, 325, 'Rema'],
#  'straightenin': [27, 420, 21, 450, 33, 64, 'Migos'],
#  'champion': [375, 41, 350, 50, 103, 325, 'Fireboy DML & D Smoke'],
#  'fendi': [375, 420, 350, 450, 66, 325, 'Blaqbonez, Joeboy'],
#  'hood scars 2': [375,
#   420,
#   350,
#   167,
#   300,
#   325,
#   'J.I the Prince of N.Y & Lil Tjay'],
#  'eli': [375, 420, 350, 158, 300, 325, 'Fireboy DML'],
#  'rapstar': [21, 420, 16, 450, 13, 100, 'Polo G'],
#  'moslado': [375, 420, 350, 108, 300, 325, 'Teni'],
#  'for you': [47, 19, 48, 15, 25, 13, 'Teni'],
#  'upgrade': [375, 420, 350, 68, 300, 325, 'Bella Shmurda'],
#  'fingers crossed': [375,
#   420,
#   350,
#   204,
#   300,
#   325,
#   'Trevor Daniel & Julia Michaels'],
#  'panty!': [76, 420, 74, 450, 129, 325, 'Lojay, Sarz'],
#  'mahomes': [99, 420, 93, 450, 300, 325, 'Migos'],
#  'liquor': [375, 420, 350, 59, 300, 325, 'Bella Shmurda'],
#  'plenty': [375, 420, 350, 153, 300, 325, 'Olamide'],
#  'ayewada': [82, 25, 84, 5, 300, 325, 'Barry Jhay'],
#  'jennifer': [375, 9, 350, 450, 300, 3, 'Guchi'],
#  'rest on kashy': [375, 420, 350, 81, 300, 325, 'Anonymous Music'],
#  'emperor ft guchi': [375, 420, 350, 197, 300, 325, 'Jennifer - Emperor'],
#  "can't relate": [375, 420, 350, 74, 300, 325, 'Omah Lay'],
#  'fame & riches': [67, 420, 59, 450, 69, 325, 'Polo G'],
#  'prayer request': [375, 420, 350, 165, 300, 325, 'Victor AD']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in e:
        keys[x] = e1[e.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    if k in f:
        keys[x] = f1[f.index(k)]
    if k in d:
        keys[x] = d1[d.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 372

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
post7 = [x[6] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x] + post6[x])/6 for x in range(0, 372)]

# %%
data = {'song':song,'artist':post7,'apple':post1,'boom':post2,'spotify':post3,'audiomack':post4, 'deezer':post5, 'youtube':post6,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,373)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:100]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv('week24-hot100.csv')
df.to_csv('week24.csv')

# %%
df
# Out:
#                  song                 artist  apple  boom  spotify  audiomack  \
# rank
# 1                Rock                Olamide      3     1        2          2
# 2             Feeling          LADIPOE, Buju      1     2       37          1
# 3             Outside                   Buju      5    13        4         11
# 4              COMING  Naira Marley, Busiswa     11     8        8          4
# 5             History    Cheque, Fireboy DML     16     3       13          3
# ...               ...                    ...    ...   ...      ...        ...
# 368            Anyone          Justin Bieber    375   420      350        450
# 369   6am in Brighton                 ArrDee    375   420      350        450
# 370    Arch Angel 222              Diamondxx    375   420      350        450
# 371               Wow             Tion Wayne    375   420      350        450
# 372            lovely  Billie Eilish, Khalid    375   420      350        450
#
#       deezer  youtube          RT
# rank
# 1          3        7    3.000000
# 2          1        2    7.333333
# 3          5       18    9.333333
# 4          8       29   11.333333
# 5         20       20   12.500000
# ...      ...      ...         ...
# 368      126      325  341.000000
# 369      130      325  341.666667
# 370      132      325  342.000000
# 371      133      325  342.166667
# 372      134      325  342.333333
#
# [372 rows x 9 columns]

# %%
import pandas as pd
from datetime import datetime
m = datetime.today().strftime('%B')
d = datetime.today().strftime('%d')
w = datetime.today().strftime('%V')
w = int(w)
d = int(d)

# %%
df1 = pd.read_csv(f'apple_alte-week{w}.csv', encoding='utf-8')
df2 = pd.read_csv(f'audio_alte-week{w}.csv', encoding='utf-8')
df3 = pd.read_csv(f'spotify_alte-week{w}.csv', encoding='utf-8')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    i = i.lower()
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        a[x] = a[x].replace('feat', '(feat')
    if 'remix' in i:
        a[x] = a[x].replace('remix', '(remix')
    if '  ' in i:
        a[x] = a[x].replace('  ', ' ')
    if '(' in a[x]:
        a[x] = a[x][: a[x].index('(')]
    if '\\' in i:
        a[x] = a[x].replace('\\', '') 
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    i = i.lower()
    if 'remix' in i:
        b[x] = i.replace('remix', '(remix')
    if 'ft' in i:
        b[x] = b[x].replace('ft', '(ft')
    if 'feat' in i:
        b[x] = b[x].replace('feat', '(feat')
    if '  ' in i:
        b[x] = b[x].replace('  ', ' ')
    if '(' in b[x]:
        b[x] = b[x][: b[x].index('(')]
    if '\\' in i:
        b[x] = b[x].replace('\\', '') 
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    i = i.lower()
    if 'ft' in i:
        c[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        c[x] = c[x].replace('feat', '(feat')
    if 'remix' in i:
        c[x] = c[x].replace('remix', '(remix')
    if '  ' in i:
        c[x] = c[x].replace('  ', ' ')
    if '(' in c[x]:
        c[x] = c[x][: c[x].index('(')]
    if '\\' in i:
        c[x] = c[x].replace('\\', '')  
    c[x] = c[x].strip().lower()
    x += 1

# %%
songs = a + b + c
songs = set(songs)

# %%
len(songs)
# Out:
# 241

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [500]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(510)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(450)

# %%
x = 0
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    if i in b and len(final[i]) < 5:
        final[i].append(b2[b.index(i)])
    if i in c and len(final[i]) < 5:
        final[i].append(c2[c.index(i)])
    #if i in d and len(final[i]) < 5:
     #   final[i].append(d2[d.index(i)])
    x += 1

# %%
final
# Out:
# {'cigarette': [500, 510, 71, 'Turunesh'],
#  'deja vu': [500, 510, 3, 'Moliy'],
#  'up': [500, 510, 32, "T'neeya"],
#  'lemonade': [500, 60, 450, 'Ria sean'],
#  'bomo': [500, 33, 450, 'Adey'],
#  'chanel': [500, 61, 450, 'Ceeboi'],
#  'call up': [500, 510, 44, 'Ria Boss'],
#  'cash': [500, 510, 49, 'Lady Donli'],
#  'indifferent': [500, 510, 51, 'Mo$hpit Cindy'],
#  'chance': [500, 510, 73, 'Juls'],
#  'wotm': [38, 510, 450, 'Richie Benson'],
#  'runaway': [500, 510, 83, 'Merry-Lynn'],
#  'down for you': [76, 510, 450, 'Aramide'],
#  'birthday': [84, 510, 450, 'Rexxie'],
#  'fancy': [16, 28, 450, 'Uche Malik', 'Amaarae'],
#  'someone else': [69, 510, 450, 'Olayinka Ehi'],
#  'cakes': [500, 14, 450, 'Straffitti featuring PatricKxxLee and KashCPT'],
#  'focused': [500, 30, 450, 'PsychoYP & Azanti'],
#  'ka$h app': [500, 79, 450, 'Beezyx feat. denzl, Kiienka, Begho, Bolaryn'],
#  'change': [500,
#   81,
#   450,
#   'Lord Edward and Boy Nino feat. Murphy Cubic, Tyrone Jones'],
#  'red eyes': [500, 510, 52, 'dndSection'],
#  'ball till we fall': [80,
#   68,
#   450,
#   'Kida Kudz',
#   'Kida Kudz featuring Bella Shmurda'],
#  'bloody samaritan': [500, 510, 101, 'Ayra Starr'],
#  '4 you': [500, 65, 450, 'Yung D3mz'],
#  "can't complain": [500, 52, 450, 'Nova'],
#  "don't fold": [500, 27, 450, 'Delis'],
#  'down low': [500, 78, 450, 'Krosszn'],
#  'searching': [41, 510, 13, 'Lady Donli', 'Lady Donli'],
#  'party starter': [11, 510, 450, 'Gabzy'],
#  'tonongo': [34, 510, 450, 'Lojay and  Sarz'],
#  'result': [65, 510, 450, 'Dreylo'],
#  'idgaf': [58, 510, 450, 'Ikayh'],
#  'mandown': [500, 67, 450, 'BoyCamilo'],
#  'leave me alone': [500, 510, 92, 'A COLORS SHOW - Amaarae'],
#  'body count': [500, 510, 56, 'Odunsi (The Engine)'],
#  'in my bag': [500, 510, 90, '808vic'],
#  'outside': [2, 510, 450, 'Buju'],
#  'shege': [15, 510, 450, 'Purple Plutonian'],
#  'anaconda': [54, 510, 450, 'BadTheSoundBoy'],
#  'cocaine': [19, 47, 450, 'Dai Verse', 'Daiverse'],
#  'euphoria': [37, 510, 55, 'Hoodini', 'PsychoYP'],
#  'brag': [500, 88, 61, 'DETO BLACK', 'DETO BLACK'],
#  'godly': [500, 45, 450, 'Omah Lay'],
#  'space': [500, 39, 450, 'Whoisakin'],
#  'push & pull': [47, 510, 450, 'Randay'],
#  'dragon fruit freestyle': [14, 510, 450, 'Lady Donli'],
#  'dupxc4x96': [53, 510, 450, 'Azekel'],
#  'seke': [24, 510, 450, 'Vader the Wildcard'],
#  'makaveli': [500, 510, 72, 'Kida Kudz'],
#  'smooth papa': [500, 510, 78, 'WundaB'],
#  "don't be shy": [500, 510, 43, 'Kida Kudz'],
#  'damages': [500, 21, 450, 'Tems'],
#  'rise of the underdogs 2': [79,
#   8,
#   450,
#   'Show Dem Camp',
#   'Show Dem Camp featuring Tomi Thomas'],
#  'santa flow': [500,
#   49,
#   450,
#   'Chop Life Crew featuring L.K, Tena Tenpo, Cubix and Miju'],
#  'eyes but no eyes': [500, 510, 26, 'M3NSA'],
#  'tdk': [82, 510, 80, 'DAP The Contract', 'DAP The Contract'],
#  'let go': [81, 510, 450, 'Txc3x96ME'],
#  'prosecco': [500, 510, 53, 'Th&o.'],
#  'feeling': [36, 510, 450, 'LADIPOE and  Buju'],
#  'dubai': [500, 23, 450, 'Skaa'],
#  'movement': [500, 71, 450, 'Lekside Westside'],
#  'lowo': [500, 83, 450, 'Chuks Profound featuring Zarion Uti and Chordratic'],
#  'pumpkin': [18, 510, 450, 'Mike Akox'],
#  'show my side': [83, 510, 450, 'CKay'],
#  'how dare you': [500, 9, 450, 'Joda Kgosi'],
#  'smile for you': [500, 1, 450, 'Mizzle featuring Oxlade'],
#  'hustler': [500, 85, 450, 'Marzi'],
#  'permission': [500, 20, 450, 'Damosh'],
#  'joro mi': [77, 510, 450, 'Beejvibe$'],
#  'fight it2': [500, 57, 450, 'Mich Straaw'],
#  'waiting outside': [500, 510, 46, 'Dj Nayiram'],
#  'quarter past love': [57, 510, 450, 'W!ll'],
#  'again': [500, 510, 54, 'Tomi Thomas'],
#  'tycoon': [500, 510, 42, 'Show Dem Camp'],
#  'nobody': [500, 84, 450, 'Pzeefire'],
#  'slow down': [500, 510, 4, 'King Promise'],
#  'jorja': [500, 510, 74, 'Hoosh'],
#  'sisi caro': [72, 510, 450, 'Governor of Africa and  Oxlade'],
#  'so long': [52, 510, 450, 'Sjxy'],
#  'bling': [17, 510, 23, 'Blaqbonez', 'Blaqbonez'],
#  'yoga': [500, 510, 87, 'Tay Iwar'],
#  'guala': [500, 55, 79, 'Teezee', 'Teezee'],
#  'popshit': [55, 510, 45, 'SGaWD', 'SGaWD'],
#  'rip old dad': [78, 510, 450, 'The.wav'],
#  'who talk': [5, 510, 450, 'Moelogo'],
#  'sweatshirt': [42, 87, 450, 'April Maey', 'April Maey'],
#  'lagos bad girls': [500, 75, 27, 'Bils', 'Bils'],
#  'we move': [500, 510, 60, 'Malachi'],
#  'the key': [51, 510, 450, 'Tems'],
#  'swayy': [500, 69, 450, 'Suté Iwar featuring Tay Iwar'],
#  'dkt': [500, 510, 12, 'Oxlade'],
#  'life of the party': [500, 510, 68, 'Yung D3mz'],
#  'we up': [500, 74, 450, 'Zilla Oaks featuring Phaemous'],
#  'all mine': [500, 92, 450, 'Kinsolo'],
#  'fire for you': [500, 86, 450, 'Prodbyvino feat. D1wav'],
#  'everywhere': [500, 31, 450, 'Straffitti featuring Buju'],
#  'london': [500, 510, 37, 'Tomi Agape'],
#  'early momo': [27, 510, 19, 'Vector', 'Vector'],
#  'nasa': [500, 510, 77, 'Rvdical the Kid'],
#  'catch a vibe': [500, 42, 450, 'Karun and MOMBRU'],
#  'closure': [68, 510, 450, 'The Syndicate'],
#  'magic': [500, 510, 25, 'Public Goods'],
#  'nobody else': [500, 80, 450, 'Ugo Klassic'],
#  'supersonic': [500, 510, 2, 'Le Mav'],
#  'sweet escape': [85, 510, 450, 'Mizzle'],
#  'let u down': [500, 4, 450, 'Sigag Lauren'],
#  'understand': [4, 510, 450, 'Omah Lay'],
#  'go outside': [500, 40, 450, 'Nonso Amadi'],
#  "numbers don't lie": [500, 72, 450, 'chuXchu featuring Ayo Jay'],
#  'greenlight': [500, 62, 450, 'Hamzil'],
#  'human': [8, 510, 450, 'Show Dem Camp'],
#  'all my ladies': [500, 35, 450, 'WANI'],
#  'pray': [1, 510, 102, 'Victony', 'Victony'],
#  'bad star': [500, 510, 18, 'burningforestboy'],
#  'geneva': [500, 510, 31, 'Ossaiofficial'],
#  'queen bee': [500, 26, 450, 'Black Lavender'],
#  'bdmn': [500, 510, 14, 'Minz'],
#  'call me baby': [500, 510, 10, 'Cheque'],
#  'non stop': [500, 24, 450, 'Jody'],
#  'workaholic': [31, 510, 450, 'BRUME'],
#  'narcissus is dead': [500, 63, 450, 'Suté Iwar'],
#  'cameras': [500, 510, 69, 'SuperJazzClub'],
#  'sacrifices': [44, 510, 86, 'DAP The Contract', 'DAP The Contract'],
#  'peace of mind': [500, 510, 70, 'Preyé'],
#  'bbc': [500, 29, 450, 'Blaqbonez'],
#  'where': [500, 19, 450, 'Bey T'],
#  'like dat': [500, 51, 450, 'Skillz 8Figure'],
#  'wait': [500, 510, 65, 'Kinsu'],
#  'secret': [500, 510, 95, 'Papi ojo'],
#  'indecisive': [23, 510, 450, 'Niinety9'],
#  'walahi': [500, 510, 24, 'D-Truce'],
#  'fast lane': [500, 64, 450, 'Lavaud'],
#  'luv hrts': [500, 12, 30, 'Zamir featuring Odunsi (The Engine)', 'Zamir'],
#  'wreckless tactics': [500, 15, 450, 'TRiPPY TRiPPY'],
#  'real': [12, 91, 99, 'Tim Lyre', 'Tim Lyre'],
#  'caribbeana': [29, 510, 7, 'Wondamagik and  Ogranya', 'Wondamagik'],
#  'hot star': [500, 22, 450, 'Chrystel'],
#  'self luv': [500, 58, 450, 'Skillz 8Figure'],
#  'if its on': [500, 93, 450, 'Silverstone Barz'],
#  'soundgasm': [40, 2, 48, 'Rema', 'Rema'],
#  'align': [59, 510, 450, 'Show Dem Camp'],
#  'firedncr.': [70, 510, 450, 'Jaylon'],
#  'dark twisted fantasy': [74, 18, 63, "T'neeya", "T'neeya"],
#  'bounce': [500, 53, 450, 'Rema'],
#  'strangers or friends': [500, 76, 450, 'Atee'],
#  'needing you': [500, 77, 450, 'Big Ozed'],
#  'lenu': [500, 37, 450, 'Buju'],
#  'for you': [75, 510, 450, 'Smyley'],
#  'mary': [500, 510, 88, '3rty'],
#  'bestie': [60, 510, 450, 'PURRRRRR'],
#  'ltf': [32, 510, 450, 'Victor Collins and  MisterKay'],
#  'celebration': [500, 44, 450, 'Joeboy'],
#  "fool's love": [500, 510, 50, 'Muzi'],
#  'serenade': [500, 510, 64, 'Begho'],
#  'tired': [500, 25, 450, 'Shirazee'],
#  'cry another day': [73, 510, 450, 'Zubi,  Gabriel and  anatu'],
#  'so wrong': [500, 510, 38, 'Dayonthetrack'],
#  'confident': [6, 7, 450, 'Savage and  Buju', 'Savage X Buju'],
#  'sacred forest': [500, 510, 16, 'Ogranya'],
#  'peru': [10, 510, 450, 'Fireboy DML'],
#  'table for two': [43, 89, 59, 'Bella Alubo', 'Bella Alubo'],
#  'over you': [500, 32, 450, 'Joey B'],
#  'ma pariwo': [500, 510, 57, 'DRB Lasgidi, Lady Donli'],
#  'feel a way': [500, 510, 93, 'Amaarae'],
#  'sweet body': [500, 510, 67, 'SuperSmashBroz'],
#  'gorgeous': [33, 510, 450, 'SaveMilli'],
#  'different strain': [500, 510, 33, 'Fasina'],
#  'how i met your mother': [500, 510, 41, 'Aussie Maze'],
#  'paradise': [500, 16, 450, '4Runna'],
#  'whaz e gonna be': [500, 510, 94, 'Wondamagik'],
#  'radar': [500, 510, 11, 'Remix - BwoiiDaas'],
#  'trust issues': [500, 510, 35, 'Bankyondbeatz'],
#  'la la': [49, 510, 450, "T'neeya"],
#  'hurricane': [500, 510, 28, 'Tomi Thomas'],
#  'salvation': [500, 510, 91, 'Ogranya'],
#  'star friends': [500, 510, 84, 'Salome'],
#  'test me': [35, 510, 450, 'Jeune Lio,  Chrystel and  Yung D3mz'],
#  'gamble': [500, 10, 450, 'Kholi'],
#  'saus': [500, 36, 450, 'Chillz x TMXO'],
#  'only you': [500, 66, 450, 'take1 & Muku Fresh'],
#  'company': [500, 11, 17, 'Twiss Tosin & Zen Univrse', 'Higo, WANI'],
#  'missed call': [500, 510, 96, 'Mike Keyz'],
#  'island pink': [500, 510, 75, 'Phaemous'],
#  'times two': [20, 90, 450, 'WANI', 'WANI'],
#  'bean24': [22, 510, 450, 'Hermez'],
#  'talk': [26, 510, 450, 'Timiboi'],
#  'wicked somebody': [21, 510, 450, 'Wondamagik and  Ogranya'],
#  'beautifully': [500, 6, 450, 'Fave'],
#  'longé': [500, 54, 450, 'Bryann'],
#  'so lovely': [500, 510, 58, 'Buju'],
#  'deep end': [500, 510, 8, 'Adey'],
#  "it's okay to cry": [500, 510, 66, 'Yinka Bernie'],
#  'dupė': [500, 38, 450, 'Azekel'],
#  'sugar': [500, 510, 97, 'Zubi'],
#  'chargie': [500, 510, 9, 'Jay Cliff'],
#  'testimony': [25, 510, 450, 'Buju'],
#  'what is this love': [500, 82, 450, 'July'],
#  'cold': [48, 510, 62, 'Zubi,  anatu and  Gabriel', 'Zubi'],
#  'vvs': [500, 510, 22, 'Studio Magic'],
#  'moscow': [500, 70, 450, 'Jody'],
#  'kogi': [67, 510, 450, 'Jumabee'],
#  'pami': [500, 41, 450, 'DJ Tunez'],
#  'vogue': [500, 510, 5, 'Wauve'],
#  'unconditionally': [9, 510, 450, 'Ajebutter 22 and  Oxlade'],
#  'sativa': [63, 510, 450, 'Runtown'],
#  'tornado': [50, 510, 450, 'chuXchu'],
#  'send me nudes': [66, 510, 450, 'KiDi'],
#  'man of my word': [500, 50, 450, 'Noir'],
#  'a. iverson': [3, 510, 450, 'Zamir'],
#  'gone girl': [500, 510, 1, 'Obongjayar, Sarz'],
#  '4amin': [500, 510, 15, 'Ayüü'],
#  'trouble': [500, 34, 450, 'DRB LasGidi'],
#  'girlfriend': [500, 46, 450, 'SirBastien'],
#  'alcy': [30, 510, 450, 'July Drama'],
#  'money & laughter': [28, 510, 85, 'BOJ', 'Boj, Amaarae'],
#  'show u love': [56, 510, 450, 'Oniisha'],
#  'problem': [500, 510, 6, 'Kida Kudz'],
#  'only human': [500, 510, 47, 'Ukweli'],
#  'free mind': [500, 510, 76, 'Tems'],
#  'essence': [500, 13, 450, 'Wizkid'],
#  'diamonds': [500, 48, 450, 'Rebecca Winter'],
#  'broken': [500, 510, 34, 'Victony'],
#  'frenemies': [7, 510, 450, 'Rexxie'],
#  'yes i do': [500, 510, 82, 'Caleb Awiti'],
#  'oh no': [39, 510, 450, 'Alpha P'],
#  'pull up': [500, 3, 450, 'Gabzy'],
#  'i miss you': [500, 17, 450, 'Joda Kgosi'],
#  'too many women': [500, 59, 450, 'Ajebutter22, BOJ, Falz'],
#  'selense': [500, 510, 39, 'The Cavemen.'],
#  'passenger': [500, 510, 89, 'Odeal'],
#  'peaking': [45, 5, 40, 'Tay Iwar', 'Tay Iwar'],
#  'fever': [64, 510, 20, 'Yung D3mz', 'Suté Iwar'],
#  'scream and shout': [500, 510, 98, 'Ejoya'],
#  'one time': [46, 510, 450, 'Moelogo'],
#  '1985': [500, 510, 21, 'Juls'],
#  'tonight': [500, 510, 81, 'Yung D3mz'],
#  'sinner': [13, 510, 450, 'Adekunle Gold and  Lucky Daye'],
#  'symbiosis': [500, 510, 36, 'Ajebo Hustlers'],
#  'gentil': [500, 510, 29, 'Zubi'],
#  'right back': [71, 56, 450, 'Skaa and  Buju', 'Skaa'],
#  'lifestyle': [62, 510, 450, 'Naassure']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    #if k in d:
     #   keys[x] = d1[d.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 241

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
#post5 = [x[4] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x])/3 for x in range(0, 241)]

# %%
data = {'song':song,'artist':post4,'apple':post1,'boom':post2,'youtube':post3,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,242)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:50]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv(f'week{w}-alte50.csv')
df.to_csv(f'week{w}-alte.csv')

# %%
df2 = pd.read_csv(f'week{w-1}-gospel50.csv')

# %%
a = list(df2['song'])
a1 = a.copy()
x = 0
for i in a:
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df1['song'])
b1 = b.copy()
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
song = []
for x in b:
    if x in a:
        song.append(a1[a.index(x)])
    else:
        song.append(b1[b.index(x)])

# %%
df1['song'] = song

# %%
a = list(df2['song'])
b = list(df1['song'])
c = list(df2['weeks on chart'])
i = 0
prev = []
weeks = []
for x in b:
    if x in a:
        prev.append(a.index(x) + 1)
        weeks.append(c[i] + 1)
    else:
        prev.append(0)
        weeks.append(1)
    i += 1
df1['Previous week'] = prev
df1['weeks on chart'] = weeks

# %%
df1.to_csv(f'week{w}-alte50.csv')
df1.to_csv('C:\\Users\\faree\\Desktop\\music charts\\weekly charts\\weekly\\alte50.csv')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\docs\\alte50.json')
df1.to_json(f'C:\\Users\\faree\\Desktop\\webboard\\week{w}\\alte50.json')

# %%
df1
# Out:
#                                               song  \
# rank
# 1                                        Soundgasm
# 2                                          PEAKING
# 3                             Dark Twisted Fantasy
# 4                                    Table for Two
# 5                                             Real
# 6                                     Confident
# 7                                         FANCY
# 8                                       Cocaine
# 9                                          Company
# 10    Rise Of The Underdogs 2 (feat. Tomi Thomas)
# 11                                        LUV HRTS
# 12                                      Caribbeana
# 13                    Bling (feat. Amaarae & Buju)
# 14                                      Early Momo
# 15                    Times Two (X2) (feat. Buju)
# 16                                       Searching
# 17                        Right Back (feat. Buju)
# 18                                   Sweatshirt
# 19                                           Fever
# 20        Ball Till We Fall (feat. Bella Shmurda)
# 21                                        Euphoria
# 22                                 Lagos Bad Girls
# 23                        POPSHIT (feat. Somadina)
# 24                                            Pray
# 25                                            cold
# 26                                Money & Laughter
# 27                                           Guala
# 28                     Sacrifices (feat. Tim Lyre)
# 29                                            Brag
# 30                          TDK (feat. SirBastien)
# 31                   Smile For You (feat. Oxlade)
# 32                                      Pull Up
# 33                        Let U Down (feat. CIll)
# 34                                  Beautifully
# 35                                 How Dare You
# 36                                       GAMBLE
# 37                                         Outside
# 38                           Essence (feat. Tems)
# 39                   A. Iverson (feat. dndSection)
# 40           Cakes (feat. PatricKxxLee & KashCPT)
# 41                                      Understand
# 42                            Wreckless Tactics
# 43       Who Talk (feat. Adekunle Gold & Ria Sean)
# 44                                     Paradise
# 45                                   I Miss You
# 46                        Frenemies (feat. Oxlade)
# 47                     Human (feat. Tomi Owxc3xb3)
# 48                    Where (Has the Time Gone)
# 49                                 Unconditionally
# 50                                   Permission
#
#                                              artist
# rank
# 1                                              Rema
# 2                                          Tay Iwar
# 3                                           T'neeya
# 4                                       Bella Alubo
# 5                                          Tim Lyre
# 6                                  Savage and  Buju
# 7                                        Uche Malik
# 8                                         Dai Verse
# 9                         Twiss Tosin & Zen Univrse
# 10                                    Show Dem Camp
# 11              Zamir featuring Odunsi (The Engine)
# 12                          Wondamagik and  Ogranya
# 13                                        Blaqbonez
# 14                                           Vector
# 15                                             WANI
# 16                                       Lady Donli
# 17                                   Skaa and  Buju
# 18                                       April Maey
# 19                                        Yung D3mz
# 20                                        Kida Kudz
# 21                                          Hoodini
# 22                                             Bils
# 23                                            SGaWD
# 24                                          Victony
# 25                        Zubi,  anatu and  Gabriel
# 26                                              BOJ
# 27                                           Teezee
# 28                                 DAP The Contract
# 29                                       DETO BLACK
# 30                                 DAP The Contract
# 31                          Mizzle featuring Oxlade
# 32                                            Gabzy
# 33                                     Sigag Lauren
# 34                                             Fave
# 35                                       Joda Kgosi
# 36                                            Kholi
# 37                                             Buju
# 38                                           Wizkid
# 39                                            Zamir
# 40    Straffitti featuring PatricKxxLee and KashCPT
# 41                                         Omah Lay
# 42                                    TRiPPY TRiPPY
# 43                                          Moelogo
# 44                                           4Runna
# 45                                       Joda Kgosi
# 46                                           Rexxie
# 47                                    Show Dem Camp
# 48                                            Bey T
# 49                         Ajebutter 22 and  Oxlade
# 50                                           Damosh

# %%
import pandas as pd
df1 = pd.read_csv('apple-week29.csv')
df2 = pd.read_csv('boom-week29.csv')
df3 = pd.read_csv('spotify-week29.csv')
df4 = pd.read_csv('audiomack-week29.csv')
df5 = pd.read_csv('deezer-week29.csv')
df6 = pd.read_csv('youtube-week29.csv')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]
df4 = df4[['song', 'artist']]
df5 = df5[['song', 'artist']]
df6 = df6[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    if '(' in i:
        c[x] = i[: i.index('(')]
    c[x] = c[x].strip().lower()
    x += 1

# %%
d = list(df4['song'])
d1 = d.copy()
d2 = list(df4['artist'])
x = 0
for i in d:
    if '(' in i:
        d[x] = i[: i.index('(')]
    d[x] = d[x].strip().lower()
    x += 1

# %%
e = list(df5['song'])
e1 = e.copy()
e2 = list(df5['artist'])
x = 0
for i in e:
    if '(' in i:
        e[x] = i[: i.index('(')]
    e[x] = e[x].strip().lower()
    x += 1

# %%
f = list(df6['song'])
f1 = f.copy()
f2 = list(df6['artist'])
x = 0
for i in f:
    if '(' in i:
        f[x] = i[: i.index('(')]
    f[x] = f[x].strip().lower()
    x += 1

# %%
songs = a + b + c + d + e + f
songs = set(songs)

# %%
len(songs)
# Out:
# 353

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [375]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(420)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(350)

# %%
x = 0
for i in songs:
    if i in d:
        final[i].append(d.index(i) + 1)
    else:
        final[i].append(450)

# %%
x = 0
for i in songs:
    if i in e:
        final[i].append(e.index(i) + 1)
    else:
        final[i].append(300)

# %%
x = 0
for i in songs:
    if i in f:
        final[i].append(f.index(i) + 1)
    else:
        final[i].append(325)

# %%
x = 0
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    if i in d and len(final[i]) < 7:
        final[i].append(d2[d.index(i)])
    if i in f and len(final[i]) < 7:
        final[i].append(f2[f.index(i)])
    if i in b and len(final[i]) < 7:
        final[i].append(b2[b.index(i)])
    if i in c and len(final[i]) < 7:
        final[i].append(c2[c.index(i)])
    if i in e and len(final[i]) < 7:
        final[i].append(e2[e.index(i)])
    x += 1

# %%
final
# Out:
# {'enjoyment': [375, 49, 350, 37, 300, 325, 'Yemi Alade'],
#  'longtime': [78, 420, 74, 450, 300, 325, 'Wizkid'],
#  'it is what it is': [33, 420, 32, 24, 5, 49, 'Adekunle Gold'],
#  'bolanle': [375, 420, 350, 450, 300, 98, 'IVD'],
#  'sho mo mi': [375, 420, 350, 64, 300, 325, 'Bella Shmurda'],
#  'bad habits': [375, 420, 350, 450, 81, 325, 'Ed Sheeran'],
#  'testimony': [6, 14, 7, 5, 2, 61, 'Buju'],
#  'rotate': [375, 70, 350, 450, 300, 325, 'Mr Eazi'],
#  'korope': [375, 35, 350, 58, 94, 325, 'Lil Kesh'],
#  'see you next week': [375, 420, 350, 223, 300, 325, 'Dremo'],
#  'cocaine': [375, 420, 350, 226, 300, 325, 'Daiverse'],
#  'twenty to one': [117, 420, 350, 450, 119, 325, 'Dave'],
#  'holy ground': [375, 420, 350, 104, 300, 325, 'Davido'],
#  'wild side': [375, 420, 350, 450, 300, 6, 'Normani'],
#  'smile': [375, 420, 116, 106, 300, 325, 'Wizkid'],
#  'paloma': [375, 420, 350, 450, 300, 50, 'Mr. P & --'],
#  'montero': [375, 420, 350, 450, 50, 58, 'Lil Nas X'],
#  'clash': [32, 420, 38, 450, 28, 64, 'Dave, Stormzy'],
#  'adkin': [375, 95, 350, 450, 300, 325, 'K1 De Ultimate'],
#  'verified': [375, 420, 350, 450, 300, 76, 'Laycon'],
#  'green light': [375, 93, 350, 151, 300, 325, 'Olamide'],
#  'like i do': [375, 420, 350, 187, 300, 325, 'Fireboy DML'],
#  'oliver twist': [84, 420, 87, 450, 23, 80, 'ArrDee'],
#  'manslaughter': [68, 420, 36, 450, 87, 325, 'ream) - Pop Smoke'],
#  'real life': [93, 420, 98, 105, 300, 325, 'Burna Boy'],
#  'symphony': [375, 420, 350, 147, 300, 325, 'Seyi Vibez'],
#  'dance': [375, 420, 350, 224, 300, 325, 'Humblesmith'],
#  'feel': [375, 33, 350, 450, 300, 325, 'Mrolaide '],
#  'essence': [14, 29, 14, 26, 15, 9, 'Wizkid'],
#  'pami': [375, 52, 350, 68, 300, 325, 'DJ Tunez'],
#  'ori': [375, 420, 350, 78, 300, 325, 'Barry Jhay'],
#  'rise up': [375, 420, 350, 215, 300, 325, '2Baba & Falz'],
#  'oh no': [375, 420, 350, 450, 138, 325, 'Alpha P'],
#  'if you no love': [375, 62, 350, 127, 300, 325, 'Chiké'],
#  'for you': [64, 44, 66, 25, 34, 21, 'Teni'],
#  'currently': [375, 420, 350, 131, 300, 325, 'Kizz Daniel'],
#  'high way': [77, 88, 86, 83, 300, 47, 'DJ Kaywise, Phyno'],
#  "can't relate": [375, 40, 350, 107, 300, 325, 'Omah Lay'],
#  'lenu': [375, 420, 350, 66, 300, 325, 'Buju'],
#  'bia': [375, 25, 118, 21, 300, 34, 'Phyno'],
#  'rest on kashy': [375, 420, 350, 143, 300, 325, 'Anonymous Music'],
#  'something different': [375, 420, 350, 164, 300, 325, 'Adekunle Gold'],
#  'felony': [36, 100, 35, 50, 3, 325, 'CKay'],
#  'system': [103, 420, 108, 450, 300, 325, 'Dave, Wizkid'],
#  'shopping spree': [85, 420, 88, 123, 300, 1, 'Davido'],
#  'leave the door open': [375,
#   420,
#   350,
#   450,
#   86,
#   100,
#   'Bruno Mars, Anderson .Paak & Silk Sonic'],
#  'party next door': [15,
#   420,
#   15,
#   450,
#   19,
#   36,
#   'Dangbana Republik, Bella Shmurda'],
#  'spoiled': [110, 420, 100, 450, 300, 325, 'Pop Smoke'],
#  'loading': [375, 55, 350, 117, 300, 325, 'Olamide'],
#  'red light green light': [375, 420, 350, 450, 104, 325, 'DaBaby'],
#  'hallelujah challenge praise medley': [375,
#   72,
#   350,
#   450,
#   300,
#   325,
#   'Nathaniel Bassey'],
#  'so crazy': [375, 420, 350, 165, 300, 325, 'Davido'],
#  'rush': [28, 420, 28, 169, 68, 325, 'Dangbana Republik, Bella Shmurda'],
#  'confession': [375, 73, 350, 150, 300, 325, 'Omah Lay'],
#  'capable god': [375, 41, 350, 450, 300, 325, 'Judikay'],
#  'roju': [375, 45, 350, 450, 300, 22, 'Chike'],
#  'pronto': [41, 83, 43, 47, 37, 325, 'Ajebo Hustlers, Omah Lay'],
#  'bling': [16, 420, 54, 19, 18, 46, 'Blaqbonez'],
#  'ginger': [25, 420, 24, 44, 44, 43, 'Wizkid'],
#  'jack': [375, 91, 350, 450, 134, 325, 'Nasty C'],
#  'focus': [53, 9, 56, 16, 62, 325, 'Joeboy'],
#  'damages': [375, 420, 350, 115, 80, 325, 'Tems'],
#  'yahweh': [375, 420, 350, 450, 300, 78, 'Mercy Chinwo'],
#  'omalicha': [375, 56, 350, 133, 300, 325, 'kolaboy'],
#  'limelight': [375, 420, 350, 228, 300, 325, 'Young Fairo'],
#  'ruger': [375, 420, 350, 450, 88, 73, 'Ruger'],
#  'true love': [80, 420, 79, 450, 300, 325, 'Wizkid'],
#  'omo ologo': [375, 420, 350, 192, 300, 325, 'Lil Frosh featuring Zinoleesky'],
#  'sai dake': [375, 420, 350, 450, 300, 81, 'Hamisu Breaker'],
#  'heartbreak anniversary': [375, 420, 350, 450, 69, 325, 'Giveon'],
#  'permission to dance': [375, 420, 350, 450, 300, 45, 'BTS'],
#  'body': [60, 420, 93, 73, 40, 40, 'Tion Wayne, Russ Millions'],
#  'be something': [375, 420, 350, 162, 300, 325, 'Polo G'],
#  'spiritual': [375, 420, 350, 100, 300, 325, 'Buju'],
#  'bad type': [375, 420, 350, 54, 300, 325, 'Seyi Vibez'],
#  'gani a so': [375, 420, 350, 450, 300, 90, 'Zainab Ambato'],
#  'kidnap who': [375, 420, 350, 206, 300, 325, 'Bouba Savage'],
#  'airplane mode': [375, 420, 350, 109, 300, 325, 'Fireboy DML'],
#  'one time': [375, 420, 350, 198, 300, 325, 'Moelogo'],
#  'spell': [375, 420, 350, 173, 300, 325, 'Fireboy DML & Wande Coal'],
#  'catalyst': [375, 420, 350, 62, 300, 325, 'Seyi Vibez'],
#  'level up': [375, 420, 350, 138, 300, 325, 'Burna Boy'],
#  'reckless': [61, 420, 63, 450, 102, 325, 'Wizkid'],
#  'beamer': [375, 420, 350, 200, 300, 325, 'Rema'],
#  'feel good': [12, 21, 13, 1, 4, 62, 'MohBad'],
#  'a m a r i': [375, 420, 350, 450, 91, 325, 'J. Cole'],
#  'running': [69, 24, 70, 23, 46, 12, 'Chike, Simi'],
#  'still lit': [375, 420, 350, 229, 300, 325, 'Action Pack'],
#  'eli': [375, 420, 350, 183, 300, 325, 'Fireboy DML'],
#  'lemonade': [375,
#   420,
#   350,
#   450,
#   85,
#   325,
#   'Internet money, Gunna, Don Toliver, NAV'],
#  "we're all alone": [106, 420, 110, 450, 300, 325, 'Dave'],
#  'olofofo': [375, 22, 350, 34, 300, 325, 'Victor AD'],
#  'rockstar': [375, 420, 350, 450, 72, 325, 'DaBaby, Roddy Ricch'],
#  'onyedikagi': [375, 420, 350, 450, 300, 63, 'Mercy Chinwo'],
#  'lazarus': [105, 420, 109, 450, 300, 325, 'Dave, Boj'],
#  'somebody baby': [52, 420, 59, 51, 33, 86, 'Davido, Peruzzi'],
#  'ponmo': [375, 420, 350, 108, 300, 325, 'Mohbad'],
#  'good woman': [375, 420, 350, 450, 300, 59, 'Flavour'],
#  'cheers': [375, 420, 350, 193, 300, 325, 'Russ'],
#  'bounce': [2, 3, 350, 450, 7, 2, 'Ruger'],
#  'call me baby': [121, 420, 350, 219, 300, 325, 'Cheque'],
#  'kpk': [112, 420, 104, 79, 45, 33, 'Rexxie, MohBad'],
#  'celebrate me': [46, 19, 48, 15, 54, 25, 'Patoranking'],
#  'so wrong': [375, 420, 350, 213, 300, 325, 'DayOnTheTrack'],
#  'early momo': [49, 420, 50, 92, 75, 70, 'Vector'],
#  'muje': [375, 420, 350, 96, 300, 325, 'Barry Jhay'],
#  'woman': [375, 420, 350, 154, 300, 325, 'Rema'],
#  'amope': [375, 420, 350, 111, 300, 325, 'Bella Shmurda'],
#  '23': [50, 61, 55, 67, 67, 325, 'Burna Boy'],
#  'commitment issues': [375, 420, 350, 184, 74, 325, 'Central Cee'],
#  'soldier go': [51, 420, 52, 31, 70, 325, 'Dangbana Republik, Bella Shmurda'],
#  'outside': [4, 8, 4, 7, 10, 26, 'Buju'],
#  'coupe': [101, 420, 95, 450, 135, 325, 'Pop Smoke'],
#  'focus dance beat': [375, 99, 350, 450, 300, 325, 'Ajimovoix Drums'],
#  'do not disturb': [375, 420, 350, 161, 300, 325, 'Omah Lay'],
#  'high fashion': [375, 420, 350, 177, 300, 325, 'Roddy Ricch'],
#  'temple': [375, 420, 350, 178, 300, 325, 'ALOMA'],
#  'my heart': [375, 420, 350, 450, 300, 91, 'Naomi Mac'],
#  'lonely': [375, 60, 350, 75, 300, 325, 'Joeboy'],
#  'late at night': [56, 420, 61, 69, 66, 325, 'Roddy Ricch'],
#  'get back': [375, 420, 350, 216, 300, 325, 'MO3'],
#  'music messiah': [375, 80, 350, 120, 300, 325, 'DJ Neptune'],
#  'sweet one': [71, 420, 68, 450, 300, 325, 'Wizkid'],
#  'ke star': [38, 420, 37, 35, 27, 23, 'Focalistic, Davido'],
#  'egbon': [375, 420, 350, 144, 300, 325, 'Masterkraft'],
#  'life is good': [375, 420, 350, 152, 300, 325, 'Future'],
#  'dama': [375, 420, 350, 450, 300, 75, 'Namenj & Hamisu Breaker'],
#  'omo x 100': [375, 420, 350, 41, 61, 325, 'Reminisce'],
#  'table for two': [375, 420, 350, 209, 300, 325, 'Bella Alubo'],
#  'jealous': [375, 420, 350, 221, 300, 325, 'Alikiba'],
#  'know you': [375, 420, 350, 175, 300, 325, 'Ladipoe'],
#  'survive': [375, 65, 350, 90, 300, 325, 'Jaido P'],
#  'iyo': [375, 420, 350, 149, 300, 325, 'Diamond Platnumz'],
#  'bounse': [54, 420, 2, 176, 29, 30, 'Rema'],
#  'more time': [65, 420, 30, 450, 76, 325, 'Pop Smoke'],
#  'jailer': [40, 43, 39, 18, 82, 325, 'Olamide'],
#  'colorado': [375, 420, 350, 91, 300, 325, 'Zugo'],
#  'addicted': [375, 420, 350, 450, 300, 69, 'Guchi'],
#  'flex': [375, 420, 350, 163, 300, 325, 'Kizz Daniel'],
#  'upgrade': [375, 420, 350, 81, 300, 325, 'Bella Shmurda'],
#  'my shit': [375, 420, 350, 201, 300, 325, 'Bizzy Banks'],
#  'kolo': [55, 420, 60, 103, 64, 77, 'Ice Prince'],
#  'my bebe': [375, 58, 350, 118, 300, 325, 'Omah Lay'],
#  "what's crackin": [91, 420, 84, 450, 107, 325, 'Pop Smoke'],
#  'go away': [375, 420, 350, 156, 300, 325, 'Fireboy DML'],
#  'fall for me': [375, 420, 350, 116, 300, 325, 'Laycon'],
#  'glu': [375, 420, 350, 208, 300, 325, 'Rygin King & Stalk Ashley'],
#  'sinner': [9, 26, 11, 9, 13, 10, 'Adekunle Gold, Lucky Daye'],
#  'far away': [18, 89, 16, 17, 24, 325, 'Dangbana Republik, Bella Shmurda'],
#  'moslado': [375, 420, 350, 132, 300, 325, 'Teni'],
#  'marlians anthem': [375, 420, 350, 114, 300, 325, 'MohBad'],
#  'omnipotent': [375, 420, 350, 71, 300, 325, 'Bella Shmurda'],
#  'zoom': [375, 420, 350, 139, 300, 325, 'Cheque'],
#  'maserati': [375, 420, 350, 179, 300, 325, 'Olakira'],
#  'hallelu': [66, 420, 71, 36, 35, 325, 'Masterkraft'],
#  'ponpon': [70, 53, 69, 45, 39, 325, 'Olamide'],
#  'baba fela': [375, 59, 350, 450, 300, 325, 'Mr Real'],
#  'this your body': [375, 46, 350, 153, 300, 325, 'Skales and Davido'],
#  'law of attraction': [108, 420, 115, 450, 112, 325, 'Dave, Snoh Aalegra'],
#  'piece of me': [88, 420, 83, 450, 300, 325, 'Wizkid'],
#  'too correct': [375, 30, 350, 46, 300, 82, 'Crayon'],
#  'legends': [375, 420, 350, 121, 300, 325, 'Juice WRLD'],
#  'door': [375, 32, 350, 89, 300, 85, 'Joeboy'],
#  'jowo': [113, 420, 105, 450, 300, 325, 'Davido'],
#  'focus vibe': [375, 97, 350, 450, 300, 325, 'Slimcase'],
#  'the best': [57, 85, 62, 77, 60, 325, 'Davido'],
#  'frenemies': [83, 420, 75, 135, 300, 325, 'Rexxie'],
#  'champion': [58, 42, 58, 52, 101, 325, 'Dangbana Republik, Bella Shmurda'],
#  'as e dey go': [375, 420, 350, 188, 300, 325, 'Naira Marley'],
#  'dopamine freestyle': [375, 420, 350, 210, 300, 325, 'Sad Frosty'],
#  'lurkin': [375, 420, 350, 191, 300, 325, 'Funk Flex, King Von, Polo G'],
#  'southy love': [42, 420, 42, 102, 83, 325, 'Peruzzi'],
#  'medicine': [17, 10, 17, 450, 53, 53, 'Jaywillz'],
#  'koleyewon': [375, 79, 350, 65, 300, 325, 'Naira Marley'],
#  'vision 2020': [375, 420, 350, 80, 300, 325, 'Bella Shmurda'],
#  'world': [27, 420, 27, 38, 51, 97, 'Dangbana Republik, Bella Shmurda'],
#  'confident': [10, 420, 9, 12, 14, 55, 'Savage, Buju'],
#  'way too big': [62, 47, 65, 72, 141, 325, 'Burna Boy'],
#  'back2back': [375, 420, 350, 199, 300, 325, 'Rexxie featuring Bella Shmurda'],
#  'heart attack': [116, 420, 350, 450, 125, 325, 'Dave'],
#  'stay': [375, 420, 350, 450, 79, 57, 'The Kid Laroi & Justin Bieber'],
#  'away': [375, 420, 350, 450, 109, 325, 'Ayra Starr'],
#  'jalebi baby': [375, 420, 350, 450, 300, 18, 'Tesher'],
#  'ma pariwo': [375, 420, 350, 88, 300, 325, 'Zinoleesky'],
#  'rapstar': [92, 420, 97, 450, 41, 325, 'Polo G'],
#  'love like this': [375, 57, 350, 450, 300, 325, 'Lil Kesh'],
#  'out there': [24, 420, 23, 11, 49, 325, 'Dangbana Republik, Bella Shmurda'],
#  'chi chi': [375, 420, 350, 99, 300, 325, 'Naira Marley'],
#  'adé orí òkin': [375, 420, 350, 450, 300, 71, 'K1 De Ultimate'],
#  'show me': [20, 6, 20, 450, 38, 24, 'Joeboy'],
#  'naira marley': [13, 11, 12, 6, 1, 65, 'Zinoleesky'],
#  'hustle': [29, 15, 29, 450, 56, 13, 'Teni'],
#  'damn': [375, 420, 350, 157, 300, 325, 'Omah Lay'],
#  'lv n attn': [26, 420, 26, 148, 129, 325, 'Lojay, Sarz'],
#  'both sides of a smile': [114, 420, 350, 450, 115, 325, 'Dave, James Blake'],
#  'baddest': [375, 420, 350, 450, 300, 95, 'Yung Bleu, Chris Brown & 2 Chainz'],
#  'jireh': [375,
#   420,
#   350,
#   450,
#   300,
#   52,
#   'Elevation Worship & Maverick City Music'],
#  'money & laughter': [94, 420, 82, 450, 300, 325, 'BOJ, Zamir, Amaarae'],
#  'lv n attn feat. wizkid': [375,
#   420,
#   350,
#   450,
#   25,
#   325,
#   'Lojay, Sarz, Wizkid'],
#  'too faithful': [375, 51, 350, 450, 300, 325, 'Moses Bliss'],
#  'mandeman': [375, 420, 350, 168, 300, 325, 'Small Doctor'],
#  'monalisa': [3, 420, 3, 450, 17, 37, 'Lojay, Sarz'],
#  'motley crew': [375, 420, 350, 450, 77, 67, 'Post Malone'],
#  'big thug boys': [7, 5, 6, 450, 12, 19, 'AV'],
#  "it ain't me tiktok": [39, 420, 350, 450, 300, 325, 'Eduardo XD'],
#  'activate': [375, 420, 350, 159, 300, 325, 'Stonebwoy'],
#  'baba nla': [375, 74, 350, 155, 300, 325, 'Dr Dolor'],
#  'squander': [375, 96, 350, 450, 300, 325, 'Falz'],
#  'fem': [375, 420, 350, 110, 300, 325, 'Davido'],
#  'yafun yafun': [73, 420, 85, 140, 300, 325, 'Ajebo Hustlers'],
#  'triumphant': [375, 23, 350, 39, 300, 325, 'Olamide'],
#  'woo baby': [82, 420, 53, 450, 58, 28, 'Pop Smoke'],
#  'soundgasm': [11, 420, 10, 55, 9, 11, 'Rema'],
#  'there is a place': [375, 420, 350, 450, 300, 20, 'Nathaniel Bassey'],
#  'times two': [375, 420, 350, 218, 300, 325, 'WANI'],
#  'you': [375, 78, 350, 119, 300, 325, 'Omah Lay'],
#  'bout a million': [30, 420, 25, 450, 52, 325, 'Pop Smoke'],
#  'godly': [79, 20, 77, 56, 55, 16, 'Omah Lay'],
#  'pay day': [375, 420, 350, 87, 300, 325, 'Seyi Vibez'],
#  'only you': [375, 420, 350, 94, 300, 325, 'Bella Shmurda'],
#  'kilometre': [35, 16, 34, 33, 26, 60, 'Burna Boy'],
#  'symbiosis': [124, 420, 350, 214, 300, 325, 'Ajebo Hustlers'],
#  'peru': [104, 63, 107, 141, 110, 99, 'Fireboy DML'],
#  'happiness': [375, 420, 350, 122, 300, 325, 'Davolee'],
#  'ball till we fall': [375,
#   420,
#   350,
#   186,
#   300,
#   325,
#   'Kida Kudz featuring Bella Shmurda'],
#  'abule': [375, 50, 350, 142, 300, 48, 'Patoranking'],
#  'real shiii': [375, 420, 350, 450, 95, 325, 'Graimmy Thesoh'],
#  'back door': [96, 420, 90, 450, 300, 325, 'Pop Smoke'],
#  'somebody': [67, 38, 67, 49, 300, 325, 'Olamide'],
#  'project dreams': [375, 420, 350, 145, 300, 325, 'Roddy Ricch'],
#  'top shotta': [90, 420, 99, 450, 98, 325, 'Pop Smoke, The Neptunes'],
#  'astronaut in the ocean': [375, 420, 350, 450, 89, 84, 'Masked Wolf'],
#  'in my maserati': [375, 420, 350, 450, 300, 29, 'Olakira'],
#  'julie': [47, 28, 49, 28, 108, 32, 'Olamide'],
#  'at my worst': [375, 420, 350, 137, 136, 325, 'Pink Sweat$'],
#  'abu dhabi': [37, 66, 40, 450, 31, 94, 'Ruger'],
#  '30': [98, 420, 91, 450, 105, 325, 'Pop Smoke'],
#  'ngnp': [375, 92, 350, 450, 300, 325, 'Idowest'],
#  'genius': [95, 420, 89, 450, 99, 325, 'Pop Smoke, Lil Tjay, Swae Lee'],
#  'feeling': [5, 2, 5, 3, 8, 8, 'LADIPOE, Buju'],
#  'don dada': [375, 420, 350, 84, 300, 89, 'Timaya'],
#  'dior': [375, 420, 350, 450, 84, 325, 'Pop Smoke'],
#  'bad influence': [375, 68, 350, 85, 73, 325, 'Omah Lay'],
#  'waka waka': [375, 420, 350, 450, 300, 68, 'Shakira'],
#  'history': [45, 7, 46, 14, 36, 42, 'Cheque, Fireboy DML'],
#  'hello brother': [375, 420, 350, 170, 300, 325, 'Omah Lay'],
#  'afar': [375, 420, 350, 180, 300, 325, 'Fireboy DML & Olamide'],
#  'dimension': [19, 48, 18, 450, 20, 35, 'JAE5'],
#  'check yourself': [375, 39, 350, 450, 300, 325, 'Kaptain'],
#  'the box': [375, 420, 350, 136, 300, 325, 'Roddy Ricch'],
#  'solace': [122, 420, 350, 450, 300, 325, 'Ajebo Hustlers'],
#  'bank on it': [48, 94, 51, 450, 300, 325, 'Burna Boy'],
#  'unforgiving': [120, 420, 350, 450, 300, 325, 'Yung Bleu, Davido'],
#  'god sent': [375, 420, 350, 98, 300, 325, 'Seyi Vibez'],
#  'lo lo': [375, 84, 350, 194, 300, 325, 'Omah Lay'],
#  'are you sure': [375, 420, 350, 29, 300, 79, 'Lyta'],
#  'butter': [375, 420, 350, 450, 300, 83, 'BTS'],
#  'alone with you': [375, 420, 350, 222, 300, 325, 'Alina Baraz'],
#  'blessed': [34, 420, 31, 450, 65, 325, 'Wizkid'],
#  'money': [375, 420, 350, 30, 300, 325, 'Terri, Bella Shmurda, Mohbad'],
#  'demeanor': [100, 420, 94, 450, 92, 325, 'Pop Smoke'],
#  'born to win': [375, 420, 350, 190, 300, 325, 'Timaya'],
#  'liquor': [375, 420, 350, 86, 300, 325, 'Bella Shmurda'],
#  'if e happen for lagos': [375, 86, 350, 126, 300, 325, 'Runtown'],
#  'jafafa': [375, 420, 350, 158, 300, 325, 'Chinko Ekun & Mohbad'],
#  'let it go': [375, 420, 350, 450, 63, 44, 'TATY KISS'],
#  'ag baby': [375, 420, 350, 172, 300, 325, 'Adekunle Gold'],
#  'adura': [375, 69, 350, 95, 300, 325, 'Mohbad'],
#  'aiye': [375, 420, 350, 42, 300, 325, 'Barry Jhay'],
#  'merci beaucoup': [102, 420, 96, 450, 300, 325, 'Pop Smoke'],
#  'jo': [375, 420, 350, 146, 300, 325, 'Teni'],
#  'straightenin': [375, 420, 350, 450, 140, 325, 'Migos'],
#  'lagos anthem': [375, 77, 350, 450, 300, 325, 'Zlatan'],
#  'selfish': [375, 420, 350, 181, 300, 325, 'Tink & Yung Bleu'],
#  'omemma': [375, 31, 350, 450, 300, 325, 'Judikay'],
#  "you're welcome": [375, 420, 350, 450, 300, 56, 'Dwayne Johnson'],
#  'die young': [375, 420, 350, 134, 300, 325, 'Roddy Ricch'],
#  'doings': [375, 420, 350, 450, 300, 41, 'Flavour'],
#  'three rivers': [115, 420, 350, 450, 118, 325, 'Dave'],
#  'rock': [8, 4, 8, 4, 11, 14, 'Olamide'],
#  'infinity': [127, 12, 119, 61, 32, 325, 'Olamide'],
#  'prayer request': [375, 420, 350, 174, 300, 325, 'Victor AD'],
#  'professor peller': [130, 420, 350, 220, 300, 325, 'Seyi Vibez'],
#  'want': [375, 87, 350, 450, 300, 325, 'Olamide'],
#  'need for speed': [86, 18, 78, 22, 300, 325, 'Olamide'],
#  'what type of dance': [375, 420, 350, 171, 300, 325, 'DJ Kaywise '],
#  'forever': [43, 67, 41, 450, 22, 15, 'Gyakie, Omah Lay'],
#  'mr. jones': [76, 420, 45, 450, 97, 66, 'Pop Smoke'],
#  'woo baby interlude': [123, 420, 112, 450, 300, 325, 'Pop Smoke'],
#  'hell': [375, 420, 350, 167, 300, 325, 'corizo'],
#  'lako': [59, 71, 57, 32, 71, 325, 'Dangbana Republik, Bella Shmurda'],
#  'verdansk': [107, 420, 113, 450, 300, 325, 'Dave'],
#  'industry baby': [119, 420, 350, 450, 111, 325, 'Lil Nas X, Jack Harlow'],
#  'boom': [375, 420, 350, 212, 300, 325, 'Saucy Santana'],
#  'in the fire': [109, 420, 117, 450, 113, 325, 'Dave'],
#  'believer': [375, 420, 350, 450, 300, 92, 'Imagine Dragons'],
#  'dumptruck': [375, 420, 350, 202, 300, 325, '500raxx & TYGA'],
#  'kiss me more': [375, 420, 350, 450, 137, 325, 'Doja Cat, SZA'],
#  'yaba buluku': [44, 17, 44, 8, 16, 5, 'DJ Tarico, Burna Boy'],
#  'jehovah overdo': [375, 420, 350, 450, 300, 17, 'Chidinma'],
#  '40 btc': [375, 420, 350, 10, 300, 325, 'Rexxie featuring Seyi Vibez'],
#  'jennifer': [375, 27, 350, 450, 300, 3, 'Guchi'],
#  'ye ye ye': [375, 420, 350, 195, 300, 325, 'Omah Lay'],
#  'olorun agbaye': [375, 420, 350, 450, 300, 38, 'Nathaniel Bassey'],
#  'sere': [375, 420, 350, 185, 300, 325, 'Spinall, Fireboy DML and 6LACK'],
#  'coming': [22, 13, 22, 13, 21, 7, 'Naira Marley, Busiswa'],
#  'beat the speaker': [99, 420, 92, 450, 106, 325, 'Pop Smoke'],
#  'all': [72, 420, 73, 53, 43, 325, 'Rexxie'],
#  'understand': [1, 1, 1, 2, 6, 4, 'Omah Lay'],
#  'tonongo': [21, 420, 21, 97, 48, 325, 'Lojay, Sarz'],
#  'kokose': [375, 420, 350, 450, 300, 93, 'Sound Sultan & Wizkid'],
#  'celebration': [375, 420, 350, 128, 300, 325, 'Joeboy'],
#  'loved by you': [63, 420, 64, 450, 30, 325, 'Justin Bieber'],
#  'kilofeshe': [97, 420, 102, 43, 47, 325, 'Zinoleesky'],
#  'cultural praise': [375,
#   420,
#   350,
#   124,
#   300,
#   325,
#   'Kcee & Okwesili Eze Group'],
#  'take off': [375, 420, 350, 160, 300, 325, 'corizo'],
#  'tell the vision': [23, 98, 19, 450, 42, 74, 'Pop Smoke'],
#  'ginger me': [375, 420, 350, 70, 139, 325, 'Bella Shmurda'],
#  'mighty wine': [87, 420, 80, 450, 300, 325, 'Wizkid'],
#  'cup of tea': [375, 90, 350, 60, 300, 325, 'Olamide'],
#  'runaway': [375, 420, 350, 450, 78, 325, 'AURORA'],
#  'aye': [375, 75, 350, 450, 300, 96, 'Davido'],
#  'picture freestyle': [375, 420, 350, 82, 300, 325, 'Seyi Vibez'],
#  'cho cho': [375, 420, 350, 63, 300, 88, 'Zlatan'],
#  'calling my phone': [375, 420, 350, 450, 93, 325, 'Lil Tjay, 6lack'],
#  'your body': [375, 420, 350, 129, 300, 325, 'Mayorkun'],
#  'sorry': [375, 420, 350, 57, 300, 325, 'MohBad'],
#  'fear nobody': [375,
#   420,
#   350,
#   227,
#   300,
#   325,
#   'Demide featuring Bella Shmurda'],
#  'happy birthday': [375,
#   420,
#   350,
#   182,
#   300,
#   325,
#   'Simi feat. Adekunle Gold and Deja'],
#  'no stress': [74, 420, 72, 93, 300, 325, 'Wizkid'],
#  'mothaland': [375, 420, 350, 450, 300, 54, 'Sound Sultan & Johnny Drille'],
#  'berna reloaded': [375, 420, 350, 450, 300, 51, 'Flavour'],
#  'ameno': [375, 37, 350, 450, 300, 39, 'ERA'],
#  'good news': [81, 420, 47, 450, 90, 325, 'Pop Smoke'],
#  'freaky': [375, 420, 350, 196, 300, 325, 'Hotkid'],
#  'brush em': [89, 420, 81, 450, 96, 325, 'Pop Smoke'],
#  'onemmenma': [375, 420, 350, 450, 300, 72, 'Mercy Chinwo & Chioma Jesus'],
#  "survivor's guilt": [118, 420, 350, 450, 300, 325, 'Dave'],
#  'ayewada': [375, 420, 350, 27, 300, 325, 'Barry Jhay'],
#  'rich and blind': [375, 420, 350, 166, 300, 325, 'Juice WRLD'],
#  'pepe': [375, 36, 350, 112, 100, 325, 'L.A.X & Davido'],
#  'cash app': [111, 54, 101, 59, 300, 31, 'Bella Shmurda, Zlatan, Lincoln'],
#  'hood scars 2': [375,
#   420,
#   350,
#   197,
#   300,
#   325,
#   'J.I the Prince of N.Y & Lil Tjay'],
#  'la la': [31, 420, 33, 450, 59, 27, 'Davido'],
#  'money man': [375, 420, 350, 217, 300, 325, 'Malcolm Nuna'],
#  'injure me': [75, 34, 76, 20, 300, 325, 'Teni'],
#  'dangbana orisa': [375, 420, 350, 101, 300, 325, 'Bella Shmurda'],
#  'so lovely': [375, 420, 350, 74, 300, 325, 'Buju'],
#  'breakup riddim': [375, 81, 350, 450, 300, 325, 'DJ Aroma'],
#  'boi boi': [375, 420, 350, 113, 300, 325, 'Rexxie featuring Teni'],
#  '90’s': [375, 420, 350, 40, 300, 325, 'Seyi Vibez'],
#  'peaches': [128, 64, 120, 450, 57, 87, 'Justin Bieber'],
#  'wonderful': [375, 420, 350, 130, 300, 325, 'Burna Boy']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in e:
        keys[x] = e1[e.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    if k in f:
        keys[x] = f1[f.index(k)]
    if k in d:
        keys[x] = d1[d.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 353

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
post7 = [x[6] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x] + post6[x])/6 for x in range(0, 353)]

# %%
data = {'song':song,'artist':post7,'apple':post1,'boom':post2,'spotify':post3,'audiomack':post4, 'deezer':post5, 'youtube':post6,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,354)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:100]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv('week29-hot100.csv')
df.to_csv('week29csv')

# %%
df
# Out:
#                           song                     artist  apple  boom  \
# rank
# 1                   Understand                   Omah Lay      1     1
# 2                      Feeling              LADIPOE, Buju      5     2
# 3                         Rock                    Olamide      8     4
# 4                      Outside                       Buju      4     8
# 5                       Sinner  Adekunle Gold, Lucky Daye      9    26
# ...                        ...                        ...    ...   ...
# 349      Red Light Green Light                     DaBaby    375   420
# 350                       Away                 Ayra Starr    375   420
# 351   Kiss Me More (feat. SZA)              Doja Cat, SZA    375   420
# 352                      Oh No                    Alpha P    375   420
# 353               Straightenin                      Migos    375   420
#
#       spotify  audiomack  deezer  youtube          RT
# rank
# 1           1          2       6        4    2.500000
# 2           5          3       8        8    5.166667
# 3           8          4      11       14    8.166667
# 4           4          7      10       26    9.833333
# 5          11          9      13       10   13.000000
# ...       ...        ...     ...      ...         ...
# 349       350        450     104      325  337.333333
# 350       350        450     109      325  338.166667
# 351       350        450     137      325  342.833333
# 352       350        450     138      325  343.000000
# 353       350        450     140      325  343.333333
#
# [353 rows x 9 columns]

# %%
df2 = pd.read_csv('week28-hot100.csv')

# %%
a = list(df2['song'])
a1 = a.copy()
x = 0
for i in a:
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df1['song'])
b1 = b.copy()
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
song = []
for x in b:
    if x in a:
        song.append(a1[a.index(x)])
    else:
        song.append(b1[b.index(x)])

# %%
df1['song'] = song

# %%
a = list(df2['song'])
b = list(df1['song'])
c = list(df2['weeks on chart'])
prev = []
weeks = []
for x in b:
    if x in a:
        prev.append(a.index(x) + 1)
        weeks.append(c[a.index(x)] + 1)
    else:
        prev.append(0)
        weeks.append(1)
df1['Previous week'] = prev
df1['weeks on chart'] = weeks

# %%
df1.to_csv('week29-hot100.csv')
df1.to_csv('C:\\Users\\faree\\Desktop\\music charts\\weekly charts\\weekly\\hot100.csv')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\docs\\hot100.json')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\week29\\hot100.json')

# %%
df1
# Out:
#             song                     artist  Previous week  weeks on chart
# rank
# 1     Understand                   Omah Lay              1               3
# 2        Feeling              LADIPOE, Buju              6              10
# 3           Rock                    Olamide             22              10
# 4        Outside                       Buju              2              10
# 5         Sinner  Adekunle Gold, Lucky Daye              3               2
# ...          ...                        ...            ...             ...
# 96    Triumphant                    Olamide            100               9
# 97     Good News                  Pop Smoke              0               1
# 98      Reckless                     Wizkid             99               5
# 99       RAPSTAR                     Polo G             96              10
# 100    Enjoyment                 Yemi Alade              0               1
#
# [100 rows x 4 columns]

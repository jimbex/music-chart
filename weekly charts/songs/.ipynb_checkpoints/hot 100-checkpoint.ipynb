# %%
import pandas as pd
df1 = pd.read_csv('apple-week20.csv')
df2 = pd.read_csv('boom-week20.csv')
df3 = pd.read_csv('spotify-week20.csv')
df4 = pd.read_csv('youtube-week20.csv')

# %%
df4
# Out:
#     Rank  Previous Rank                                  song  \
# 0      1            NaN                                  Rock
# 1      2            3.0                      Running (To You)
# 2      3            1.0                    La La (feat. CKay)
# 3      4            2.0                        Jehovah Overdo
# 4      5            4.0                       Forever (Remix)
# ..   ...            ...                                   ...
# 95    96           43.0  THANKFUL (feat. Lil Wayne & Jeremih)
# 96    97           92.0              Squander (feat. Niniola)
# 97    98           80.0                              Gani Aso
# 98    99           60.0     Cho Cho (feat. Davido & Mayorkun)
# 99   100           90.0             Nesesari (feat. Philkeyz)
#
#                artist  Weeks on Chart   Views Weekly Growth  \
# 0             Olamide               1  225246           NaN
# 1        Chike & Simi              14  179250         7.20%
# ...

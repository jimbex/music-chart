# %%
import pandas as pd

df1 = pd.read_csv('week20.csv')
df2 = pd.read_csv('week21.csv')
df3 = pd.read_csv('week22.csv')
df4 = pd.read_csv('week23.csv')
df5 = pd.read_csv('week24.csv')
df6 = pd.read_csv('week25.csv')
df7 = pd.read_csv('week26.csv')
df8 = pd.read_csv('week27.csv')
df9 = pd.read_csv('week28.csv')
df = pd.read_csv('week29.csv')

# %%
import matplotlib.pyplot as plt

# %%
a = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df]
b = ['week19','week20','week21','week22','week23','week24','week25','week26','week27','week28','week29']
c = [1]
for x in a:
    c.append(list(x['song']).index('Feeling') + 1)

# %%
plt.yticks(range(100,1,-2))
plt.figure(figsize=(10, 5))
display(plt.plot(b,c))

# %%
plt.plot(b,c)

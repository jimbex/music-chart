# %%
import pandas as pd
from datetime import datetime
m = datetime.today().strftime('%B')
d = datetime.today().strftime('%d')
w = datetime.today().strftime('%V')
w = int(w)
d = int(d)

# %%
df1 = pd.read_csv(f'apple-week{w}.csv', encoding='utf-8')
df2 = pd.read_csv(f'audiomack-week{w}.csv', encoding='utf-8')
df3 = pd.read_csv(f'youtube-week{w}.csv', encoding='utf-8')
df4 = pd.read_csv(f'boom_week{w}.csv', encoding='utf-8')
df5 = pd.read_csv(f'spotify-week{w}.csv', encoding='utf-8')
df6 = pd.read_csv(f'deezer-week{w}.csv', encoding='utf-8')

# %%
df3['song'] = df3['Track Name']
df3['artist'] = df3['Artist Names']

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]
df4 = df4[['song', 'artist']]
df5 = df5[['song', 'artist']]
df6 = df6[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    i = i.lower()
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft')
    if '[' in i:
        a[x] = a[x].replace('[', '(')
    if 'feat' in i:
        a[x] = a[x].replace('feat', '(feat')
    if 'remix' in i:
        a[x] = a[x].replace('remix', '(remix')
    if '  ' in i:
        a[x] = a[x].replace('  ', ' ')
    if '(' in a[x]:
        a[x] = a[x][: a[x].index('(')]
    if '\\' in i:
        a[x] = a[x].replace('\\', '') 
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    i = i.lower()
    if 'remix' in i:
        b[x] = i.replace('remix', '(remix')
    if 'ft' in i:
        b[x] = b[x].replace('ft', '(ft')
    if '[' in i:
        b[x] = b[x].replace('[', '(')
    if 'feat' in i:
        b[x] = b[x].replace('feat', '(feat')
    if '  ' in i:
        b[x] = b[x].replace('  ', ' ')
    if '(' in b[x]:
        b[x] = b[x][: b[x].index('(')]
    if '\\' in i:
        b[x] = b[x].replace('\\', '') 
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    i = i.lower()
    if 'ft' in i:
        c[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        c[x] = c[x].replace('feat', '(feat')
    if '[' in i:
        c[x] = c[x].replace('[', '(')
    if 'remix' in i:
        c[x] = c[x].replace('remix', '(remix')
    if '  ' in i:
        c[x] = c[x].replace('  ', ' ')
    if '(' in c[x]:
        c[x] = c[x][: c[x].index('(')]
    if '\\' in i:
        c[x] = c[x].replace('\\', '')  
    c[x] = c[x].strip().lower()
    x += 1

# %%
d = list(df4['song'])
d1 = d.copy()
d2 = list(df4['artist'])
x = 0
for i in d:
    i = i.lower()
    if 'ft' in i:
        d[x] = i.replace('ft', '(ft') + ')'
    if 'feat' in i:
        d[x] = d[x].replace('feat', '(feat')
    if '[' in i:
        d[x] = d[x].replace('[', '(')
    if 'remix' in i:
        d[x] = d[x].replace('remix', '(remix')
    if '  ' in d[x]:
        d[x] = d[x].replace('  ', ' ')
    x += 1
x = 0
for i in d:
    if '(' in i:
        d[x] = i[: i.index('(')]
    if '\\' in i:
        d[x] = d[x].replace('\\', '') 
    d[x] = d[x].strip().lower()
    x += 1

# %%
e = list(df5['song'])
e1 = e.copy()
e2 = list(df5['artist'])
x = 0
for i in e:
    i = i.lower()
    if 'ft' in i:
        e[x] = e[x].replace('ft', '(ft')
    if 'feat' in i:
        e[x] = e[x].replace('feat', '(feat')
    if '[' in i:
        e[x] = e[x].replace('[', '(')
    if 'remix' in i:
        e[x] = e[x].replace('remix', '(remix')
    if '  ' in i:
        e[x] = e[x].replace('  ', ' ')
    if '(' in e[x]:
        e[x] = e[x][: e[x].index('(')]
    if '\\' in i:
        e[x] = e[x].replace('\\', '') 
    e[x] = e[x].strip().lower()
    x += 1

# %%
f = list(df6['song'])
f1 = f.copy()
f2 = list(df6['artist'])
x = 0
for i in f:
    i = i.lower()
    if 'ft' in i:
        f[x] = f[x].replace('ft', '(ft')
    if 'feat' in i:
        f[x] = f[x].replace('feat', '(feat')
    if '[' in i:
        f[x] = f[x].replace('[', '(')
    if 'remix' in i:
        f[x] = f[x].replace('remix', '(remix')
    if '  ' in i:
        f[x] = f[x].replace('  ', ' ')
    if '(' in f[x]:
        f[x] = f[x][: f[x].index('(')]
    if '\\' in i:
        f[x] = f[x].replace('\\', '') 
    f[x] = f[x].strip().lower()
    x += 1

# %%
songs = a + b + c + d + e + f
songs = set(songs)

# %%
len(songs)
# Out:
# 340

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [375]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(420)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(350)

# %%
x = 0
for i in songs:
    if i in d:
        final[i].append(d.index(i) + 1)
    else:
        final[i].append(450)

# %%
x = 0
for i in songs:
    if i in e:
        final[i].append(e.index(i) + 1)
    else:
        final[i].append(300)

# %%
x = 0
for i in songs:
    if i in f:
        final[i].append(f.index(i) + 1)
    else:
        final[i].append(325)

# %%
x = 0
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    if i in d and len(final[i]) < 7:
        final[i].append(d2[d.index(i)])
    if i in f and len(final[i]) < 7:
        final[i].append(f2[f.index(i)])
    if i in b and len(final[i]) < 7:
        final[i].append(b2[b.index(i)])
    if i in c and len(final[i]) < 7:
        final[i].append(c2[c.index(i)])
    if i in e and len(final[i]) < 7:
        final[i].append(e2[e.index(i)])
    x += 1

# %%
final
# Out:
# {'confident': [14, 15, 58, 450, 12, 45, 'Savage and  Buju'],
#  'naira marley': [18, 8, 67, 19, 16, 41, 'Zinoleesky'],
#  'cup of tea': [375, 68, 350, 450, 300, 325, 'Olamide'],
#  'out there': [41,
#   12,
#   350,
#   450,
#   39,
#   75,
#   'Dangbana Republik and  Bella Shmurda'],
#  'pray': [102, 420, 350, 450, 300, 113, 'Victony'],
#  'reckless': [74, 420, 350, 450, 70, 325, 'Wizkid'],
#  'ginger': [38, 45, 42, 450, 37, 40, 'Wizkid'],
#  'in the fire': [28, 420, 350, 450, 24, 61, 'Dave'],
#  'let it go': [375, 420, 350, 450, 300, 67, 'DJ Khaled'],
#  'take off': [375, 177, 350, 450, 300, 325, 'corizo'],
#  'black': [375, 227, 350, 21, 300, 325, 'Victor AD'],
#  'abu dhabi': [36, 420, 85, 59, 38, 15, 'Ruger'],
#  'professor peller': [57, 163, 350, 46, 54, 325, 'Seyi Vibez'],
#  'shopping spree': [95, 141, 7, 450, 87, 325, 'Davido'],
#  'project dreams': [375, 147, 350, 450, 300, 325, 'Roddy Ricch'],
#  'holy ground': [375, 115, 350, 450, 300, 325, 'Davido'],
#  'lazarus': [10, 420, 91, 450, 7, 39, 'Dave and  Boj'],
#  'bloody samaritan': [103, 218, 350, 450, 300, 105, 'Ayra Starr'],
#  'what type of dance': [375, 193, 350, 450, 300, 325, 'DJ Kaywise '],
#  'call me baby': [51, 11, 350, 30, 44, 97, 'Cheque'],
#  'rock': [15, 4, 14, 4, 14, 33, 'Olamide'],
#  'yafun yafun': [63, 112, 350, 450, 60, 66, 'Ajebo Hustlers'],
#  'heart attack': [42, 420, 350, 450, 35, 35, 'Dave'],
#  'l.u.s': [375, 206, 350, 450, 300, 325, 'BJ The Chicago Kid'],
#  'high fashion': [375, 188, 350, 450, 300, 325, 'Roddy Ricch'],
#  'hood scars 2': [375,
#   199,
#   350,
#   450,
#   300,
#   325,
#   'J.I the Prince of N.Y & Lil Tjay'],
#  'permission to dance': [375, 420, 59, 450, 300, 325, 'BTS'],
#  'okay': [375, 420, 46, 450, 300, 325, 'Adekunle Gold'],
#  'motley crew': [375, 420, 350, 450, 300, 83, 'Post Malone'],
#  'amope': [375, 117, 350, 450, 300, 325, 'Bella Shmurda'],
#  'oliver twist': [85, 420, 81, 450, 83, 13, 'ArrDee'],
#  'in summer': [375, 420, 75, 450, 300, 325, 'Josh Gad'],
#  'unconditionally': [76, 420, 350, 95, 74, 325, 'Ajebutter 22 and  Oxlade'],
#  'ginger me': [375, 76, 350, 450, 300, 325, 'Bella Shmurda'],
#  'symphony': [375, 150, 350, 450, 300, 325, 'Seyi Vibez'],
#  'party next door': [22,
#   420,
#   55,
#   450,
#   21,
#   56,
#   'Dangbana Republik and  Bella Shmurda'],
#  'kilofeshe': [90, 47, 350, 450, 88, 49, 'Zinoleesky'],
#  'felony': [47, 54, 350, 82, 49, 9, 'CKay'],
#  'baba fela': [375, 420, 350, 65, 300, 325, 'Mr Real'],
#  'too faithful': [375, 420, 350, 56, 300, 325, 'Moses Bliss'],
#  'sho mo mi': [375, 63, 350, 450, 300, 325, 'Bella Shmurda'],
#  'zoom': [375, 146, 350, 450, 300, 325, 'Cheque'],
#  'coming': [34, 18, 11, 16, 34, 11, 'Naira Marley and  Busiswa'],
#  'the best': [69, 81, 350, 99, 67, 89, 'Davido'],
#  'if e happen for lagos': [375, 122, 350, 84, 300, 325, 'Runtown'],
#  'feeling': [9, 3, 8, 2, 8, 4, 'LADIPOE and  Buju'],
#  'god sent': [375, 86, 350, 450, 300, 325, 'Seyi Vibez'],
#  'bad type': [375, 51, 350, 450, 300, 325, 'Seyi Vibez'],
#  'lit like this': [108, 420, 350, 450, 300, 116, 'Skepta'],
#  'survive': [375, 113, 350, 62, 300, 325, 'Jaido P'],
#  'pay day': [375, 88, 350, 450, 300, 325, 'Seyi Vibez'],
#  'lenu': [375, 66, 350, 450, 300, 325, 'Buju'],
#  'bad habits': [375, 420, 92, 450, 300, 73, 'Ed Sheeran'],
#  'dangbana orisa': [375, 105, 350, 450, 300, 325, 'Bella Shmurda'],
#  'dior': [375, 420, 350, 450, 300, 85, 'Pop Smoke'],
#  'peaches': [375, 420, 87, 75, 300, 69, 'Justin Bieber'],
#  'bling': [24, 24, 45, 450, 23, 53, 'Blaqbonez'],
#  'vision 2020': [375, 78, 350, 450, 300, 325, 'Bella Shmurda'],
#  'fear nobody': [375,
#   178,
#   350,
#   450,
#   300,
#   325,
#   'Demide featuring Bella Shmurda'],
#  'all in': [375, 420, 350, 450, 300, 118, 'Nasty C'],
#  'airplane mode': [375, 107, 350, 98, 300, 325, 'Fireboy DML'],
#  'medicine': [20, 420, 43, 10, 19, 17, 'Jaywillz'],
#  'new normal': [375, 420, 100, 450, 300, 115, 'Khalid'],
#  'damages': [375, 121, 350, 450, 300, 82, 'Tems'],
#  'bless boys': [375, 420, 350, 68, 300, 325, 'Victor AD'],
#  'kilometre': [50, 39, 65, 24, 50, 18, 'Burna Boy'],
#  'jireh': [375,
#   420,
#   54,
#   450,
#   300,
#   325,
#   'Elevation Worship & Maverick City Music'],
#  'so wrong': [375, 197, 350, 450, 300, 325, 'DayOnTheTrack'],
#  'bank on it': [60, 420, 98, 94, 56, 325, 'Burna Boy'],
#  'boi boi': [375, 129, 350, 450, 300, 325, 'Rexxie featuring Teni'],
#  'system': [2, 420, 26, 32, 97, 6, 'Dave and  Wizkid'],
#  'muje': [375, 102, 350, 450, 300, 325, 'Barry Jhay'],
#  'calling my phone': [375, 420, 350, 450, 300, 100, 'Lil Tjay'],
#  'omemma': [375, 420, 350, 43, 300, 325, 'Judikay'],
#  'hustle': [40, 420, 15, 20, 40, 52, 'Teni'],
#  'legends': [375, 120, 350, 450, 300, 325, 'Juice WRLD'],
#  'smile': [375, 114, 350, 450, 300, 325, 'Wizkid'],
#  'temple': [375, 180, 350, 450, 300, 325, 'ALOMA'],
#  'liquor': [375, 90, 350, 450, 300, 325, 'Bella Shmurda'],
#  'verdansk': [23, 420, 350, 450, 20, 59, 'Dave'],
#  'cho cho': [375, 71, 350, 450, 300, 325, 'Zlatan'],
#  "can't relate": [375, 116, 350, 44, 300, 325, 'Omah Lay'],
#  'omo x 100': [375, 55, 350, 450, 300, 98, 'Reminisce'],
#  'early momo': [64, 99, 74, 450, 62, 90, 'Vector'],
#  'currently': [375, 145, 350, 450, 300, 325, 'Kizz Daniel'],
#  'good woman': [375, 420, 70, 450, 300, 325, 'Flavour'],
#  'jennifer': [375, 420, 5, 33, 300, 325, 'GUCHI'],
#  'big thug boys': [12, 420, 19, 6, 11, 32, 'AV'],
#  'infinity': [375, 61, 350, 15, 300, 55, 'Olamide'],
#  'history': [58, 13, 50, 8, 55, 28, 'Cheque and  Fireboy DML'],
#  'pronto': [33, 37, 350, 81, 32, 21, 'Ajebo Hustlers and  Omah Lay'],
#  'door': [375, 98, 82, 38, 300, 325, 'Joeboy'],
#  'animalistic': [375, 198, 350, 450, 300, 325, 'Kida Kudz'],
#  'go away': [375, 164, 350, 450, 300, 325, 'Fireboy DML'],
#  'if you no love': [375, 132, 350, 70, 300, 325, 'Chike'],
#  'the box': [375, 140, 350, 450, 300, 325, 'Roddy Ricch'],
#  'fem': [375, 119, 350, 450, 300, 325, 'Davido'],
#  'mandeman': [375, 192, 350, 450, 300, 325, 'Small Doctor'],
#  'astronaut in the ocean': [375, 420, 97, 450, 300, 86, 'Masked Wolf'],
#  'ruger': [375, 420, 76, 450, 300, 95, 'Ruger'],
#  'gone girl': [96, 420, 350, 450, 90, 99, 'Obongjayar and  Sarz'],
#  'symbiosis': [97, 152, 350, 450, 91, 325, 'Ajebo Hustlers'],
#  'jehovah overdo': [375, 420, 17, 450, 300, 325, 'Chidinma'],
#  'rockstar': [375, 420, 350, 450, 300, 81, 'DaBaby'],
#  'in my maserati': [375, 420, 28, 450, 300, 325, 'Olakira'],
#  'twenty to one': [35, 420, 350, 450, 30, 62, 'Dave'],
#  'life is good': [375, 148, 350, 450, 300, 325, 'Future'],
#  'olofofo': [375, 35, 350, 26, 300, 325, 'Victor AD'],
#  'eli': [375, 191, 350, 450, 300, 325, 'Fireboy DML'],
#  'loved by you': [72, 420, 350, 450, 68, 23, 'Justin Bieber'],
#  'lonely': [375, 82, 350, 66, 300, 325, 'Joeboy'],
#  'yahweh': [375, 420, 95, 450, 300, 325, 'Mercy Chinwo'],
#  'tonongo': [32, 97, 350, 450, 31, 46, 'Lojay and  Sarz'],
#  'clash': [13, 420, 49, 450, 9, 7, 'Dave and  Stormzy'],
#  'ile aye': [375, 420, 350, 450, 300, 106, 'Josseyan-tizzy'],
#  'montero': [375, 420, 36, 450, 300, 50, 'Lil Nas X'],
#  'lukuti': [375, 420, 53, 450, 300, 325, 'DJ AB'],
#  'real life': [80, 109, 350, 450, 76, 117, 'Burna Boy'],
#  'jailer': [61, 22, 350, 54, 58, 103, 'Olamide'],
#  'peru': [7, 7, 35, 3, 5, 37, 'Fireboy DML'],
#  'non living thing': [375, 226, 350, 450, 300, 325, 'Sarkodie'],
#  'blessed': [44, 420, 350, 450, 43, 79, 'Wizkid'],
#  'jafafa': [375, 172, 350, 450, 300, 325, 'Chinko Ekun & Mohbad'],
#  'know you': [375, 189, 350, 450, 300, 325, 'Ladipoe'],
#  'ye ye ye': [375, 160, 350, 450, 300, 325, 'Omah Lay'],
#  'hallelu': [78, 41, 44, 450, 75, 24, 'Masterkraft'],
#  'way too big': [68, 74, 350, 51, 66, 325, 'Burna Boy'],
#  'roju': [375, 420, 25, 55, 300, 325, 'Chike'],
#  'kpk': [375, 84, 39, 450, 300, 48, 'Rexxie'],
#  'all mine': [375, 225, 350, 450, 300, 325, 'Kinsolo'],
#  'confession': [375, 161, 350, 78, 300, 325, 'Omah Lay'],
#  'afar': [375, 194, 350, 450, 300, 325, 'Fireboy DML & Olamide'],
#  'la la': [49, 420, 40, 450, 48, 72, 'Davido'],
#  'world': [46, 46, 350, 450, 42, 74, 'Dangbana Republik and  Bella Shmurda'],
#  'sere': [375, 213, 350, 450, 300, 325, 'Spinall, Fireboy DML and 6LACK'],
#  'see you next week': [375, 207, 350, 450, 300, 325, 'Dremo'],
#  'ma pariwo': [375, 93, 350, 450, 300, 325, 'Zinoleesky'],
#  'ponmo': [375, 111, 350, 450, 300, 325, 'Mohbad'],
#  'celebrate me': [62, 20, 21, 22, 59, 71, 'Patoranking'],
#  'loading': [375, 126, 350, 60, 300, 325, 'Olamide'],
#  'industry baby': [26, 420, 2, 89, 25, 5, 'Lil Nas X and  Jack Harlow'],
#  'times two': [375, 62, 350, 450, 300, 325, 'WANI'],
#  'omalicha': [375, 124, 350, 37, 300, 325, 'Kolaboy'],
#  'moslado': [375, 130, 350, 450, 300, 325, 'Teni'],
#  'destructo': [375, 420, 350, 450, 300, 107, 'Diamondxx'],
#  'unforgiving': [99, 420, 78, 450, 93, 325, 'Yung Bleu and  Davido'],
#  'fall for me': [375, 118, 350, 450, 300, 325, 'Laycon'],
#  'my bebe': [375, 125, 350, 64, 300, 325, 'Omah Lay'],
#  '23': [59, 67, 350, 67, 57, 70, 'Burna Boy'],
#  'triumphant': [375, 43, 350, 23, 300, 325, 'Olamide'],
#  'bellator': [107, 420, 350, 450, 300, 110, 'Skepta'],
#  'marlians anthem': [375, 110, 350, 450, 300, 325, 'MohBad'],
#  'rapstar': [83, 420, 350, 450, 80, 34, 'Polo G'],
#  'lagos anthem': [375, 211, 350, 87, 300, 325, 'Zlatan'],
#  'nirvana': [106, 210, 350, 450, 300, 108, 'Skepta and  J Balvin'],
#  'true love': [111, 420, 350, 450, 103, 325, 'Wizkid'],
#  'music messiah': [375, 133, 350, 90, 300, 325, 'DJ Neptune'],
#  'colorado': [375, 70, 350, 450, 300, 325, 'Zugo'],
#  "you're welcome": [375, 420, 62, 450, 300, 325, 'Dwayne Johnson'],
#  'lv n attn': [37, 155, 350, 450, 36, 10, 'Lojay and  Sarz'],
#  'heartbreak anniversary': [375, 420, 350, 450, 300, 91, 'Giveon'],
#  'berna reloaded': [375, 420, 57, 450, 300, 325, 'Flavour'],
#  'only you': [375, 101, 350, 450, 300, 325, 'Bella Shmurda'],
#  'peace of mind': [105, 420, 350, 450, 300, 112, 'Skepta'],
#  'ameno': [375, 420, 68, 47, 300, 325, 'Dj Xclusive'],
#  "i didn't change my number": [375, 420, 350, 450, 300, 121, 'Billie Eilish'],
#  'blu boyz': [375,
#   205,
#   350,
#   450,
#   300,
#   325,
#   'Young Dolph, Key Glock, Paper Route EMPIRE'],
#  'sinner': [3, 5, 1, 14, 1, 3, 'Adekunle Gold and  Lucky Daye'],
#  'bout a million': [93, 420, 350, 450, 79, 92, 'Pop Smoke'],
#  'no stress': [89, 96, 350, 450, 89, 325, 'Wizkid'],
#  'forever': [56, 420, 16, 79, 53, 14, 'Gyakie and  Omah Lay'],
#  'spell': [375, 187, 350, 450, 300, 325, 'Fireboy DML & Wande Coal'],
#  'jealous': [375, 42, 350, 450, 300, 325, 'Alikiba'],
#  'somebody': [375, 58, 350, 50, 300, 325, 'Olamide'],
#  'at my worst': [375, 149, 350, 450, 300, 325, 'Pink Sweat$'],
#  'ability': [375, 224, 350, 450, 300, 325, 'jaywon'],
#  'omo ologo': [375, 95, 350, 450, 300, 325, 'Lil Frosh featuring Zinoleesky'],
#  'over the top': [375, 143, 350, 450, 300, 325, 'Smiley'],
#  'enjoyment': [375, 135, 350, 450, 300, 325, 'Yemi Alade'],
#  'paloma': [375, 420, 6, 450, 300, 325, 'Mr. P & --'],
#  'dorime': [109, 219, 350, 450, 300, 325, 'Teni'],
#  'hell': [375, 176, 350, 450, 300, 325, 'corizo'],
#  'injure me': [88, 28, 350, 48, 84, 325, 'Teni'],
#  'damn': [375, 151, 350, 450, 300, 325, 'Omah Lay featuring 6LACK'],
#  'ori': [375, 87, 350, 450, 300, 325, 'Barry Jhay'],
#  'from the garden': [375, 220, 350, 450, 300, 325, 'Isaiah Rashad'],
#  'running': [81, 26, 10, 27, 77, 64, 'Chike and  Simi'],
#  'sai dake': [375, 420, 94, 450, 300, 325, 'Hamisu Breaker'],
#  'need for speed': [375, 25, 350, 31, 300, 325, 'Olamide'],
#  'anymore': [375, 222, 350, 450, 300, 325, 'Victor AD'],
#  'three rivers': [39, 420, 350, 450, 33, 30, 'Dave'],
#  'rise up': [375, 17, 30, 13, 300, 325, '2Baba'],
#  'woman': [375, 167, 350, 450, 300, 325, 'Rema'],
#  'going up': [375, 208, 350, 450, 300, 325, 'YXNG K.A'],
#  'leave the door open': [375, 420, 350, 450, 300, 93, 'Bruno Mars'],
#  'godly': [91, 57, 18, 25, 92, 65, 'Omah Lay'],
#  'p r i d e . i s . t h e . d e v i l': [375,
#   420,
#   350,
#   450,
#   300,
#   122,
#   'J. Cole'],
#  'getting older': [375, 420, 350, 450, 300, 109, 'Billie Eilish'],
#  'onemmenma': [375, 420, 66, 450, 300, 325, 'Mercy Chinwo & Chioma Jesus'],
#  'solace': [48, 420, 350, 450, 45, 102, 'Ajebo Hustlers'],
#  'joanna': [375, 215, 350, 450, 300, 325, 'Victor AD'],
#  'coupe': [375, 420, 86, 450, 300, 325, 'Pop Smoke'],
#  'my heart': [375, 420, 71, 450, 300, 325, 'Naomi Mac'],
#  'activate': [375, 174, 350, 450, 300, 325, 'Stonebwoy'],
#  'soldier go': [79,
#   34,
#   350,
#   450,
#   72,
#   114,
#   'Dangbana Republik and  Bella Shmurda'],
#  'essence': [19, 27, 9, 34, 17, 47, 'Wizkid'],
#  'don dada': [375, 85, 77, 450, 300, 325, 'Timaya'],
#  'lako': [82, 36, 350, 450, 78, 325, 'Dangbana Republik and  Bella Shmurda'],
#  'love like this': [375, 420, 350, 61, 300, 325, 'Lil Kesh'],
#  'your body': [375, 142, 350, 450, 300, 325, 'Mayorkun'],
#  'green light': [375, 169, 350, 93, 300, 325, 'Olamide'],
#  "it ain't me tiktok": [52, 420, 350, 450, 300, 325, 'Eduardo XD'],
#  'outside': [8, 6, 24, 9, 6, 29, 'Buju'],
#  'something different': [375, 166, 350, 450, 300, 325, 'Adekunle Gold'],
#  'cash app': [375, 60, 34, 76, 300, 325, 'Bella Shmurda'],
#  'spiritual': [375, 100, 350, 450, 300, 325, 'Buju'],
#  'hello brother': [375, 185, 350, 450, 300, 325, 'Omah Lay'],
#  'somebody baby': [67, 56, 90, 450, 63, 26, 'Davido and  Peruzzi'],
#  'maserati': [375, 203, 350, 450, 300, 325, 'Olakira'],
#  'chi chi': [375, 106, 350, 450, 300, 325, 'Naira Marley'],
#  'check yourself': [375, 420, 350, 49, 300, 325, 'Kaptain'],
#  'body': [77, 92, 56, 450, 73, 38, 'Tion Wayne and  Russ Millions'],
#  'cultural praise': [375,
#   136,
#   350,
#   450,
#   300,
#   325,
#   'Kcee & Okwesili Eze Group'],
#  'freaky': [375, 201, 350, 450, 300, 325, 'Hotkid'],
#  'soundgasm': [17, 64, 13, 450, 15, 8, 'Rema'],
#  'late at night': [65, 69, 350, 450, 61, 77, 'Roddy Ricch'],
#  'rest on kashy': [375, 156, 350, 450, 300, 325, 'Anonymous Music'],
#  'prayer request': [375, 184, 350, 450, 300, 325, 'Victor AD'],
#  'this your body': [375, 175, 350, 74, 300, 325, 'Skales'],
#  "don't go yet": [375, 420, 73, 450, 300, 325, 'Camila Cabello'],
#  'feel good': [11, 1, 60, 12, 10, 42, 'MohBad'],
#  'abule': [375, 153, 47, 57, 300, 325, 'Patoranking'],
#  'capable god': [375, 420, 350, 45, 300, 325, 'Judikay'],
#  'both sides of a smile': [31, 420, 350, 450, 26, 16, 'Dave and  James Blake'],
#  'dimension': [27, 420, 37, 96, 27, 57, 'JAE5'],
#  'stay': [375, 420, 84, 450, 300, 27, 'The Kid Laroi'],
#  'flex': [375, 186, 350, 450, 300, 325, 'Kizz Daniel'],
#  'skate': [375,
#   223,
#   350,
#   450,
#   300,
#   325,
#   'Bruno Mars, Anderson .Paak, Silk Sonic'],
#  'ke star': [53, 44, 27, 450, 51, 20, 'Focalistic and  Davido'],
#  'rich and blind': [375, 165, 350, 450, 300, 325, 'Juice WRLD'],
#  'ag baby': [375, 171, 350, 450, 300, 325, 'Adekunle Gold'],
#  'tell the vision': [92, 420, 350, 450, 64, 101, 'Pop Smoke'],
#  'need to know': [100, 420, 69, 450, 100, 325, 'Doja Cat'],
#  '40 btc': [375, 14, 350, 450, 300, 325, 'Rexxie featuring Seyi Vibez'],
#  'korope': [375, 77, 350, 40, 300, 325, 'Lil Kesh'],
#  'be something': [375, 168, 350, 450, 300, 325, 'Polo G'],
#  'catalyst': [375, 59, 350, 450, 300, 325, 'Seyi Vibez'],
#  'bounce': [5, 202, 4, 5, 3, 2, 'Ruger'],
#  'level up': [375, 144, 350, 450, 300, 325, 'Burna Boy'],
#  'one kiss': [375, 420, 350, 53, 300, 325, 'Victor AD'],
#  "survivor's guilt": [54, 420, 350, 450, 46, 87, 'Dave'],
#  'ball till we fall': [375,
#   131,
#   350,
#   450,
#   300,
#   325,
#   'Kida Kudz featuring Bella Shmurda'],
#  'runaway': [375, 420, 350, 450, 300, 88, 'AURORA'],
#  'happiness': [375, 128, 350, 450, 300, 325, 'Davolee'],
#  'focus': [66, 21, 72, 11, 65, 68, 'Joeboy'],
#  'law of attraction': [25, 420, 350, 450, 22, 60, 'Dave and  Snoh Aalegra'],
#  'feel': [375, 420, 350, 39, 300, 325, 'Mrolaide '],
#  'alone with you': [375, 196, 350, 450, 300, 325, 'Alina Baraz'],
#  'koleyewon': [375, 75, 350, 450, 300, 325, 'Naira Marley'],
#  'baba nla': [375, 162, 350, 450, 300, 325, 'Dr Dolor'],
#  'butter': [375, 420, 83, 450, 300, 325, 'BTS'],
#  'eyes on me': [375, 420, 350, 450, 300, 123, 'Skepta'],
#  'adura': [375, 94, 350, 72, 300, 325, 'Bella Shmurda'],
#  'pami': [375, 65, 350, 58, 300, 325, 'DJ Tunez'],
#  'lemonade': [375, 420, 350, 450, 300, 94, 'Internet money'],
#  'kolo': [75, 108, 79, 450, 71, 78, 'Ice Prince'],
#  'so crazy': [375, 183, 350, 450, 300, 325, 'Davido'],
#  'cultural praise vol.2': [375,
#   209,
#   350,
#   450,
#   300,
#   325,
#   'Kcee, Okwesili Eze Group'],
#  'cocaine': [71, 157, 350, 450, 95, 63, 'Dai Verse'],
#  'ayewada': [375, 29, 350, 450, 300, 325, 'Barry Jhay'],
#  'bad influence': [375, 89, 350, 73, 300, 80, 'Omah Lay'],
#  'die young': [375, 137, 350, 450, 300, 325, 'Roddy Ricch'],
#  'there is a place': [375, 420, 29, 450, 300, 325, 'Nathaniel Bassey'],
#  'wild side': [375, 420, 31, 450, 300, 325, 'Normani'],
#  'ponpon': [98, 52, 350, 63, 94, 44, 'Olamide'],
#  'high way': [101, 91, 350, 450, 101, 325, 'DJ Kaywise and  Phyno'],
#  'picture freestyle': [375, 79, 350, 450, 300, 325, 'Seyi Vibez'],
#  'bus stop': [375, 420, 350, 450, 300, 119, 'Ajebo Hustlers'],
#  'too correct': [375, 49, 80, 36, 300, 325, 'Crayon'],
#  "runnin'": [375, 217, 350, 450, 300, 325, 'Isaiah Rashad'],
#  'julie': [73, 33, 20, 35, 69, 104, 'Olamide'],
#  'frenemies': [375, 170, 350, 450, 300, 325, 'Rexxie and Oxlade'],
#  'no forget': [375, 420, 64, 450, 300, 325, 'Adekunle Gold'],
#  'matriculation': [375, 420, 350, 91, 300, 325, 'PlaTBoss'],
#  'mind games': [375, 212, 350, 450, 300, 325, 'Buju'],
#  'addicted': [375, 420, 61, 450, 300, 325, 'Guchi'],
#  'rotate': [375, 420, 350, 77, 300, 325, 'Mr Eazi'],
#  'red light green light': [375, 420, 350, 450, 300, 120, 'DaBaby'],
#  'celebration': [375, 134, 350, 450, 300, 325, 'Joeboy'],
#  'yaba buluku': [6, 9, 12, 17, 4, 51, 'DJ Tarico and  Burna Boy'],
#  'rush': [43, 420, 350, 450, 41, 84, 'Dangbana Republik and  Bella Shmurda'],
#  'omnipotent': [375, 73, 350, 450, 300, 325, 'Bella Shmurda'],
#  'upgrade': [375, 80, 350, 450, 300, 325, 'Bella Shmurda'],
#  'like i do': [375, 190, 350, 450, 300, 325, 'Fireboy DML'],
#  'get back': [375, 179, 350, 450, 300, 325, 'MO3'],
#  'commitment issues': [375, 420, 350, 450, 300, 76, 'Central Cee'],
#  'money': [375, 32, 350, 450, 300, 325, 'Terri, Bella Shmurda, Mohbad'],
#  'southy love': [55, 103, 350, 450, 52, 325, 'Peruzzi'],
#  'kiss me more': [375, 420, 96, 450, 300, 325, 'Doja Cat'],
#  'olorun agbaye': [375, 420, 38, 450, 300, 325, 'Nathaniel Bassey'],
#  'champion': [94,
#   50,
#   350,
#   41,
#   82,
#   325,
#   'Dangbana Republik and  Bella Shmurda'],
#  'lo lo': [375, 154, 350, 86, 300, 325, 'Omah Lay'],
#  'show me': [29, 420, 23, 7, 28, 31, 'Joeboy'],
#  'monalisa': [4, 420, 32, 450, 2, 36, 'Lojay and  Sarz'],
#  'all': [110, 53, 350, 450, 102, 43, 'Rexxie'],
#  'hallelujah challenge praise medley': [375,
#   420,
#   350,
#   71,
#   300,
#   325,
#   'Nathaniel Bassey'],
#  'so lovely': [375, 83, 350, 450, 300, 325, 'Buju'],
#  'better believe': [375,
#   420,
#   99,
#   450,
#   300,
#   325,
#   'Belly, The Weeknd & Young Thug'],
#  'jack': [375, 420, 350, 97, 300, 325, 'Nasty C'],
#  'senseless': [375, 216, 350, 450, 300, 325, 'Kodak Black'],
#  'sweet': [375, 204, 350, 450, 300, 325, 'Rayvanny'],
#  'it is what it is': [45, 16, 41, 450, 47, 12, 'Adekunle Gold'],
#  'jo': [375, 159, 350, 450, 300, 325, 'Teni'],
#  'sorry': [375, 38, 350, 450, 300, 325, 'MohBad'],
#  'for you': [84, 23, 22, 52, 81, 25, 'Teni'],
#  'far away': [30, 19, 51, 450, 29, 19, 'Dangbana Republik and  Bella Shmurda'],
#  'jalebi baby': [375, 420, 48, 450, 300, 325, 'Tesher'],
#  'pepe': [375, 139, 350, 42, 300, 325, 'L.A.X'],
#  'bia': [375, 30, 63, 29, 300, 325, 'Phyno'],
#  'any more': [375, 420, 350, 18, 300, 325, 'Victor AD'],
#  'egbon': [375, 182, 350, 450, 300, 325, 'Masterkraft'],
#  'onyedikagi': [375, 420, 52, 450, 300, 325, 'Mercy Chinwo'],
#  'mrs. bubblegum': [375, 221, 350, 450, 300, 325, 'Tyga'],
#  'wonderful': [375, 138, 350, 450, 300, 325, 'Burna Boy'],
#  "we're all alone": [21, 420, 350, 450, 18, 58, 'Dave'],
#  'testimony': [16, 10, 89, 28, 13, 54, 'Buju'],
#  'real shiii': [375, 420, 350, 450, 300, 96, 'Graimmy Thesoh'],
#  'understand': [1, 2, 3, 1, 96, 1, 'Omah Lay'],
#  'mercy': [104, 214, 350, 450, 300, 111, 'Falz'],
#  'are you sure': [375, 31, 88, 450, 300, 325, 'Lyta'],
#  'obinasom': [375, 420, 350, 100, 300, 325, 'Mercy Chinwo'],
#  'aye': [375, 420, 93, 80, 300, 325, 'Naira Marley'],
#  'longtime': [87, 420, 350, 450, 86, 325, 'Wizkid'],
#  'oh no': [375, 420, 350, 450, 300, 124, 'Alpha P'],
#  'do not disturb': [375, 173, 350, 450, 300, 325, 'Omah Lay'],
#  'you': [375, 127, 350, 85, 300, 325, 'Omah Lay'],
#  'aiye': [375, 104, 350, 450, 300, 325, 'Barry Jhay'],
#  'happy birthday': [375,
#   181,
#   350,
#   450,
#   300,
#   325,
#   'Simi feat. Adekunle Gold and Deja'],
#  'sweet one': [86, 420, 350, 450, 85, 325, 'Wizkid'],
#  '90’s': [375, 40, 350, 450, 300, 325, 'Seyi Vibez']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in e:
        keys[x] = e1[e.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    if k in f:
        keys[x] = f1[f.index(k)]
    if k in d:
        keys[x] = d1[d.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 340

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
post7 = [x[6] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x] + post6[x])/6 for x in range(0, 340)]

# %%
data = {'song':song,'artist':post7,'apple':post1,'boom':post2,'spotify':post3,'audiomack':post4, 'deezer':post5, 'youtube':post6,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,341)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:100]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv(f'week{w}-hot100.csv')
df.to_csv(f'week{w}.csv')

# %%
df
# Out:
#                        song                                  artist  apple  \
# rank
# 1     Sinner ft. Lucky Daye           Adekunle Gold and  Lucky Daye      3
# 2          Feeling ft. Buju                       LADIPOE and  Buju      9
# 3                   Outside                                    Buju      8
# 4                      Rock                                 Olamide     15
# 5                      Peru                             Fireboy DML      7
# ...                     ...                                     ...    ...
# 336                 Anymore                               Victor AD    375
# 337                   Skate  Bruno Mars, Anderson .Paak, Silk Sonic    375
# 338                 Ability                                  jaywon    375
# 339          All Mine Remix                                 Kinsolo    375
# 340        Non Living Thing                                Sarkodie    375
#
#       boom  spotify  audiomack  deezer  youtube          RT
# rank
# 1        5        1         14       1        3    4.500000
# 2        3        8          2       8        4    5.666667
# 3        6       24          9       6       29   13.666667
# 4        4       14          4      14       33   14.000000
# 5        7       35          3       5       37   15.666667
# ...    ...      ...        ...     ...      ...         ...
# 336    222      350        450     300      325  337.000000
# 337    223      350        450     300      325  337.166667
# 338    224      350        450     300      325  337.333333
# 339    225      350        450     300      325  337.500000
# 340    226      350        450     300      325  337.666667
#
# [340 rows x 9 columns]

# %%
df2 = pd.read_csv(f'week{w-1}-hot100.csv')

# %%
a = list(df2['song'])
a1 = a.copy()
x = 0
for i in a:
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df1['song'])
b1 = b.copy()
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
song = []
for x in b:
    if x in a:
        song.append(a1[a.index(x)])
    else:
        song.append(b1[b.index(x)])

# %%
df1['song'] = song

# %%
a = list(df2['song'])
b = list(df1['song'])
c = list(df2['weeks on chart'])
prev = []
weeks = []
for x in b:
    if x in a:
        prev.append(a.index(x) + 1)
        weeks.append(c[a.index(x)] + 1)
    else:
        prev.append(0)
        weeks.append(1)
df1['Previous week'] = prev
df1['weeks on chart'] = weeks

# %%
df1.to_csv(f'week{w}-hot100.csv')
df1.to_csv('C:\\Users\\faree\\Desktop\\music charts\\weekly charts\\weekly\\hot100.csv')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\docs\\hot100.json')
df1.to_json(f'C:\\Users\\faree\\Desktop\\webboard\\week{w}\\hot100.json')

# %%
df1
# Out:
#                   song                                artist  Previous week  \
# rank
# 1               Sinner         Adekunle Gold and  Lucky Daye              5
# 2              Feeling                     LADIPOE and  Buju              2
# 3              Outside                                  Buju              4
# 4                 Rock                               Olamide              3
# 5                 Peru                           Fireboy DML             37
# ...                ...                                   ...            ...
# 96                Rush  Dangbana Republik and  Bella Shmurda             74
# 97           No Stress                                Wizkid             85
# 98      Need For Speed                               Olamide             56
# 99    Survivor's Guilt                                  Dave              0
# 100            Olofofo                             Victor AD             95
#
#       weeks on chart
# rank
# 1                  3
# 2                 11
# 3                 11
# 4                 11
# 5                  2
# ...              ...
# 96                11
# 97                11
# 98                 6
# 99                 1
# 100                8
#
# [100 rows x 4 columns]

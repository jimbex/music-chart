# %%
import pandas as pd
from datetime import datetime
m = datetime.today().strftime('%B')
d = datetime.today().strftime('%d')
w = datetime.today().strftime('%V')
w = int(w)
d = int(d)

# %%
df1 = pd.read_csv(f'apple_gospel-week{w}.csv')
df2 = pd.read_csv(f'boom_gospel-week{w}.csv')
df3 = pd.read_csv(f'youtube_gospel-week{w}.csv')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]

# %%
a = list(df1['song'])
a1 = a.copy()
a2 = list(df1['artist'])
x = 0
for i in a:
    i = i.lower()
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        a[x] = a[x].replace('feat', '(feat')
    if 'remix' in i:
        a[x] = a[x].replace('remix', '(remix')
    if '  ' in i:
        a[x] = a[x].replace('  ', ' ')
    if '(' in a[x]:
        a[x] = a[x][: a[x].index('(')]
    if '\\' in i:
        a[x] = a[x].replace('\\', '') 
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df2['song'])
b1 = b.copy()
b2 = list(df2['artist'])
x = 0
for i in b:
    i = i.lower()
    if 'remix' in i:
        b[x] = i.replace('remix', '(remix')
    if 'ft' in i:
        b[x] = b[x].replace('ft', '(ft')
    if 'feat' in i:
        b[x] = b[x].replace('feat', '(feat')
    if '  ' in i:
        b[x] = b[x].replace('  ', ' ')
    if '(' in b[x]:
        b[x] = b[x][: b[x].index('(')]
    if '\\' in i:
        b[x] = b[x].replace('\\', '') 
    b[x] = b[x].strip().lower()
    x += 1

# %%
c = list(df3['song'])
c1 = c.copy()
c2 = list(df3['artist'])
x = 0
for i in c:
    i = i.lower()
    if 'ft' in i:
        c[x] = i.replace('ft', '(ft')
    if 'feat' in i:
        c[x] = c[x].replace('feat', '(feat')
    if 'remix' in i:
        c[x] = c[x].replace('remix', '(remix')
    if '  ' in i:
        c[x] = c[x].replace('  ', ' ')
    if '(' in c[x]:
        c[x] = c[x][: c[x].index('(')]
    if '\\' in i:
        c[x] = c[x].replace('\\', '')  
    c[x] = c[x].strip().lower()
    x += 1

# %%
songs = a + b + c
songs = set(songs)

# %%
len(songs)
# Out:
# 234

# %%
songs = list(songs)

# %%
final = {}

# %%
x = 0
for i in songs:
    if i in a:
        final[i] = [a.index(i) + 1]
    else:
        final[i] = [500]

# %%
x = 0
for i in songs:
    if i in b:
        final[i].append(b.index(i) + 1)
    else:
        final[i].append(510)

# %%
x = 0
for i in songs:
    if i in c:
        final[i].append(c.index(i) + 1)
    else:
        final[i].append(450)

# %%
x = 0
for i in songs:
    if i in a:
        final[i].append(a2[a.index(i)])
    if i in b and len(final[i]) < 5:
        final[i].append(b2[b.index(i)])
    if i in c and len(final[i]) < 5:
        final[i].append(c2[c.index(i)])
    #if i in d and len(final[i]) < 5:
     #   final[i].append(d2[d.index(i)])
    x += 1

# %%
final
# Out:
# {'je veux te louer': [500, 76, 450, 'Indira'],
#  'yesu mo': [500, 35, 450, 'Joe Mettle'],
#  'covenant keeper': [500, 43, 450, 'David G'],
#  'shine': [500, 98, 450, 'Ada Ehi'],
#  'we prevail': [59, 510, 450, 'Sinach'],
#  'olorun agbaye - you are mighty': [7,
#   32,
#   450,
#   'Nathaniel Bassey',
#   'Nathaniel Bassey'],
#  'jesus': [500, 20, 35, 'Samsong', 'Samsong'],
#  'capable god': [32, 510, 450, 'Judikay'],
#  'lions': [48, 510, 450, 'T Sharp'],
#  'your love': [500, 28, 450, 'Steve Crown'],
#  'ebe': [500, 510, 87, 'Sola Allyson'],
#  'rejoice in the lord philippians 4:4': [500, 510, 12, 'Victoria Orenze'],
#  'itestify': [500, 50, 450, 'Ada Ehi'],
#  'congratulations': [15, 5, 29, 'Ada Ehi', 'Ada Ehi'],
#  'hallelujah challenge worship medley': [500, 36, 450, 'Nathaniel Bassey'],
#  'nothing missing': [42, 510, 450, 'Preye Odede'],
#  'grace is available': [78, 510, 450, 'Sammie Okposo'],
#  'fix my eyes on you': [500, 13, 450, 'Ada Ehi'],
#  'ekele': [63, 510, 450, 'Desai David'],
#  'rid me of those things': [500, 510, 49, 'Elijah Oyelade'],
#  'song of victory': [24, 510, 450, 'Esther Olugbemi'],
#  'iyanu a sele': [70, 510, 8, 'Tim Godfrey', 'Tim Godfrey'],
#  'unastahili': [73, 510, 450, 'Evelyn Wanjiru'],
#  'man of galilee': [500, 510, 73, 'Judikay'],
#  'omemma': [17, 21, 100, 'Judikay', 'Sinach'],
#  'i bow': [2, 510, 450, 'Judikay'],
#  'peace in the storm': [500, 510, 42, 'Sinach'],
#  'bigger every day': [500, 17, 450, 'Moses Bliss'],
#  'iyin': [500, 510, 91, 'Sola Allyson'],
#  'yours': [500, 510, 64, 'Minister GUC'],
#  'you are great': [500, 12, 48, 'Steve Crown', 'Steve Crown'],
#  'ebube jehovah': [22, 510, 450, 'Victor Ike'],
#  'covenant keeping god': [13, 510, 40, 'Jimmy D Psalmist', 'Jimmy D Psalmist'],
#  'too much': [60, 510, 450, 'Chioma Jesus'],
#  'gratitude': [500, 510, 72, 'Tope Alabi'],
#  'awurade': [95, 510, 450, 'Jayana'],
#  'i win': [500, 510, 83, 'Samsong'],
#  'your name is jesus': [23, 510, 450, 'Eljoe Onoja'],
#  'all that matters': [500, 74, 57, 'Minister GUC', 'GUC'],
#  'amen': [14, 510, 450, 'Tjsarx'],
#  'je laisse tout a dieu': [500, 54, 450, 'Indira'],
#  'finally': [500, 47, 450, 'Ada Ehi'],
#  'perfect love': [66, 510, 450, "Rhema 'Ye"],
#  'in this place': [29, 510, 450, 'Minister GUC'],
#  'my father & my friend': [77, 510, 20, 'Elijah Oyelade', 'Elijah Oyelade'],
#  'i will praise you': [500, 83, 450, 'Solomon Lange'],
#  'bigger everyday': [74,
#   53,
#   66,
#   'Moses Bliss,  Festizie,  Membrane,  Uwa,  Chris Heavens and  Temple',
#   'Moses Bliss'],
#  'i overcame': [500, 75, 450, 'Ada Ehi'],
#  'under the canopy': [500, 93, 62, 'Frank Edwards', 'Frank Edwards'],
#  'ajibole': [50, 510, 450, 'Protek Illasheva and  Marizu'],
#  'omeriwo': [500, 510, 54, 'Sammie Okposo'],
#  'yahweh': [92, 510, 1, 'Ifeoma Okoli', 'Mercy Chinwo'],
#  'holy ghost': [89, 510, 450, 'Joe Praize'],
#  'do': [80, 510, 450, 'Austin Hogan'],
#  'imela': [500, 65, 65, 'Steve Crown', 'Steve Crown'],
#  'beautiful': [35, 510, 2, 'Sinach', 'Sinach'],
#  'all the glory': [500, 24, 450, 'Steve Crown'],
#  'excess love': [4, 66, 22, 'Mercy Chinwo', 'Mercy Chinwo'],
#  'in your hands': [500, 78, 34, 'Moses Bliss', 'Moses Bliss'],
#  'my everything': [500, 94, 450, 'Joe Mettle'],
#  'take over': [500, 510, 30, '1spirit & Theopilus Sunday'],
#  'mighty god': [500, 51, 69, 'Steve Crown', 'Steve Crown'],
#  'show up': [500, 510, 39, 'Ema Onyx'],
#  'oka ome': [500, 87, 450, 'Chioma Jesus'],
#  'mimo': [500, 510, 67, 'Sola Allyson'],
#  'same god': [500, 510, 76, 'Segun John'],
#  'answer your name': [69, 510, 450, 'Caleb Audu'],
#  'ìrì': [500, 510, 52, 'Sola Allyson'],
#  'halleluyah': [500, 82, 58, 'Tope Alabi', 'Tope Alabi'],
#  'your love is amazing': [21, 510, 450, 'Rebekah Dawn'],
#  'healing stream': [500, 510, 53, 'Evans Ighodalo'],
#  'ada ehi': [500, 510, 61, 'Ada Ehi'],
#  'all in all': [40, 510, 450, 'CalledOut Music'],
#  'lae la o ma bo oluwa': [500, 58, 450, 'Tope Alabi'],
#  'never go down': [500, 2, 450, 'Ada Ehi'],
#  'akamdinelu': [500, 73, 450, 'Mercy Chinwo'],
#  "oka'ome": [64, 510, 450, 'Chioma Jesus'],
#  'hozanna': [44, 510, 450, 'Claire Bahi'],
#  'all things new': [46, 510, 450, 'Tee Worship'],
#  'amanamo': [75, 510, 450, 'Chris Morgan'],
#  'agbebolo': [500, 60, 450, 'Celestine Donkor'],
#  'worship medley': [500, 510, 10, 'Kaydee Numbere'],
#  'okemmuo ft. mercy chinwo': [500, 70, 450, 'Chioma Jesus'],
#  'no other name': [500, 34, 56, 'Frank Edwards', 'Frank Edwards'],
#  'jesus never fails': [500, 510, 24, 'MaryJane Nweke'],
#  'ekundayo': [500, 86, 450, 'Yinka Ayefele'],
#  'na you dey reign': [500, 55, 47, 'Mercy Chinwo', 'Mercy Chinwo'],
#  'idinma': [500, 510, 77, 'Judikay'],
#  'you are jehovah': [500, 510, 79, 'Prospa Ochimana'],
#  'my peace': [500, 510, 96, 'Elijah Oyelade'],
#  'yahweh yahweh': [39, 33, 450, 'Nathaniel Bassey', 'Nathaniel Bassey'],
#  'i believe': [68, 510, 450, 'Jessika Kioja'],
#  'bulldozer': [500, 63, 450, 'Chioma Jesus'],
#  'fragrance to fire': [500, 16, 59, 'Dunsin Oyekan', 'Dunsin Oyekan'],
#  'most high': [57, 510, 450, 'Frank Edwards'],
#  'nyansabuakwa nyame': [500, 40, 450, 'Diana Hamilton'],
#  'how great you are': [500, 510, 78, 'JOEPRAIZE'],
#  'fourthman': [54, 510, 450, 'Caleb Audu'],
#  'way maker': [500, 19, 17, 'Sinach', 'Sinach'],
#  'obinasom': [500, 10, 15, 'Mercy Chinwo', 'Mercy Chinwo'],
#  'nara': [500, 67, 23, 'Tim Godfrey', 'Tim Godfrey'],
#  'cultural praise vol. 3': [94, 510, 450, 'KCee and  Okwesili Eze Group'],
#  'onememma': [500, 59, 450, 'Mercy Chinwo'],
#  'best of me': [49, 510, 450, 'Double F'],
#  'overflow': [500, 100, 450, 'Sinach'],
#  'ubangiji': [65, 510, 450, 'Younggod'],
#  'you remain the same': [500, 68, 450, 'Dunsin Oyekan'],
#  'emmanuel': [500, 27, 450, 'Nathaniel Bassey'],
#  'battles': [76, 510, 41, 'Tim Godfrey', 'Tim Godfrey'],
#  'we bow down': [99, 510, 450, 'Sinach'],
#  'yeshua hamashiach': [500, 22, 450, 'Nathaniel Bassey'],
#  'you no dey use me play': [500, 510, 45, 'Ema Onyx'],
#  'awone': [52, 510, 450, 'naomee'],
#  'okokroko': [87, 510, 450, 'Sonnie Badu'],
#  'we testify': [93, 510, 450, 'Deborah Lukalu'],
#  'love my home': [500, 510, 27, 'Sinach'],
#  'incredible god': [98, 510, 450, 'Mercy Chinwo'],
#  'born to worship': [500, 510, 88, 'Prinz'],
#  'we hail you': [18, 510, 450, 'Nayaah'],
#  'king of glory': [47, 510, 450, 'Sinach'],
#  'the harvest': [500, 91, 450, 'Eben'],
#  'nothing without you': [500, 510, 11, 'Dr Tumi'],
#  'nobody can': [500, 510, 94, 'Sammie Okposo'],
#  'hallelujah challenge praise medley': [500, 8, 450, 'Nathaniel Bassey'],
#  'unchangeable': [500, 510, 28, 'Joe Praize'],
#  'more than conquerors': [33, 510, 450, 'Chelsea Levi'],
#  'new level': [500, 42, 450, 'Ada Ehi'],
#  'too faithful': [1, 3, 21, 'Moses Bliss', 'Moses Bliss'],
#  'nothing is impossible': [90, 510, 450, 'EBEN'],
#  'jesus jehovah': [500, 510, 16, 'Lara George'],
#  'god alone': [500, 510, 99, 'Joe Praize'],
#  'magnify': [500, 510, 14, 'Dare David'],
#  'baba ese': [86, 69, 450, 'Mike Abdul', 'Mike Abdul'],
#  'chioma': [500, 31, 450, 'Frank Edwards'],
#  'aye ole': [500, 510, 89, 'Infinity'],
#  'more than gold': [12, 510, 60, 'Judith Kanayo', 'Judikay'],
#  'imole de': [500, 510, 70, 'Dunsin Oyekan'],
#  'jesu ore otito': [500, 89, 450, 'Tope Alabi'],
#  'sinach': [500, 510, 101, 'Sinach'],
#  'onyedikagi': [10, 510, 6, 'Mercy Chinwo', 'Mercy Chinwo'],
#  'settled': [500, 56, 450, 'Ada Ehi'],
#  'nazo bondela yo': [500, 84, 450, 'ROSNY KAYIBA'],
#  'hallelujah no go finish': [38, 510, 63, 'Freke Umoh', 'Freke Umoh'],
#  'mai taimako na': [500, 79, 450, 'Solomon Lange'],
#  'my praise': [500, 510, 50, 'Norine Mindeyes'],
#  'this love': [26, 510, 450, 'Chidinma'],
#  'mmoloki waka': [37, 510, 450, 'Choko'],
#  'heaven': [500, 44, 450, 'JayMikee'],
#  'oga jesus': [5, 510, 450, 'Daniel Mylez'],
#  'they that wait': [19, 510, 450, 'Joe Mettle'],
#  'you i live for': [500, 46, 450, 'Moses Bliss'],
#  'hosanna': [41, 15, 450, 'Steve Crown', 'Steve Crown'],
#  'evidence': [83, 510, 450, 'Opera-David Benson'],
#  'now': [96, 14, 43, 'Ada Ehi', 'Ada Ehi'],
#  'jehovah overdo': [3, 23, 450, 'Chidinma', 'Chidinma'],
#  'you are yahweh': [500, 7, 18, 'Steve Crown', 'Steve Crown'],
#  'adam nana': [500, 57, 450, 'Joyce Blessing'],
#  'faithful god': [61, 25, 450, 'Onos', 'Onos'],
#  'my beautifier': [500, 45, 450, 'Chris Shalom'],
#  'you are worthy': [500, 62, 31, 'Tope Alabi', 'Tope Alabi'],
#  'all things are ready': [500, 77, 68, 'Sinach', 'Sinach'],
#  'spirit pray': [500, 510, 82, 'Elijah Oyelade'],
#  'jesus power': [500, 90, 450, 'Eben'],
#  'thank you': [43, 510, 450, 'Kobby Mantey and  Joe Mettle'],
#  'indomitable': [500, 510, 5, 'Jimmy D Psalmist'],
#  'mighty man of war': [500, 88, 450, 'Jimmy D Psalmist'],
#  'at all cost': [500, 48, 44, 'Dunsin Oyekan', 'Dunsin Oyekan'],
#  'taking care': [500, 26, 450, 'Moses Bliss'],
#  'yes lord': [500, 510, 81, 'Judikay'],
#  'worship your maker': [28, 64, 9, 'Dunsin Oyekan', 'Dunsin Oyekan'],
#  'we wait on you': [500, 510, 86, 'Steve Crown'],
#  'your word is truth': [500, 510, 38, 'CHRIS SHALOM'],
#  'grateful': [91, 80, 450, 'Sinach', 'Limoblaze'],
#  'ye obua mi': [27, 39, 450, 'Joe Mettle', 'Joe Mettle'],
#  'awesome god': [500, 510, 80, 'SINACH'],
#  'everything': [11, 1, 3, 'Timi Dakolo', 'Ada Ehi'],
#  'unchangeable god': [500, 52, 450, 'Joe Praize'],
#  'great & mighty': [55, 510, 450, 'Segun John'],
#  'e dey work': [500, 510, 93, 'Samsong'],
#  'you fight for me': [58, 510, 450, 'Mahalia Buchanan'],
#  'imole': [500, 510, 7, 'Sola Allyson'],
#  'bless me': [81, 510, 95, 'Mercy Masika', 'Mercy Masika'],
#  'more than enough': [500, 9, 450, 'Ada Ehi'],
#  'spirit chant': [500, 30, 450, 'Victoria Orenze'],
#  'adonai [live]': [500, 510, 32, 'Elijah Oyelade'],
#  'cheta': [500, 81, 450, 'Ada Ehi'],
#  'notice': [500, 95, 450, 'Ada Ehi'],
#  'on #yes and amen album': [500, 510, 75, 'Tope Alabi'],
#  'one moment': [500, 510, 13, 'Freke Umoh'],
#  'more than a song': [500, 71, 450, 'Dunsin Oyekan'],
#  'cultural praise vol.2': [79, 510, 450, 'KCee and  Okwesili Eze Group'],
#  'yes and amen': [500, 37, 46, 'Tope Alabi', 'Tope Alabi'],
#  'billion words': [20, 510, 450, 'Limoblaze and  Onos'],
#  'my father my god': [53, 18, 450, 'Jimmy D Psalmist', 'Jimmy D Psalmist'],
#  'korede': [500, 510, 90, 'Mike Abdul'],
#  'hallelujah': [6, 510, 450, 'Joe Mettle'],
#  'yah': [500, 41, 450, 'Dunsin Oyekan'],
#  'chinedum': [500, 92, 37, 'Mercy Chinwo', 'Mercy Chinwo'],
#  'greatest lord': [82, 510, 450, 'Sinach'],
#  'chukwu eze': [72, 510, 450, 'Melody Gabriel'],
#  'good god': [9, 510, 450, 'Limoblaze and  Ada Ehi'],
#  'you are god': [100, 510, 450, 'Chingtok Ishaku and  House of Judah'],
#  'what a mighty god': [500, 85, 450, 'Steve Crown'],
#  'we worship you': [500, 510, 36, 'Frank Edwards'],
#  'jesu doh': [45, 510, 450, 'EBEN'],
#  'angels bow': [500, 510, 74, 'Steve Crown'],
#  'oyoyo chukwu': [500, 96, 450, 'Mercy Chinwo'],
#  'konyana': [71, 510, 450, 'Dr Tumi'],
#  'mercy o !': [16, 510, 450, 'Wale Adenuga'],
#  'olorun agbaye: you are mighty': [500, 510, 25, 'Nathaniel Bassey'],
#  'amazing': [56, 510, 450, 'Isyrose'],
#  'izurukeme': [500, 510, 71, 'Promise Benson'],
#  'alpha & omega': [8, 510, 450, 'K Praise'],
#  'never forget your love': [31, 510, 450, 'Anny'],
#  'eze nara ekele': [500, 97, 85, 'Steve Crown', 'Steve Crown'],
#  'we raise a sound': [88, 510, 19, 'Nosa', 'Nosa'],
#  'iyin ye o': [500, 510, 92, 'Tope Alabi'],
#  'jésù mi dà': [500, 510, 98, 'Mike Abdul'],
#  'ekwueme': [500, 29, 450, 'Prospa Ochimana'],
#  'have mercy': [500, 61, 450, 'Victoria Orenze'],
#  'i made it': [97, 510, 450, 'Gabriel Eziashi'],
#  'iro halleluyah': [500, 510, 97, 'Mike Abdul'],
#  'liyinqaba': [62, 510, 450, 'Hle and  Hlengiwe Mhlaba'],
#  'praise medley': [84, 510, 450, 'Joe Mettle'],
#  'one song': [30, 510, 450, 'Ikiri Lawrence'],
#  'great i am': [500, 510, 51, 'Dare David'],
#  'knowing you': [500, 510, 26, 'Minister GUC'],
#  'mma mma': [85, 510, 450, 'Frank Edwards'],
#  'yahweh be praised': [500, 510, 55, 'Emmasings'],
#  'thank you for my life': [500, 11, 450, 'Ada Ehi'],
#  'god most high': [51, 510, 450, 'Shalom Braide'],
#  'adom grace': [500, 4, 450, 'Diana Hamilton'],
#  'no troubles': [25, 510, 450, 'Chris Morgan'],
#  'god of vengeance': [500, 99, 33, 'Minister GUC', 'Minister GUC']}

# %%
x = 0
keys = list(final.keys())
for k in keys:
    if k in a:
        keys[x] = a1[a.index(k)]
    if k in b:
        keys[x] = b1[b.index(k)]
    if k in c:
        keys[x] = c1[c.index(k)]
    #if k in d:
     #   keys[x] = d1[d.index(k)]
    x += 1

# %%
i = 0
k = list(final.keys())
for x in k:
    final[keys[i]] = final.pop(x)
    i += 1

# %%
len(final)
# Out:
# 234

# %%
song = list(final.keys())
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
#post5 = [x[4] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x])/3 for x in range(0, 234)]

# %%
data = {'song':song,'artist':post4,'apple':post1,'boom':post2,'youtube':post3,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,235)]

# %%
df1 = df[['rank', 'song', 'artist']]
df1 = df1[:50]

# %%
df1 = df1.set_index('rank')
df = df.set_index('rank')

# %%
df1.to_csv(f'week{w}-gospel50.csv')
df.to_csv(f'week{w}-gospel.csv')

# %%
df2 = pd.read_csv(f'week{w-1}-gospel50.csv')

# %%
a = list(df2['song'])
a1 = a.copy()
x = 0
for i in a:
    if 'ft' in i:
        a[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in a:
    if '(' in i:
        a[x] = i[: i.index('(')]
    a[x] = a[x].strip().lower()
    x += 1

# %%
b = list(df1['song'])
b1 = b.copy()
x = 0
for i in b:
    if 'ft' in i:
        b[x] = i.replace('ft', '(ft') + ')'
    x += 1
x = 0
for i in b:
    if '(' in i:
        b[x] = i[: i.index('(')]
    b[x] = b[x].strip().lower()
    x += 1

# %%
song = []
for x in b:
    if x in a:
        song.append(a1[a.index(x)])
    else:
        song.append(b1[b.index(x)])

# %%
df1['song'] = song

# %%
a = list(df2['song'])
b = list(df1['song'])
c = list(df2['weeks on chart'])
i = 0
prev = []
weeks = []
for x in b:
    if x in a:
        prev.append(a.index(x) + 1)
        weeks.append(c[i] + 1)
    else:
        prev.append(0)
        weeks.append(1)
    i += 1
df1['Previous week'] = prev
df1['weeks on chart'] = weeks

# %%
df1.to_csv(f'week{w}-gospel50.csv')
df1.to_csv('C:\\Users\\faree\\Desktop\\music charts\\weekly charts\\weekly\\gospel50.csv')
df1.to_json('C:\\Users\\faree\\Desktop\\webboard\\docs\\gospel50.json')
df1.to_json(f'C:\\Users\\faree\\Desktop\\webboard\\week{w}\\gospel50.json')

# %%
df1
# Out:
#                                                    song  \
# rank
# 1                                     Everything (Amen)
# 2                                          Too Faithful
# 3                         Congratulations (feat. Buchi)
# 4     Excess Love (feat. J.J. Hairston & Youthful Pr...
# 5                                                Omemma
# 6                                    Worship Your Maker
# 7                                                   Now
# 8                            Nara (feat. Travis Greene)
# 9                                       Bigger Everyday
# 10                                               Yahweh
# 11    Olorun Agbaye - You Are Mighty (feat. Chandler...
# 12                                       Jehovah Overdo
# 13                                       Hosanna (Live)
# 14                                 Ye Obua Mi (My Help)
# 15                         Yahweh Yahweh (feat. Sinach)
# 16                                             Obinasom
# 17                           Onyedikagi (feat. Glowrie)
# 18                                       You are Yahweh
# 19                                  Faithful God (Live)
# 20                                            Way Maker
# 21                   Beautiful (feat. Nathaniel Bassey)
# 22                                           Adom Grace
# 23                           Jesus (feat. Mercy Chinwo)
# 24                                        You are Great
# 25                                 Covenant Keeping God
# 26    Iyanu a Sele (feat. Pastor E.A Adeboye & Tope ...
# 27                                    Fragrance to Fire
# 28                                         Yes And Amen
# 29                                       More Than Gold
# 30                                       You Are Worthy
# 31                                          At All Cost
# 32     My Father & My Friend (feat. Stephanie Kome Ita)
# 33                                        NO OTHER NAME
# 34                       Baba Ese ft. Yoruba Mass Choir
# 35                                             Chinedum
# 36                    We Raise a Sound (feat. 121SELAH)
# 37                              Hallelujah No Go Finish
# 38                                     Na You Dey Reign
# 39                                        In Your Hands
# 40                                              Battles
# 41                  Mighty God (feat. Nathaniel Bassey)
# 42                                     God of Vengeance
# 43                                           Halleluyah
# 44                                 All Things Are Ready
# 45                                     All That Matters
# 46                                           Wanibariki
# 47                                                Imela
# 48                                     Under The Canopy
# 49                             Bless Me (feat. Ada Ehi)
# 50                          Never Go Down ft. Limoblaze
#
#                                                  artist  Previous week  \
# rank
# 1                                           Timi Dakolo              1
# 2                                           Moses Bliss              2
# 3                                               Ada Ehi              3
# 4                                          Mercy Chinwo              5
# 5                                               Judikay              6
# 6                                         Dunsin Oyekan              7
# 7                                               Ada Ehi              8
# 8                                           Tim Godfrey             11
# 9     Moses Bliss, Festizie, Membrane, Uwa, Chris He...              9
# 10                                         Ifeoma Okoli             10
# 11                                     Nathaniel Bassey              4
# 12                                             Chidinma             12
# 13                                          Steve Crown             13
# 14                                           Joe Mettle             14
# 15                                     Nathaniel Bassey             17
# 16                                         Mercy Chinwo             15
# 17                                         Mercy Chinwo             16
# 18                                          Steve Crown             18
# 19                                                 Onos             19
# 20                                               Sinach             22
# 21                                               Sinach             20
# 22                                       Diana Hamilton             23
# 23                                              Samsong             24
# 24                                          Steve Crown             25
# 25                                     Jimmy D Psalmist             32
# 26                                          Tim Godfrey             26
# 27                                        Dunsin Oyekan             28
# 28                                           Tope Alabi             30
# 29                                        Judith Kanayo             29
# 30                                           Tope Alabi             31
# 31                                        Dunsin Oyekan             39
# 32                                       Elijah Oyelade             33
# 33                                        Frank Edwards             35
# 34                                           Mike Abdul              0
# 35                                         Mercy Chinwo             36
# 36                                                 Nosa             38
# 37                                           Freke Umoh             37
# 38                                         Mercy Chinwo             43
# 39                                          Moses Bliss             40
# 40                                          Tim Godfrey             41
# 41                                          Steve Crown             44
# 42                                         Minister GUC             42
# 43                                           Tope Alabi             45
# 44                                               Sinach             46
# 45                                         Minister GUC              0
# 46                                                Nandy              0
# 47                                          Steve Crown             47
# 48                                        Frank Edwards             48
# 49                                         Mercy Masika             49
# 50                                              Ada Ehi             50
#
#       weeks on chart
# rank
# 1                  5
# 2                  5
# 3                  4
# 4                  4
# 5                  5
# 6                  4
# 7                  5
# 8                  4
# 9                  4
# 10                 2
# 11                 5
# 12                 5
# 13                 5
# 14                 4
# 15                 4
# 16                 5
# 17                 4
# 18                 5
# 19                 3
# 20                 4
# 21                 3
# 22                 5
# 23                 5
# 24                 5
# 25                 5
# 26                 5
# 27                 5
# 28                 5
# 29                 5
# 30                 3
# 31                 4
# 32                 3
# 33                 3
# 34                 1
# 35                 5
# 36                 5
# 37                 5
# 38                 5
# 39                 2
# 40                 4
# 41                 4
# 42                 5
# 43                 5
# 44                 2
# 45                 1
# 46                 1
# 47                 2
# 48                 2
# 49                 2
# 50                 2

# %%
import pandas as pd
df1 = pd.read_csv('may30.csv')
df2 = pd.read_csv('may31.csv')
df3 = pd.read_csv('june1.csv')
df4 = pd.read_csv('june2.csv')
df5 = pd.read_csv('june3.csv')
df6 = pd.read_csv('june4.csv')
df7 = pd.read_csv('june5.csv')

# %%
df1 = df1[['song', 'artist', 'album']]
df2 = df2[['song', 'artist', 'album']]
df3 = df3[['song', 'artist', 'album']]
df4 = df4[['song', 'artist', 'album']]
df5 = df5[['song', 'artist', 'album']]
df6 = df6[['song', 'artist', 'album']]
df7 = df7[['song', 'artist', 'album']]

# %%
df7['position'] = [x for x in range(1,101)]
df6['position'] = [x for x in range(1,101)]
df5['position'] = [x for x in range(1,101)]
df4['position'] = [x for x in range(1,101)]
df3['position'] = [x for x in range(1,101)]
df2['position'] = [x for x in range(1,101)]
df1['position'] = [x for x in range(1,101)]

# %%
df7['title'] = [df7['song'][x] + ' - ' + df7['artist'][x] for x in range(0,100)]
df6['title'] = [df6['song'][x] + ' - ' + df6['artist'][x] for x in range(0,100)]
df5['title'] = [df5['song'][x] + ' - ' + df5['artist'][x] for x in range(0,100)]
df4['title'] = [df4['song'][x] + ' - ' + df4['artist'][x] for x in range(0,100)]
df3['title'] = [df3['song'][x] + ' - ' + df3['artist'][x] for x in range(0,100)]
df2['title'] = [df2['song'][x] + ' - ' + df2['artist'][x] for x in range(0,100)]
df1['title'] = [df1['song'][x] + ' - ' + df1['artist'][x] for x in range(0,100)]

# %%
songs = list(df1['title']) + list(df2['title']) + list(df3['title']) + list(df4['title']) + list(df5['title']) + list(df6['title']) + list(df7['title'])
songs = set(songs)
final = {}

# %%
song = list(df1['title'])
for x in songs:
    if x in song:
        final[x] = list(df1['position'][df1['title'] == x])
    else:
        final[x] = [301]

# %%
song1 = list(df2['title'])
for x in songs:
    if x in song1:
        final[x].append(int(df2['position'][df2['title'] == x]))
    else:
        final[x].append(301)

# %%
final
# Out:
# {'Coming - Naira Marley, Busiswa': [7, 7],
#  'Blessed (feat. Damian "Jr. Gong" Marley) - Wizkid': [29, 30],
#  'Your Body - Mayorkun': [76, 87],
#  'Piece of Me (feat. Ella Mai) - Wizkid': [86, 78],
#  'Capable God - Judikay': [301, 91],
#  "That\\'s Facts - Lil Baby, Lil Durk": [301, 301],
#  'HEARTBREAK ANNIVERSARY - GIV\\xc4\\x92ON': [61, 61],
#  'World - Dangbana Republik, Bella Shmurda': [27, 29],
#  'Way Too Big - Burna Boy': [49, 53],
#  'Panty! - Lojay, Sarz': [301, 301],
#  'KOLO (feat. Oxlade) - Ice Prince': [26, 27],
#  'Show Me - Joeboy': [11, 11],
#  'All My Life (feat. Oxlade) - M.I Abaga': [301, 301],
#  'Verified (feat. Mayorkun) - Laycon': [60, 56],
#  'Focus - Joeboy': [19, 18],
#  'Mood Swings (feat. Lil Tjay) - Pop Smoke': [85, 85],
#  'Hallelu (feat. Bella Shmurda & Zlatan) - Masterkraft': [41, 41],
#  'Sweet One - Wizkid': [71, 68],
#  'Oliver Twist - ArrDee': [301, 301],
#  'It Is What It Is - Adekunle Gold': [15, 14],
#  'Door - Joeboy, Kwesi Arthur': [52, 57],
#  'Bounce - Rema': [23, 25],
#  'Up The Side - Lil Baby, Lil Durk, Young Thug': [301, 301],
#  'Beamer Body - KDDO, Davido': [90, 100],
#  'If You Want To - Lil Baby, Lil Durk': [301, 301],
#  'Reckless - Wizkid': [56, 54],
#  'Longtime (feat. Skepta) - Wizkid': [69, 69],
#  'Runaway - AURORA': [63, 67],
#  'a p p l y i n g . p r e s s u r e - J. Cole': [87, 93],
#  'Abu Dhabi - Ruger': [50, 50],
#  'Okay - Adekunle Gold': [94, 95],
#  '9 5 . s o u t h - J. Cole': [58, 64],
#  'Early Momo (feat. GoodGirl LA) - Vector': [28, 31],
#  'BBC (feat. Tiwa Savage) [Remix] - Blaqbonez': [97, 301],
#  'RAPSTAR - Polo G': [88, 86],
#  'Cash App - Bella Shmurda, Zlatan, Lincoln': [51, 58],
#  'Still Hood - Lil Baby, Lil Durk': [301, 301],
#  'Okay - Lil Baby, Lil Durk': [301, 301],
#  'Loco (feat. Mayorkun) - KDDO': [89, 96],
#  'a m a r i - J. Cole': [33, 36],
#  'Monalisa - Lojay, Sarz': [301, 301],
#  'High Way - DJ Kaywise, Phyno': [35, 39],
#  'Cho Cho (feat. Davido & Mayorkun) - Zlatan': [68, 73],
#  'Southy Love (feat. Fireboy DML) - Peruzzi': [21, 22],
#  'Ke Star (feat. Virgo Deep) [Remix] - Focalistic, Davido': [16, 17],
#  'Loading (feat. Bad Boy Timz) - Olamide': [83, 90],
#  'Onyeka (Baby) - Burna Boy': [77, 84],
#  'Body (Remix) [feat. ArrDee, E1 (3x3), ZT (3x3), Bugzy Malone, Buni, Fivio Foreign & Darkoo] - Tion Wayne, Russ Millions': [9,
#   9],
#  '1 0 0 . m i l \\xe2\\x80\\x98 - J. Cole, Bas': [99, 301],
#  'Rich Off Pain - Lil Baby, Lil Durk, Rod Wave': [301, 301],
#  'Voice of the Heroes - Lil Baby, Lil Durk': [301, 301],
#  'Mighty Wine - Wizkid': [73, 72],
#  'LV N ATTN feat. Wizkid - Lojay, Sarz': [301, 301],
#  'Kilometre - Burna Boy': [8, 8],
#  'Ginger (feat. Burna Boy) - Wizkid': [22, 21],
#  'Bruised Up - Lil Baby, Lil Durk': [301, 301],
#  'Leave The Door Open - Bruno Mars, Anderson .Paak, Silk Sonic': [62, 66],
#  'Still Runnin - Lil Baby, Lil Durk, Meek Mill': [301, 301],
#  'True Love (feat. Tay Iwar & Projexx) - Wizkid': [72, 70],
#  'Feeling - LADIPOE, Buju': [1, 1],
#  'KPK (Ko Por Ke) - Rexxie, MohBad': [38, 44],
#  'i n t e r l u d e - J. Cole': [96, 98],
#  'Fendi (feat. Joeboy) - Blaqbonez': [53, 55],
#  'Rush - Dangbana Republik, Bella Shmurda': [34, 35],
#  'FEM - Davido': [100, 301],
#  'La La (feat. CKay) - Davido': [301, 24],
#  'Too Correct - Crayon, Rema': [44, 45],
#  'History - Cheque, Fireboy DML': [17, 16],
#  'Man of my Word - Lil Baby, Lil Durk': [301, 301],
#  'Seeing Green - Nicki Minaj, Drake, Lil Wayne': [82, 89],
#  'Park O X3 - Lojay, Sarz': [301, 301],
#  'p r i d e . i s . t h e . d e v i l - J. Cole, Lil Baby': [45, 48],
#  'Ruger - Ruger': [78, 74],
#  'Loved By You (feat. Burna Boy) - Justin Bieber': [24, 26],
#  'Outside - Buju': [4, 4],
#  'Bounce - Ruger': [3, 3],
#  'LET IT GO (feat. Justin Bieber & 21 Savage) - DJ Khaled': [79, 80],
#  'Tonongo - Lojay, Sarz': [301, 301],
#  'Hats Off - Lil Baby, Lil Durk, Travis Scott': [301, 301],
#  'Kilofeshe - Zinoleesky': [43, 46],
#  'Lying - Lil Baby, Lil Durk': [301, 301],
#  'Pronto - Ajebo Hustlers, Omah Lay': [13, 13],
#  'Medical - Lil Baby, Lil Durk': [301, 301],
#  'Infinity (feat. Omah Lay) - Olamide': [59, 62],
#  'Happy Birthday (feat. Adekunle Gold & Deja) - Simi': [301, 23],
#  'PAMI (feat. Wizkid, Adekunle Gold & Omah Lay) - DJ Tunez': [91, 88],
#  'FOR YOU (feat. Davido) - Teni': [31, 34],
#  'INJURE ME - Teni': [40, 42],
#  'No Stress - Wizkid': [66, 63],
#  'Peaches (feat. Daniel Caesar & GIV\\xc4\\x92ON) - Justin Bieber': [30, 32],
#  'The Best (feat. Mayorkun) - Davido': [32, 33],
#  'How It Feels - Lil Baby, Lil Durk': [301, 301],
#  'Essence (feat. Tems) - Wizkid': [10, 10],
#  'This Your Body - Skales, Davido': [64, 60],
#  'Body - Russ Millions, Tion Wayne': [93, 97],
#  'Koleyewon - Naira Marley': [70, 77],
#  'Jowo - Davido': [47, 52],
#  'Away - Ayra Starr': [67, 75],
#  'Please - Lil Baby, Lil Durk': [301, 301],
#  'Make It Out - Lil Baby, Lil Durk': [301, 301],
#  'Running (To You) - Chike, Simi': [25, 28],
#  'Felony - CKay': [14, 15],
#  'Godly - Omah Lay': [39, 40],
#  'Late At Night - Roddy Ricch': [301, 301],
#  'Triumphant (feat. Bella Shmurda) - Olamide': [95, 92],
#  'Okwaraji - Blaqbonez': [48, 51],
#  'Commitment Issues - Central Cee': [46, 47],
#  'Kiss Me More (feat. SZA) - Doja Cat': [84, 83],
#  'l e t . g o . m y . h a n d - J. Cole, Bas, 6LACK': [92, 99],
#  'Who I Want - Lil Baby, Lil Durk': [301, 301],
#  'Ayewada - Barry Jhay': [54, 49],
#  'Kilofese (feat. Mayorkun & Busiswa) [Remix] - Zinoleesky': [57, 65],
#  'Dimension (feat. Skepta & Rema) - JAE5': [6, 6],
#  '2040 - Lil Baby, Lil Durk': [301, 301],
#  'Calling My Phone - Lil Tjay, 6LACK': [80, 81],
#  'Music Messiah - DJ Neptune, Wande Coal': [42, 43],
#  'Smile (feat. H.E.R.) - Wizkid': [98, 94],
#  'Bank on It - Burna Boy': [55, 59],
#  'Real Life (feat. Stormzy) - Burna Boy': [65, 71],
#  'Bling (feat. Amaarae & Buju) - Blaqbonez': [5, 5],
#  'Money - Terri, Bella Shmurda, MohBad': [20, 20],
#  'Somebody Baby - Davido, Peruzzi': [18, 19],
#  '23 - Burna Boy': [37, 37],
#  'Holy Ground (feat. Nicki Minaj) - Davido': [74, 76],
#  'Damages - Tems': [81, 82],
#  'Bad Influence - Omah Lay': [75, 79],
#  'Constantly (feat. Mayorkun & Peruzzi) - Speroachbeatz': [301, 301],
#  'Forever (Remix) - Gyakie, Omah Lay': [12, 12],
#  'Rock - Olamide': [2, 2],
#  'm y . l i f e - J. Cole, 21 Savage, Morray': [36, 38]}

# %%
song2 = list(df3['title'])
for x in songs:
    if x in song2:
        final[x].append(int(df3['position'][df3['title'] == x]))
    else:
        final[x].append(301)

# %%
song3 = list(df4['title'])
for x in songs:
    if x in song3:
        final[x].append(int(df4['position'][df4['title'] == x]))
    else:
        final[x].append(301)

# %%
song4 = list(df5['title'])
for x in songs:
    if x in song4:
        final[x].append(int(df5['position'][df5['title'] == x]))
    else:
        final[x].append(301)

# %%
song5 = list(df6['title'])
for x in songs:
    if x in song5:
        final[x].append(int(df6['position'][df6['title'] == x]))
    else:
        final[x].append(301)

# %%
song6 = list(df7['title'])
for x in songs:
    if x in song6:
        final[x].append(int(df7['position'][df7['title'] == x]))
    else:
        final[x].append(301)

# %%
len(final)
# Out:
# 130

# %%
songs = [x[:x.index('-') - 1 ] for x in final.keys()]
artists = [x[x.index('-') + 2:] for x in final.keys()]
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
post7 = [x[6] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x] + post6[x] + post7[x] )/7 for x in range(0, 130)]

# %%
data = {'song':songs,'artist':artists,'R1':post1,'R2':post2,'R3':post3,'R4':post4,'R5':post5,'R6':post6,'R7':post7,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,131)]
df = df.set_index('rank')

# %%
df
# Out:
#                                  song              artist   R1   R2   R3   R4  \
# rank
# 1                             Feeling       LADIPOE, Buju    1    1    1    1
# 2                                Rock             Olamide    2    2    2    2
# 3                              Bounce               Ruger    3    3    3    3
# 4                             Outside                Buju    4    4    4    4
# 5        Bling (feat. Amaarae & Buju)           Blaqbonez    5    5    5    5
# ...                               ...                 ...  ...  ...  ...  ...
# 126                    If You Want To  Lil Baby, Lil Durk  301  301  301  301
# 127                      Oliver Twist              ArrDee  301  301  301  301
# 128   BBC (feat. Tiwa Savage) [Remix]           Blaqbonez   97  301  301  301
# 129        1 0 0 . m i l \xe2\x80\x98        J. Cole, Bas   99  301  301  301
# 130                               FEM              Davido  100  301  301  301
#
#        R5   R6   R7          RT
# rank
# 1       1    1    1    1.000000
# 2       2    2    2    2.000000
# 3       3    3    3    3.000000
# 4       4    4    5    4.142857
# 5       5    5    6    5.142857
# ...   ...  ...  ...         ...
# 126   301  301   77  269.000000
# 127   301  301   84  270.000000
# 128   301  301  301  271.857143
# 129   301  301  301  272.142857
# 130   301  301  301  272.285714
#
# [130 rows x 10 columns]

# %%
df.to_csv('C:\\Users\\faree\\Desktop\\music charts\\apple\\apple-week22.csv')

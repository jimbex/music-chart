# %%
from datetime import datetime
m = datetime.today().strftime('%B')
d = datetime.today().strftime('%d')
d = int(d)
w = datetime.today().strftime("%V")

# %%
import pandas as pd
df1 = pd.read_csv(f'C:\\Users\\faree\\Desktop\\music charts\\audiomack\\album-{m}{d - 6}.csv')
df2 = pd.read_csv(f'C:\\Users\\faree\\Desktop\\music charts\\audiomack\\album-{m}{d - 5}.csv')
df3 = pd.read_csv(f'C:\\Users\\faree\\Desktop\\music charts\\audiomack\\album-{m}{d - 4}.csv')
df4 = pd.read_csv(f'C:\\Users\\faree\\Desktop\\music charts\\audiomack\\album-{m}{d - 3}.csv')
df5 = pd.read_csv(f'C:\\Users\\faree\\Desktop\\music charts\\audiomack\\album-{m}{d - 2}.csv')
df6 = pd.read_csv(f'C:\\Users\\faree\\Desktop\\music charts\\audiomack\\album-{m}{d - 1}.csv')
df7 = pd.read_csv(f'C:\\Users\\faree\\Desktop\\music charts\\audiomack\\album-{m}{d}.csv')

# %%
albums = list(df1['album']) + list(df2['album']) + list(df3['album']) + list(df4['album']) + list(df5['album']) + list(df6['album']) + list(df7['album'])
albums = set(albums)
final = {}

# %%
artist1 = list(df1['artist'])
artist2 = list(df2['artist'])
artist3 = list(df3['artist'])
artist4 = list(df4['artist'])
artist5 = list(df5['artist'])
artist6 = list(df6['artist'])
artist7 = list(df7['artist'])

# %%
album = list(df1['album'])
for x in albums:
    if x in album:
        final[x] = [album.index(x) + 1]
    else:
        final[x] = [401]

# %%
album1 = list(df2['album'])
for x in albums:
    if x in album1:
        final[x].append(album1.index(x) + 1)
    else:
        final[x].append(401)

# %%
album2 = list(df3['album'])
for x in albums:
    if x in album2:
        final[x].append(album2.index(x) + 1)
    else:
        final[x].append(401)

# %%
album3 = list(df4['album'])
for x in albums:
    if x in album3:
        final[x].append(album3.index(x) + 1)
    else:
        final[x].append(401)

# %%
album4 = list(df5['album'])
for x in albums:
    if x in album4:
        final[x].append(album4.index(x) + 1)
    else:
        final[x].append(401)

# %%
album5 = list(df6['album'])
for x in albums:
    if x in album5:
        final[x].append(album5.index(x) + 1)
    else:
        final[x].append(401)

# %%
album6 = list(df7['album'])
for x in albums:
    if x in album6:
        final[x].append(album6.index(x) + 1)
    else:
        final[x].append(401)

# %%
albums = [x for x in final.keys()]
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
post7 = [x[6] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x] + post6[x] + post7[x] )/7 for x in range(0, len(final))]

# %%
artist = []
x = 0
for i in albums:
    if i in album:
        artist.append(artist1[album.index(i)])
    elif i in album1:
        artist.append(artist2[album1.index(i)])
    elif i in album2:
        artist.append(artist3[album2.index(i)])
    elif i in album3:
        artist.append(artist4[album3.index(i)])
    elif i in album5:
        artist.append(artist6[album5.index(i)])
    elif i in album6:
        artist.append(artist7[album6.index(i)])
    elif i in album4:
        artist.append(artist5[album4.index(i)])
    x += 1

# %%
data = {'album':albums,'artist':artist,'R1':post1,'R2':post2,'R3':post3,'R4':post4,'R5':post5,'R6':post6,'R7':post7,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,len(final) + 1)]
df = df.set_index('rank')

# %%
df
# Out:
#                                               album  \
# rank
# 1                                          UY Scuti
# 2                                  High Tension 2.0
# 3                                   A True Champion
# 4                                   High Tension EP
# 5                  Somewhere Between Beauty & Magic
# ...                                             ...
# 214                                     In The Dark
# 215                              Beyond Bulletproof
# 216   Project Baby 2: All Grown Up (Deluxe Edition)
# 217                              Lucille's Grandson
# 218                          CTV3: Cool Tape Vol. 3
#
#                                  artist   R1   R2   R3   R4   R5   R6   R7  \
# rank
# 1                               Olamide    2    1    1    1    1    1    1
# 2     Dangbana Republik & Bella Shmurda    1    2    2    2    2    2    2
# 3                                Rexxie    3    4    3    3    4    3    5
# 4                         Bella Shmurda    5    3    5    5    3    4    3
# 5                                Joeboy    4    8    4    4    6    5    4
# ...                                 ...  ...  ...  ...  ...  ...  ...  ...
# 214                              Mizzle  401  401  401  401  401  401  171
# 215                               Mozzy  401  401  401  173  401  401  401
# 216                         Kodak Black  401  174  401  401  401  401  401
# 217                          Kevo Muney  174  401  401  401  401  401  401
# 218                               Jaden  175  401  401  401  401  401  401
#
#               RT
# rank
# 1       1.142857
# 2       1.857143
# 3       3.571429
# 4       4.000000
# 5       5.000000
# ...          ...
# 214   368.142857
# 215   368.428571
# 216   368.571429
# 217   368.571429
# 218   368.714286
#
# [218 rows x 10 columns]

# %%
df.to_csv(f'C:\\Users\\faree\\Desktop\\music charts\\audiomack\\audiomack_album-week{w}.csv')

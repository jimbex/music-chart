# %%
from datetime import datetime
m = datetime.today().strftime('%B')
d = datetime.today().strftime('%d')
d = int(d)
w = datetime.today().strftime("%V")

# %%
import pandas as pd
df1 = pd.read_csv(f'africa-{m}{d - 6}.csv')
df2 = pd.read_csv(f'africa-{m}{d - 5}.csv')
df3 = pd.read_csv(f'africa-{m}{d - 4}.csv')
df4 = pd.read_csv(f'africa-{m}{d - 3}.csv')
df5 = pd.read_csv(f'africa-{m}{d - 2}.csv')
df6 = pd.read_csv(f'africa-{m}{d - 1}.csv')
df7 = pd.read_csv(f'africa-{m}{d}.csv')

# %%
df1 = df1[['song', 'artist']]
df2 = df2[['song', 'artist']]
df3 = df3[['song', 'artist']]
df4 = df4[['song', 'artist']]
df5 = df5[['song', 'artist']]
df6 = df6[['song', 'artist']]
df7 = df7[['song', 'artist']]

# %%
df7['position'] = [x for x in range(1,len(df7['song']) + 1)]
df6['position'] = [x for x in range(1,len(df6['song']) + 1)]
df5['position'] = [x for x in range(1,len(df5['song']) + 1)]
df4['position'] = [x for x in range(1,len(df4['song']) + 1)]
df3['position'] = [x for x in range(1,len(df3['song']) + 1)]
df2['position'] = [x for x in range(1,len(df2['song']) + 1)]
df1['position'] = [x for x in range(1,len(df1['song']) + 1)]

# %%
df7['title'] = [df7['song'][x] + ' - ' + df7['artist'][x] for x in range(0,len(df7['song']))]
df6['title'] = [df6['song'][x] + ' - ' + df6['artist'][x] for x in range(0,len(df6['song']))]
df5['title'] = [df5['song'][x] + ' - ' + df5['artist'][x] for x in range(0,len(df5['song']))]
df4['title'] = [df4['song'][x] + ' - ' + df4['artist'][x] for x in range(0,len(df4['song']))]
df3['title'] = [df3['song'][x] + ' - ' + df3['artist'][x] for x in range(0,len(df3['song']))]
df2['title'] = [df2['song'][x] + ' - ' + df2['artist'][x] for x in range(0,len(df2['song']))]
df1['title'] = [df1['song'][x] + ' - ' + df1['artist'][x] for x in range(0,len(df1['song']))]

# %%
songs = list(df1['title']) + list(df2['title']) + list(df3['title']) + list(df4['title']) + list(df5['title']) + list(df6['title']) + list(df7['title'])
songs = set(songs)
final = {}

# %%
song = list(df1['title'])
for x in songs:
    if x in song:
        final[x] = list(df1['position'][df1['title'] == x])
    else:
        final[x] = [301]

# %%
song1 = list(df2['title'])
for x in songs:
    if x in song1:
        final[x].append(int(df2['position'][df2['title'] == x]))
    else:
        final[x].append(301)

# %%
song2 = list(df3['title'])
for x in songs:
    if x in song2:
        final[x].append(int(df3['position'][df3['title'] == x]))
    else:
        final[x].append(301)

# %%
song3 = list(df4['title'])
for x in songs:
    if x in song3:
        final[x].append(int(df4['position'][df4['title'] == x]))
    else:
        final[x].append(301)

# %%
song4 = list(df5['title'])
for x in songs:
    if x in song4:
        final[x].append(int(df5['position'][df5['title'] == x]))
    else:
        final[x].append(301)

# %%
song5 = list(df6['title'])
for x in songs:
    if x in song5:
        final[x].append(int(df6['position'][df6['title'] == x]))
    else:
        final[x].append(301)

# %%
song6 = list(df7['title'])
for x in songs:
    if x in song6:
        final[x].append(int(df7['position'][df7['title'] == x]))
    else:
        final[x].append(301)

# %%
len(final)
# Out:
# 54

# %%
songs = [x[:x.index('-') - 1 ] for x in final.keys()]
artists = [x[x.index('-') + 2:] for x in final.keys()]
post1 = [x[0] for x in final.values()]
post2 = [x[1] for x in final.values()]
post3 = [x[2] for x in final.values()]
post4 = [x[3] for x in final.values()]
post5 = [x[4] for x in final.values()]
post6 = [x[5] for x in final.values()]
post7 = [x[6] for x in final.values()]
postT = [(post1[x] + post2[x] + post3[x] + post4[x] + post5[x] + post6[x] + post7[x] )/7 for x in range(0, len(final))]

# %%
data = {'song':songs,'artist':artists,'R1':post1,'R2':post2,'R3':post3,'R4':post4,'R5':post5,'R6':post6,'R7':post7,'RT': postT}
df = pd.DataFrame(data)

# %%
df.sort_values(by=['RT'], inplace=True)

# %%
df['rank'] = [x for x in range(1,len(final) + 1)]
df = df.set_index('rank')

# %%
df
# Out:
#                                                  song  \
# rank
# 1                                           Soundgasm
# 2                                             Feeling
# 3                                                Door
# 4                                           Kilometre
# 5                        Send Me Nudes (feat. Joey B)
# 6                     Dimension (feat. Skepta & Rema)
# 7                                              Bounce
# 8                                              Coming
# 9                                     Forever (Remix)
# 10                                            MOSLADO
# 11                                   Running (To You)
# 12                                               Rock
# 13                                      Falling For U
# 14                                           Kilofese
# 15                                              Focus
# 16                                          Confident
# 17                                      Music Messiah
# 18                                             Kamata
# 19                             LV N ATTN feat. Wizkid
# 20                                             Koroba
# 21          Yaba Buluku (feat. Preck & Nelson Tivane)
# 22                                        Let Dem Kno
# 23                                             Bosana
# 24                                           Dinaledi
# 25                                     Breakup Riddim
# 26                                       Celebrate Me
# 27    Ndombolo (feat. AbduKiba, K2ga & Tommy Flavour)
# 28                                       Yebo Teacher
# 29                          Nossas Coisas (feat. Ary)
# 30                                     This Your Body
# 31                                          Slow Down
# 32                                            Baikoko
# 33                                              GUPTA
# 34                                           Touch It
# 35                                               Woza
# 36                                          John Wick
# 37                                    KPK (Ko Por Ke)
# 38                                          Niko Sawa
# 39                       Sekkle & Bop (feat. Popcaan)
# 40                             Somebody (feat. Phyno)
# 41                                               PEPE
# 42                                             Meliza
# 43                                         Khuza Gogo
# 44                                               Jowo
# 45                                       Siyathandana
# 46                               Essence (feat. Tems)
# 47                                            Banyana
# 48                                           Señorita
# 49                                              Baajo
# 50                               Essence (feat. Tems)
# 51                                         Understand
# 52                                            Banyana
# 53                                       Siyathandana
# 54                                             Sinner
#
#                                                  artist   R1   R2   R3   R4  \
# rank
# 1                                                  Rema    1    1    1    1
# 2                                               LADIPOE    5    5    5    5
# 3                                                Joeboy    6    6    6    6
# 4                                             Burna Boy    3    3    3    3
# 5                                                  KiDi    4    4    4    4
# 6                                                  JAE5    9    9    9    9
# 7                                                  Rema    7    7    7    7
# 8                                          Naira Marley   10   10   10   10
# 9                                                Gyakie   11   11   11   11
# 10                                                 Teni   13   13   13   13
# 11                                                chike   12   12   12   12
# 12                                              Olamide   14   14   14   14
# 13                                          Blaq Jerzee   15   15   15   15
# 14                                   Remix - Zinoleesky   17   17   17   17
# 15                                               Joeboy   19   19   19   19
# 16                                               Savage   18   18   18   18
# 17                                           DJ Neptune   20   20   20   20
# 18                                     Diamond Platnumz   28   28   28   28
# 19                                                Lojay   22   22   22   22
# 20                                          Tiwa Savage   21   21   21   21
# 21                                    Remix - DJ Tarico   23   23   23   23
